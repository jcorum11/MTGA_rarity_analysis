# %%
# Load all packages necessary for analysis
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json
import re
import os
import timeit
import filecmp
import url_stripper

# %% [markdown]
# # mtg_archive

# %% [markdown]
# ## Gather

# %%
mtg_card_rarities_clean = pd.read_csv('mtg_card_rarities_clean.csv')

# %%
# Code to create a function to see if url leads to a file that can be downloaded
def is_downloadable(url):
    """
    Does the url contain a downloadable resource
    """
    h = requests.head(url, allow_redirects=True)
    header = h.headers
    content_type = header.get('content-type')
    if 'text' in content_type.lower():
        return False
    if 'html' in content_type.lower():
        return False
    return True

# %%
# code to see if url is downloadable
print(is_downloadable('https://www.mtgjson.com/json/AllSets.json'))
# Out:
# True

# %%
# code to download data as a response object and make it into a json object
mtg_archive = requests.get('https://www.mtgjson.com/json/AllSets.json')
mtg_archive_clean = mtg_archive.json()

# %%
# code to save mtg_archive_clean as a json file
with open('mtg_archive.txt', 'w') as outfile: 
    json.dump(mtg_archive_clean, outfile)

# %%
# code to load all cards data
with open('mtg_archive.txt', encoding='utf-8') as file:
    mtg_archive_clean = json.load(file)

# %% [markdown]
# ## Assess

# %%
# code to assess the type of mtg_archive_clean
type(mtg_archive_clean)
# Out:
# dict

# %%
# code to get the 40th element from mtg_archive_clean as a list
list(mtg_archive_clean.items())[1]
# Out:
# ('2ED',
#  {'baseSetSize': 302,
#   'block': 'Core Set',
#   'boosterV3': ['rare',
#    'uncommon',
#    'uncommon',
#    'uncommon',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common'],
#   'cards': [{'artist': 'Richard Thomas',
#     'borderColor': 'white',
#     'colorIdentity': ['U'],
#     'colors': ['U'],
#     'convertedManaCost': 5.0,
#     'edhrecRank': 11979,
#     'flavorText': 'These spirits of the air are winsome and wild, and cannot be truly contained. Only marginally intelligent, they often substitute whimsy for strategy, delighting in mischief and mayhem.',
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'brawl': 'Legal',
#      'commander': 'Legal',
#      'duel': 'Legal',
#      'future': 'Legal',
#      'historic': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'pioneer': 'Legal',
#      'standard': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{3}{U}{U}',
#     'mcmId': 4721,
#     'mcmMetaId': 81,
#     'mtgstocksId': 15753,
#     'multiverseId': 691,
#     'name': 'Air Elemental',
#     'number': '47',
#     'originalText': 'Flying',
#     'originalType': 'Summon - Elemental',
#     'power': '4',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 3.05,
#       '2019-08-04': 3.27,
#       '2019-08-11': 4.0,
#       '2019-08-18': 3.56,
#       '2019-08-25': 3.53,
#       '2019-09-01': 3.72,
#       '2019-09-08': 3.65,
#       '2019-09-15': 3.65,
#       '2019-09-22': 3.56,
#       '2019-09-29': 3.65,
#       '2019-10-06': 3.87,
#       '2019-10-13': 3.99,
#       '2019-10-20': 3.99},
#      'paperFoil': {}},
#     'printings': ['10E',
#      '2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      '7ED',
#      '8ED',
#      '9ED',
#      'BRB',
#      'BTD',
#      'CED',
#      'CEI',
#      'DD2',
#      'DPA',
#      'FBB',
#      'GNT',
#      'JVC',
#      'LEA',
#      'LEB',
#      'M10',
#      'M19',
#      'M20',
#      'ME4',
#      'P02',
#      'PS11',
#      'S99',
#      'SUM',
#      'W17',
#      'XLN'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/da7ee1a891c6dc07',
#      'mtgstocks': 'https://mtgjson.com/links/198ec7d5b2cbfe88',
#      'tcgplayer': 'https://mtgjson.com/links/3fa7c8121f5ff069'},
#     'rarity': 'uncommon',
#     'rulings': [],
#     'scryfallId': 'ef5b8140-a157-4c20-a428-fa7250ab34e1',
#     'scryfallIllustrationId': '67f66b28-3ee8-4ce0-a184-cb3d7c8fdb4f',
#     'scryfallOracleId': '7744bae4-a8b7-44a5-9b4c-0048ad4cc448',
#     'subtypes': ['Elemental'],
#     'supertypes': [],
#     'tcgplayerProductId': 8972,
#     'text': 'Flying',
#     'toughness': '4',
#     'type': 'Creature — Elemental',
#     'types': ['Creature'],
#     'uuid': '09c8f87f-aef0-56bf-861d-dae4b974a6e6'},
#    {'artist': 'Mark Poole',
#     'borderColor': 'white',
#     'colorIdentity': ['U'],
#     'colors': ['U'],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 17488,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'isReserved': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Banned',
#      'duel': 'Banned',
#      'legacy': 'Banned',
#      'oldschool': 'Restricted',
#      'vintage': 'Restricted'},
#     'manaCost': '{U}',
#     'mcmId': 4723,
#     'mcmMetaId': 161,
#     'mtgstocksId': 15754,
#     'multiverseId': 692,
#     'name': 'Ancestral Recall',
#     'number': '48',
#     'originalText': 'Draw 3 cards or force opponent to draw 3 cards.',
#     'originalType': 'Instant',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 2768.33,
#       '2019-08-04': 2768.33,
#       '2019-08-11': 2768.33,
#       '2019-08-18': 2768.33,
#       '2019-08-25': 2999.0,
#       '2019-09-01': 2999.0,
#       '2019-09-08': 2999.0,
#       '2019-09-15': 2999.0,
#       '2019-09-22': 2999.0,
#       '2019-09-29': 2999.0,
#       '2019-10-06': 2999.0,
#       '2019-10-13': 2999.0,
#       '2019-10-20': 2924.5},
#      'paperFoil': {}},
#     'printings': ['2ED', 'CED', 'CEI', 'LEA', 'LEB', 'OVNT', 'PRM', 'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/27ea4b196fba7c90',
#      'mtgstocks': 'https://mtgjson.com/links/4067a685624dbe6a',
#      'tcgplayer': 'https://mtgjson.com/links/d630d3deb695e147'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': '2dd41293-d7c8-4422-9f0c-b3e96350f5c9',
#     'scryfallIllustrationId': 'd20eda7b-a902-4c00-bdab-601059e417b5',
#     'scryfallOracleId': '550c74d4-1fcb-406a-b02a-639a760a4380',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8973,
#     'text': 'Target player draws three cards.',
#     'type': 'Instant',
#     'types': ['Instant'],
#     'uuid': 'e1a727f8-1653-5adc-b37b-35b444777cf6'},
#    {'artist': 'Douglas Shuler',
#     'borderColor': 'white',
#     'colorIdentity': ['U'],
#     'colors': ['U'],
#     'convertedManaCost': 4.0,
#     'edhrecRank': 16703,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{3}{U}',
#     'mcmId': 4725,
#     'mcmMetaId': 199,
#     'mtgstocksId': 15755,
#     'multiverseId': 693,
#     'name': 'Animate Artifact',
#     'number': '49',
#     'originalText': 'Target artifact is now a creature with both power and toughness equal to its casting cost; target retains all its original abilities as well. This will destroy artifacts with 0 casting cost.',
#     'originalType': 'Enchant Non-Creature Artifact',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 1.9,
#       '2019-08-04': 1.96,
#       '2019-08-11': 1.88,
#       '2019-08-18': 1.78,
#       '2019-08-25': 1.75,
#       '2019-09-01': 1.8,
#       '2019-09-08': 1.8,
#       '2019-09-15': 1.8,
#       '2019-09-22': 1.8,
#       '2019-09-29': 1.96,
#       '2019-10-06': 1.99,
#       '2019-10-13': 2.01,
#       '2019-10-20': 1.96},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME4',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/0987754305cff412',
#      'mtgstocks': 'https://mtgjson.com/links/f86dc7d07275b383',
#      'tcgplayer': 'https://mtgjson.com/links/51f857a7090afad9'},
#     'rarity': 'uncommon',
#     'rulings': [{'date': '2008-08-01',
#       'text': 'This card has been returned to its original functionality. If it is enchanting an artifact that’s already a creature, it won’t change its power and toughness.'},
#      {'date': '2008-08-01',
#       'text': 'A noncreature permanent that turns into a creature can attack, and its {T} abilities can be activated, only if its controller has continuously controlled that permanent since the beginning of their most recent turn. It doesn’t matter how long the permanent has been a creature.'}],
#     'scryfallId': 'caf1ee51-2852-44c0-a5d4-d0e415381738',
#     'scryfallIllustrationId': '3c8723a8-4f77-491b-9d6b-7ee13e08edb6',
#     'scryfallOracleId': '2dd7a4dc-902a-4e85-8a3b-c96a898fba86',
#     'subtypes': ['Aura'],
#     'supertypes': [],
#     'tcgplayerProductId': 8974,
#     'text': "Enchant artifact\nAs long as enchanted artifact isn't a creature, it's an artifact creature with power and toughness each equal to its converted mana cost.",
#     'type': 'Enchantment — Aura',
#     'types': ['Enchantment'],
#     'uuid': 'ff4f7f41-4612-52a4-94d3-d985e52d047a'},
#    {'artist': 'Anson Maddocks',
#     'borderColor': 'white',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 155,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}{B}',
#     'mcmId': 4629,
#     'mcmMetaId': 200,
#     'mtgstocksId': 15756,
#     'multiverseId': 645,
#     'name': 'Animate Dead',
#     'number': '93',
#     'originalText': "Any creature in either player's graveyard comes into play on your side with -1 to its original power. If this enchantment is removed, or at end of game, target creature is returned to its owner's graveyard. Target creature may be killed as normal.",
#     'originalType': 'Enchant Dead Creature',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 13.99,
#       '2019-08-04': 13.99,
#       '2019-08-11': 13.99,
#       '2019-08-18': 13.85,
#       '2019-08-25': 13.76,
#       '2019-09-01': 14.49,
#       '2019-09-08': 14.24,
#       '2019-09-15': 14.49,
#       '2019-09-22': 13.99,
#       '2019-09-29': 14.22,
#       '2019-10-06': 14.55,
#       '2019-10-13': 13.56,
#       '2019-10-20': 13.56},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'CED',
#      'CEI',
#      'EMA',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME1',
#      'PD3',
#      'SUM',
#      'TD0',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/a035a920d38839f7',
#      'mtgstocks': 'https://mtgjson.com/links/211d75d773ab60fd',
#      'tcgplayer': 'https://mtgjson.com/links/5c29bb6d691728a1'},
#     'rarity': 'uncommon',
#     'rulings': [{'date': '2016-06-08',
#       'text': 'Animate Dead is an Aura, albeit with an unusual enchant ability. You target a creature card in a graveyard when you cast it. It enters the battlefield attached to that card. Then it returns that card to the battlefield, and attaches itself to the card again (since the card is a new object on the battlefield). Animate Dead itself never moves into a graveyard during this process.'},
#      {'date': '2016-06-08',
#       'text': 'If Animate Dead isn’t on the battlefield as its triggered ability resolves, none of its effects happen. The creature card won’t be returned to the battlefield.'},
#      {'date': '2016-06-08',
#       'text': 'Abilities such as shroud and protection function only on the battlefield unless otherwise specified. A creature card with shroud may be targeted by Animate Dead, and Animate Dead will become attached to the creature that enters the battlefield.'},
#      {'date': '2016-06-08',
#       'text': 'If the creature put onto the battlefield has protection from black—or if the creature can’t legally be enchanted by Animate Dead for another reason—Animate Dead won’t be able to attach to it. It will be put into the graveyard as a state-based action, causing its delayed triggered ability to trigger. When the trigger resolves, if the creature’s still on the battlefield, its controller will sacrifice it.'},
#      {'date': '2016-06-08',
#       'text': 'Once the creature is returned to the battlefield, Animate Dead can’t be attached to anything other than it (unless Animate Dead somehow manages to put a different creature onto the battlefield). Attempting to move Animate Dead to another creature won’t work.'}],
#     'scryfallId': '0fc3ed63-96ee-420c-bde1-e0c904059931',
#     'scryfallIllustrationId': 'b19cb181-a679-4d68-b2cd-e0a809de03bc',
#     'scryfallOracleId': 'c0d8fef4-65f4-4769-982d-b397d2b7e977',
#     'subtypes': ['Aura'],
#     'supertypes': [],
#     'tcgplayerProductId': 8975,
#     'text': 'Enchant creature card in a graveyard\nWhen Animate Dead enters the battlefield, if it\'s on the battlefield, it loses "enchant creature card in a graveyard" and gains "enchant creature put onto the battlefield with Animate Dead." Return enchanted creature card to the battlefield under your control and attach Animate Dead to it. When Animate Dead leaves the battlefield, that creature\'s controller sacrifices it.\nEnchanted creature gets -1/-0.',
#     'type': 'Enchantment — Aura',
#     'types': ['Enchantment'],
#     'uuid': '810ceb8f-66ae-5fee-8033-fad5aaf0d25a'},
#    {'artist': 'Dan Frazier',
#     'borderColor': 'white',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 10466,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{W}',
#     'mcmId': 4997,
#     'mcmMetaId': 202,
#     'mtgstocksId': 15757,
#     'multiverseId': 829,
#     'name': 'Animate Wall',
#     'number': '1',
#     'originalText': "Target wall can now attack. Target wall's power and toughness are unchanged, even if its power is 0.",
#     'originalType': 'Enchant Wall',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 11.98,
#       '2019-08-04': 11.98,
#       '2019-08-11': 11.98,
#       '2019-08-18': 11.99,
#       '2019-08-25': 11.98,
#       '2019-09-01': 12.0,
#       '2019-09-08': 14.44,
#       '2019-09-15': 14.8,
#       '2019-09-22': 14.89,
#       '2019-09-29': 17.9,
#       '2019-10-06': 18.0,
#       '2019-10-13': 18.04,
#       '2019-10-20': 10.45},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME1',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/7e422871372e3867',
#      'mtgstocks': 'https://mtgjson.com/links/e638770374d66ca1',
#      'tcgplayer': 'https://mtgjson.com/links/d45b49a5c408c3a5'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2007-09-16',
#       'text': 'This is a change from the most recent wording. As was the case in the past, Animate Wall can now enchant only a Wall.'}],
#     'scryfallId': '05d7bed4-950a-4a4e-b79a-50e4aa416fe9',
#     'scryfallIllustrationId': '6757e04d-7bfc-4bdc-9dcb-02059a2d4e60',
#     'scryfallOracleId': 'c7a6a165-b709-46e0-ae42-6f69a17c0621',
#     'subtypes': ['Aura'],
#     'supertypes': [],
#     'tcgplayerProductId': 8976,
#     'text': "Enchant Wall\nEnchanted Wall can attack as though it didn't have defender.",
#     'type': 'Enchantment — Aura',
#     'types': ['Enchantment'],
#     'uuid': '4ba51671-c7be-5196-a211-aaa0cc33c5b7'},
#    {'artist': 'Amy Weber',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 3186,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{2}',
#     'mcmId': 5089,
#     'mcmMetaId': 203,
#     'mtgstocksId': 15758,
#     'multiverseId': 598,
#     'name': 'Ankh of Mishra',
#     'number': '231',
#     'originalText': 'Ankh does 2 damage to anyone who puts a new land into play.',
#     'originalType': 'Continuous Artifact',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 57.25,
#       '2019-08-04': 68.14,
#       '2019-08-11': 69.99,
#       '2019-08-18': 62.99,
#       '2019-08-25': 65.98,
#       '2019-09-01': 61.23,
#       '2019-09-08': 61.21,
#       '2019-09-15': 61.21,
#       '2019-09-22': 59.48,
#       '2019-09-29': 52.46,
#       '2019-10-06': 61.21,
#       '2019-10-13': 47.5,
#       '2019-10-20': 50.0},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME1',
#      'SUM',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/c77c2c6308a6a3cc',
#      'mtgstocks': 'https://mtgjson.com/links/b5a993d53cd2975d',
#      'tcgplayer': 'https://mtgjson.com/links/3309e3883ea9bcc8'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2004-10-04',
#       'text': 'This triggers on any land entering the battlefield. This includes playing a land or putting a land onto the battlefield using a spell or ability.'},
#      {'date': '2004-10-04',
#       'text': 'It determines the land’s controller at the time the ability resolves. If the land leaves the battlefield before the ability resolves, the land’s last controller before it left is used.'}],
#     'scryfallId': '808cad10-69d5-4e14-9834-476c53ec97e4',
#     'scryfallIllustrationId': 'f6b4406b-9216-4a41-b637-13a77b078ab9',
#     'scryfallOracleId': '63c1eda1-3e6f-4e9c-adf3-a43164df98bb',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8977,
#     'text': "Whenever a land enters the battlefield, Ankh of Mishra deals 2 damage to that land's controller.",
#     'type': 'Artifact',
#     'types': ['Artifact'],
#     'uuid': 'df3fc42f-2a53-575e-90b9-b7821d20bf92'},
#    {'artist': 'Jesper Myrfors',
#     'borderColor': 'white',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 4.0,
#     'edhrecRank': 904,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{3}{W}',
#     'mcmId': 4999,
#     'mcmMetaId': 283,
#     'mtgstocksId': 15759,
#     'multiverseId': 830,
#     'name': 'Armageddon',
#     'number': '2',
#     'originalText': 'All lands in play are destroyed.',
#     'originalType': 'Sorcery',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 94.29,
#       '2019-08-04': 89.99,
#       '2019-08-11': 89.99,
#       '2019-08-18': 89.99,
#       '2019-08-25': 89.98,
#       '2019-09-01': 89.99,
#       '2019-09-08': 89.98,
#       '2019-09-15': 89.98,
#       '2019-09-22': 87.0,
#       '2019-09-29': 87.0,
#       '2019-10-06': 85.0,
#       '2019-10-13': 85.0,
#       '2019-10-20': 85.0},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      'A25',
#      'ATH',
#      'CED',
#      'CEI',
#      'FBB',
#      'G04',
#      'LEA',
#      'LEB',
#      'ME1',
#      'ME4',
#      'MP2',
#      'P02',
#      'POR',
#      'PRM',
#      'PTC',
#      'S99',
#      'SUM',
#      'V14',
#      'VMA',
#      'WC00',
#      'WC98'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/a02da8ecf0dda549',
#      'mtgstocks': 'https://mtgjson.com/links/50b606c26f466ba7',
#      'tcgplayer': 'https://mtgjson.com/links/6e0fa02a857e9126'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': 'df2c5d5c-f1c9-4639-bf72-3f6bde554864',
#     'scryfallIllustrationId': 'be2ceead-1cc4-4e3b-8b0d-bb7010b91312',
#     'scryfallOracleId': 'c9ed8b01-959a-47d6-891e-0abbdccf6e4f',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8978,
#     'text': 'Destroy all lands.',
#     'type': 'Sorcery',
#     'types': ['Sorcery'],
#     'uuid': 'd0b5920c-ee6f-5211-9bc5-eb18838b6d32'},
#    {'artist': 'Jeff A. Menges',
#     'borderColor': 'white',
#     'colorIdentity': ['G'],
#     'colors': ['G'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 11664,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}{G}',
#     'mcmId': 4813,
#     'mcmMetaId': 320,
#     'mtgstocksId': 15760,
#     'multiverseId': 737,
#     'name': 'Aspect of Wolf',
#     'number': '185',
#     'originalText': "Target creature's power and toughness are increased by half the number of forests you have in play, rounding down for power and up for toughness.",
#     'originalType': 'Enchant Creature',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 10.0,
#       '2019-08-04': 10.0,
#       '2019-08-11': 11.38,
#       '2019-08-18': 11.38,
#       '2019-08-25': 10.0,
#       '2019-09-01': 9.98,
#       '2019-09-08': 13.5,
#       '2019-09-15': 9.74,
#       '2019-09-22': 9.05,
#       '2019-09-29': 9.09,
#       '2019-10-06': 9.98,
#       '2019-10-13': 9.45,
#       '2019-10-20': 12.13},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'PZ2',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/8e2d8f31e995a2d5',
#      'mtgstocks': 'https://mtgjson.com/links/1e75a5eb2eaebfce',
#      'tcgplayer': 'https://mtgjson.com/links/d8fe6b9b76a029c1'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2009-10-01',
#       'text': 'The effect is continuously updated based on the number of Forests you control at any given time.'}],
#     'scryfallId': '5aa02bb5-7365-4b8d-ac86-13721fb19d01',
#     'scryfallIllustrationId': 'e31bc7be-9082-475c-9fb6-7336354ad1e2',
#     'scryfallOracleId': '77b7277d-90a1-4774-a998-8c35c3f94e4a',
#     'subtypes': ['Aura'],
#     'supertypes': [],
#     'tcgplayerProductId': 8979,
#     'text': 'Enchant creature\nEnchanted creature gets +X/+Y, where X is half the number of Forests you control, rounded down, and Y is half the number of Forests you control, rounded up.',
#     'type': 'Enchantment — Aura',
#     'types': ['Enchantment'],
#     'uuid': '7277d11a-2476-52f8-8cfc-638c82aa987c'},
#    {'artist': 'Jesper Myrfors',
#     'borderColor': 'white',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 3882,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}{B}',
#     'mcmId': 4631,
#     'mcmMetaId': 405,
#     'mtgstocksId': 15761,
#     'multiverseId': 646,
#     'name': 'Bad Moon',
#     'number': '94',
#     'originalText': 'All black creatures in play gain +1/+1.',
#     'originalType': 'Enchantment',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 89.0,
#       '2019-08-04': 89.0,
#       '2019-08-11': 88.98,
#       '2019-08-18': 98.95,
#       '2019-08-25': 31.98,
#       '2019-09-01': 31.98,
#       '2019-09-08': 29.95,
#       '2019-09-15': 26.4,
#       '2019-09-22': 22.85,
#       '2019-09-29': 21.93,
#       '2019-10-06': 21.89,
#       '2019-10-13': 80.99,
#       '2019-10-20': 75.99},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'C14',
#      'CED',
#      'CEI',
#      'DDD',
#      'FBB',
#      'GVL',
#      'LEA',
#      'LEB',
#      'SUM',
#      'TSB'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/7f9b31c821322880',
#      'mtgstocks': 'https://mtgjson.com/links/d9db501bfca5a1bc',
#      'tcgplayer': 'https://mtgjson.com/links/1072aa7d027aeab3'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': '882fe528-1a84-4d34-bd15-330963b684ff',
#     'scryfallIllustrationId': '7a41f4a9-2cb2-4844-ac0a-85a8d3014d5e',
#     'scryfallOracleId': 'fc5d3341-cbce-49e5-93cc-8add92479dca',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8980,
#     'text': 'Black creatures get +1/+1.',
#     'type': 'Enchantment',
#     'types': ['Enchantment'],
#     'uuid': '89a5e7ed-2a95-53b6-b3c5-d7b676d78b42'},
#    {'artist': 'Rob Alexander',
#     'borderColor': 'white',
#     'colorIdentity': ['B', 'R'],
#     'colors': [],
#     'convertedManaCost': 0.0,
#     'edhrecRank': 532,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'isReserved': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'mcmId': 5183,
#     'mcmMetaId': 407,
#     'mtgstocksId': 15762,
#     'multiverseId': 878,
#     'name': 'Badlands',
#     'number': '278',
#     'originalText': 'Counts as both mountains and swamp and is affected by spells that affect either. Tap to add either oR or oB to your mana pool.',
#     'originalType': 'Land',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 550.72,
#       '2019-08-04': 550.72,
#       '2019-08-11': 550.72,
#       '2019-08-18': 601.45,
#       '2019-08-25': 601.45,
#       '2019-09-01': 601.45,
#       '2019-09-08': 601.45,
#       '2019-09-15': 601.45,
#       '2019-09-22': 550.23,
#       '2019-09-29': 550.23,
#       '2019-10-06': 550.72,
#       '2019-10-13': 499.0,
#       '2019-10-20': 499.0},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME2',
#      'ME4',
#      'OLGC',
#      'PRM',
#      'SUM',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/50faba082c868e53',
#      'mtgstocks': 'https://mtgjson.com/links/0be25fdae2677d86',
#      'tcgplayer': 'https://mtgjson.com/links/0bf366a6fdd64380'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2004-10-04',
#       'text': 'Land type changing effects that change a dual land’s land type will remove the old land types completely. Text-changing effects that just change one of the two land types will leave the other type unaffected.'},
#      {'date': '2004-10-04',
#       'text': 'This card is a Mountain and a Swamp even while in the graveyard, library, or any other zone.'},
#      {'date': '2008-10-01',
#       'text': 'This has the mana abilities associated with both of its basic land types.'},
#      {'date': '2008-10-01',
#       'text': 'This has basic land types, but it isn’t a basic land. Things that affect basic lands don’t affect it. Things that affect basic land types do.'}],
#     'scryfallId': '5804dcd3-d41d-4cbd-9f8f-9736f2d37a64',
#     'scryfallIllustrationId': '669aded5-981a-45ab-9e4e-5864a91c71e5',
#     'scryfallOracleId': '13ff3222-91cb-4796-a34e-899ed817694c',
#     'subtypes': ['Swamp', 'Mountain'],
#     'supertypes': [],
#     'tcgplayerProductId': 8981,
#     'text': '({T}: Add {B} or {R}.)',
#     'type': 'Land — Swamp Mountain',
#     'types': ['Land'],
#     'uuid': 'e4d53516-8187-5480-bf54-ae2ba755f1d4'},
#    {'artist': 'Mark Poole',
#     'borderColor': 'white',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 18388,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Banned',
#      'duel': 'Legal',
#      'legacy': 'Banned',
#      'oldschool': 'Restricted',
#      'vintage': 'Restricted'},
#     'manaCost': '{1}{W}',
#     'mcmId': 5001,
#     'mcmMetaId': 409,
#     'mtgstocksId': 15763,
#     'multiverseId': 831,
#     'name': 'Balance',
#     'number': '3',
#     'originalText': 'Whichever player has more lands in play must discard enough lands of his or her choice to equalize the number of lands both players have in play. Cards in hand and creatures in play must be equalized the same way. Creatures lost in this manner may not be regenerated.',
#     'originalType': 'Sorcery',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 41.28,
#       '2019-08-04': 40.92,
#       '2019-08-11': 40.92,
#       '2019-08-18': 40.92,
#       '2019-08-25': 35.97,
#       '2019-09-01': 60.99,
#       '2019-09-08': 60.99,
#       '2019-09-15': 59.99,
#       '2019-09-22': 59.49,
#       '2019-09-29': 61.99,
#       '2019-10-06': 60.99,
#       '2019-10-13': 59.49,
#       '2019-10-20': 61.99},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      'CED',
#      'CEI',
#      'EMA',
#      'FBB',
#      'G04',
#      'LEA',
#      'LEB',
#      'ME4',
#      'PRM',
#      'PTC',
#      'SUM',
#      'V09',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/55b66962e85ea8d5',
#      'mtgstocks': 'https://mtgjson.com/links/685a01bcbf7ff41e',
#      'tcgplayer': 'https://mtgjson.com/links/8a14280db61f034e'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2016-06-08',
#       'text': 'First the player whose turn it is chooses which lands (if any) to keep, then each other player in turn order does the same. Each player will know the choices made by the players who chose before them. All of the unchosen lands are then sacrificed simultaneously. Then the process is repeated for cards in hand, except that no cards are revealed until all players have chosen what to discard, at which point those cards are all discarded simultaneously. Lastly, the process is repeated for creatures, and players will again know earlier choices made when deciding what to sacrifice. All of the unchosen creatures are then sacrificed simultaneously.'},
#      {'date': '2016-06-08',
#       'text': 'Balance doesn’t have targets, so permanents that can’t be targeted, such as a creature with shroud or protection from white, are valid choices to be sacrificed.'},
#      {'date': '2016-06-08',
#       'text': 'Each type of object is counted during the corresponding part of the process. Cards in hand are counted after lands have been sacrificed, and creatures on the battlefield are counted after cards have been discarded. Thus, a land creature sacrificed to the first part of the spell would not be counted when determining how many creatures are on the battlefield for the last part.'}],
#     'scryfallId': '8352e8b6-c947-49f3-a653-a6af65d3e9c3',
#     'scryfallIllustrationId': 'e47fbe71-fcea-4aba-9d74-fc6fec8407f7',
#     'scryfallOracleId': '17fa98cd-ed8f-483f-9525-7e989a82ebb2',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8982,
#     'text': 'Each player chooses a number of lands they control equal to the number of lands controlled by the player who controls the fewest, then sacrifices the rest. Players discard cards and sacrifice creatures the same way.',
#     'type': 'Sorcery',
#     'types': ['Sorcery'],
#     'uuid': '39342ed8-f073-57b3-a741-ae2cd782d88a'},
#    {'artist': 'Jesper Myrfors',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 3.0,
#     'edhrecRank': 263,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{3}',
#     'mcmId': 5091,
#     'mcmMetaId': 470,
#     'mtgstocksId': 15764,
#     'multiverseId': 599,
#     'name': 'Basalt Monolith',
#     'number': '232',
#     'originalText': 'Tap to add 3 colorless mana to your mana pool. Does not untap as normal during untap phase; spend o3 to untap. Tapping this artifact can be played as an interrupt.',
#     'originalType': 'Mono Artifact',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 15.0,
#       '2019-08-04': 14.49,
#       '2019-08-11': 13.79,
#       '2019-08-18': 13.62,
#       '2019-08-25': 13.0,
#       '2019-09-01': 12.85,
#       '2019-09-08': 12.85,
#       '2019-09-15': 11.99,
#       '2019-09-22': 11.77,
#       '2019-09-29': 12.0,
#       '2019-10-06': 11.87,
#       '2019-10-13': 11.87,
#       '2019-10-20': 11.77},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      'C13',
#      'C15',
#      'CED',
#      'CEI',
#      'CM2',
#      'CMA',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME4',
#      'PRM',
#      'PZ1',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/b4db4e86d87a5aaf',
#      'mtgstocks': 'https://mtgjson.com/links/31db5ec18e9c8bb2',
#      'tcgplayer': 'https://mtgjson.com/links/6cbb65e4607f0fee'},
#     'rarity': 'uncommon',
#     'rulings': [{'date': '2004-10-04',
#       'text': 'It can be untapped as often as you can pay for it.'}],
#     'scryfallId': '5a72cd4b-5b47-46b8-b230-4b246f97221f',
#     'scryfallIllustrationId': '86e208e2-f67d-4dd2-9a46-48e704d43efb',
#     'scryfallOracleId': '6b8cf2a0-b045-4d91-9d91-c602d40c6237',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8983,
#     'text': "Basalt Monolith doesn't untap during your untap step.\n{T}: Add {C}{C}{C}.\n{3}: Untap Basalt Monolith.",
#     'type': 'Artifact',
#     'types': ['Artifact'],
#     'uuid': 'f1cd5807-b3f4-58ee-9b39-87e028296b65'},
#    {'artist': 'Jesper Myrfors',
#     'borderColor': 'white',
#     'colorIdentity': ['B', 'G'],
#     'colors': [],
#     'convertedManaCost': 0.0,
#     'edhrecRank': 489,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'isReserved': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'mcmId': 5185,
#     'mcmMetaId': 492,
#     'mtgstocksId': 15765,
#     'multiverseId': 879,
#     'name': 'Bayou',
#     'number': '279',
#     'originalText': 'Counts as both swamp and forest and is affected by spells that affect either. Tap to add either oB or oG to your mana pool.',
#     'originalType': 'Land',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 759.0,
#       '2019-08-04': 748.75,
#       '2019-08-11': 692.0,
#       '2019-08-18': 759.0,
#       '2019-08-25': 725.0,
#       '2019-09-01': 792.0,
#       '2019-09-08': 769.0,
#       '2019-09-15': 709.5,
#       '2019-09-22': 693.25,
#       '2019-09-29': 708.25,
#       '2019-10-06': 799.0,
#       '2019-10-13': 699.6,
#       '2019-10-20': 699.6},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME3',
#      'ME4',
#      'OLGC',
#      'PRM',
#      'SUM',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/0000e6ae11886e5a',
#      'mtgstocks': 'https://mtgjson.com/links/ade6800a35b089aa',
#      'tcgplayer': 'https://mtgjson.com/links/946b10af6556fa2a'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2008-10-01',
#       'text': 'This has the mana abilities associated with both of its basic land types.'},
#      {'date': '2008-10-01',
#       'text': 'This has basic land types, but it isn’t a basic land. Things that affect basic lands don’t affect it. Things that affect basic land types do.'}],
#     'scryfallId': 'd66e43f0-1558-409f-8248-cc1d76c6bd8e',
#     'scryfallIllustrationId': '8cb160a9-900b-420e-bce8-3a62f689d2c8',
#     'scryfallOracleId': 'b76d1ae6-ad1d-4bac-b4c3-2e03e0e84d9b',
#     'subtypes': ['Swamp', 'Forest'],
#     'supertypes': [],
#     'tcgplayerProductId': 8984,
#     'text': '({T}: Add {B} or {G}.)',
#     'type': 'Land — Swamp Forest',
#     'types': ['Land'],
#     'uuid': 'fbcd5538-9879-5b5f-84e1-5c200fb3ea7f'},
#    {'artist': 'Douglas Shuler',
#     'borderColor': 'white',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 13726,
#     'flavorText': 'Benalia has a complex caste system that changes with the lunar year. No matter what the season, the only caste that cannot be attained by either heredity or money is that of the hero.',
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'pauper': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{W}',
#     'mcmId': 5003,
#     'mcmMetaId': 518,
#     'mtgstocksId': 15766,
#     'multiverseId': 832,
#     'name': 'Benalish Hero',
#     'number': '4',
#     'originalText': 'Bands',
#     'originalType': 'Summon - Hero',
#     'power': '1',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 0.54,
#       '2019-08-04': 0.53,
#       '2019-08-11': 0.51,
#       '2019-08-18': 0.54,
#       '2019-08-25': 0.55,
#       '2019-09-01': 0.6,
#       '2019-09-08': 0.58,
#       '2019-09-15': 0.6,
#       '2019-09-22': 0.57,
#       '2019-09-29': 0.54,
#       '2019-10-06': 0.55,
#       '2019-10-13': 0.57,
#       '2019-10-20': 0.5},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME1',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/8c37bcea87c0dc9c',
#      'mtgstocks': 'https://mtgjson.com/links/137605df6f07f6b9',
#      'tcgplayer': 'https://mtgjson.com/links/89cfcea2d8153d71'},
#     'rarity': 'common',
#     'rulings': [{'date': '2008-10-01',
#       'text': 'If a creature with banding attacks, it can team up with any number of other attacking creatures with banding (and up to one nonbanding creature) and attack as a unit called a “band.” The band can be blocked by any creature that could block a single creature in the band. Blocking any creature in a band blocks the entire band. If a creature with banding is blocked, the attacking player chooses how the blockers’ damage is assigned.'},
#      {'date': '2008-10-01',
#       'text': 'A maximum of one nonbanding creature can join an attacking band no matter how many creatures with banding are in it.'},
#      {'date': '2008-10-01',
#       'text': 'Creatures in the same band must all attack the same player or planeswalker.'},
#      {'date': '2009-10-01',
#       'text': 'If a creature in combat has banding, its controller assigns damage for creatures blocking or blocked by it. That player can ignore the damage assignment order when making this assignment.'}],
#     'scryfallId': '9404e779-2065-4c4f-95d1-6997c7fea156',
#     'scryfallIllustrationId': '36cd4598-d058-49f8-b39e-0a5997ca5a42',
#     'scryfallOracleId': '4c81cfb7-8765-4e28-ae33-4287fa9a86cc',
#     'subtypes': ['Human', 'Soldier'],
#     'supertypes': [],
#     'tcgplayerProductId': 8985,
#     'text': "Banding (Any creatures with banding, and up to one without, can attack in a band. Bands are blocked as a group. If any creatures with banding you control are blocking or being blocked by a creature, you divide that creature's combat damage, not its controller, among any of the creatures it's being blocked by or is blocking.)",
#     'toughness': '1',
#     'type': 'Creature — Human Soldier',
#     'types': ['Creature'],
#     'uuid': '26eeede1-1658-557e-97c1-885ae835546c'},
#    {'artist': 'Dan Frazier',
#     'borderColor': 'white',
#     'colorIdentity': ['G'],
#     'colors': ['G'],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 2882,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{G}',
#     'mcmId': 4815,
#     'mcmMetaId': 532,
#     'mtgstocksId': 15767,
#     'multiverseId': 738,
#     'name': 'Berserk',
#     'number': '186',
#     'originalText': "Until end of turn, target creature's current power doubles and it gains trample ability. If it attacks, target creature is destroyed at end of turn. This spell cannot be cast after current turn's attack is completed.",
#     'originalType': 'Instant',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 78.01,
#       '2019-08-04': 75.0,
#       '2019-08-11': 76.75,
#       '2019-08-18': 76.75,
#       '2019-08-25': 78.58,
#       '2019-09-01': 76.24,
#       '2019-09-08': 76.24,
#       '2019-09-15': 74.12,
#       '2019-09-22': 76.24,
#       '2019-09-29': 76.24,
#       '2019-10-06': 76.24,
#       '2019-10-13': 76.24,
#       '2019-10-20': 76.14},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      'CED',
#      'CEI',
#      'CN2',
#      'LEA',
#      'LEB',
#      'ME1',
#      'V09',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/8564cb6ad9529539',
#      'mtgstocks': 'https://mtgjson.com/links/9b8e27c00ad4e318',
#      'tcgplayer': 'https://mtgjson.com/links/7e162e2951e5e5cd'},
#     'rarity': 'uncommon',
#     'rulings': [{'date': '2004-10-04',
#       'text': 'If the permanent stops being a creature before the end of the turn, it is still destroyed.'}],
#     'scryfallId': 'fd082697-493f-48e3-a41f-123700435025',
#     'scryfallIllustrationId': '9b8e590c-8a0c-4805-ba5d-60fc2f243e86',
#     'scryfallOracleId': '8b67d192-9a05-4a47-82ae-5fc4b7834d88',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8986,
#     'text': 'Cast this spell only before the combat damage step.\nTarget creature gains trample and gets +X/+0 until end of turn, where X is its power. At the beginning of the next end step, destroy that creature if it attacked this turn.',
#     'type': 'Instant',
#     'types': ['Instant'],
#     'uuid': '9833721b-dcb5-52c2-ab3c-46f673632d14'},
#    {'artist': 'Mark Poole',
#     'borderColor': 'white',
#     'colorIdentity': ['G'],
#     'colors': ['G'],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 78,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{G}',
#     'mcmId': 4817,
#     'mcmMetaId': 545,
#     'mtgstocksId': 15768,
#     'multiverseId': 739,
#     'name': 'Birds of Paradise',
#     'number': '187',
#     'originalText': 'Flying\nTap to add one mana of any color to your mana pool. This tap may be played as an interrupt.',
#     'originalType': 'Summon - Mana Birds',
#     'power': '0',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 300.0,
#       '2019-08-04': 300.0,
#       '2019-08-11': 300.0,
#       '2019-08-18': 312.5,
#       '2019-08-25': 312.5,
#       '2019-09-01': 312.5,
#       '2019-09-08': 312.5,
#       '2019-09-15': 312.5,
#       '2019-09-22': 280.0,
#       '2019-09-29': 312.5,
#       '2019-10-06': 312.5,
#       '2019-10-13': 319.5,
#       '2019-10-20': 319.5},
#      'paperFoil': {}},
#     'printings': ['10E',
#      '2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      '7ED',
#      '8ED',
#      'CED',
#      'CEI',
#      'CN2',
#      'FBB',
#      'GK2',
#      'LEA',
#      'LEB',
#      'M10',
#      'M11',
#      'M12',
#      'PM11',
#      'PRM',
#      'PTC',
#      'RAV',
#      'SUM',
#      'WC00',
#      'WC01',
#      'WC02',
#      'WC98'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/9103bf4e554db164',
#      'mtgstocks': 'https://mtgjson.com/links/7345e3a1ace6b75e',
#      'tcgplayer': 'https://mtgjson.com/links/b2327bdfba5a1f75'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': '4e50454c-3927-4e7e-b4f6-7f5d5fd9b913',
#     'scryfallIllustrationId': '96b78cb9-847b-428f-a887-e330c2d9f9ee',
#     'scryfallOracleId': 'd3a0b660-358c-41bd-9cd2-41fbf3491b1a',
#     'subtypes': ['Bird'],
#     'supertypes': [],
#     'tcgplayerProductId': 8987,
#     'text': 'Flying\n{T}: Add one mana of any color.',
#     'toughness': '1',
#     'type': 'Creature — Bird',
#     'types': ['Creature'],
#     'uuid': 'd139d0ae-8a22-50cc-9e8c-77aec3b4ba72'},
#    {'artist': 'Jeff A. Menges',
#     'borderColor': 'white',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 7089,
#     'flavorText': "Battle doesn't need a purpose; the battle is its own purpose. You don't ask why a plague spreads or a field burns. Don't ask why I fight.",
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{B}{B}',
#     'mcmId': 4633,
#     'mcmMetaId': 547,
#     'mtgstocksId': 15769,
#     'multiverseId': 647,
#     'name': 'Black Knight',
#     'number': '95',
#     'originalText': 'Protection from white, first strike',
#     'originalType': 'Summon - Knight',
#     'power': '2',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 15.94,
#       '2019-08-04': 15.95,
#       '2019-08-11': 15.46,
#       '2019-08-18': 14.99,
#       '2019-08-25': 14.99,
#       '2019-09-01': 14.98,
#       '2019-09-08': 14.49,
#       '2019-09-15': 12.51,
#       '2019-09-22': 13.1,
#       '2019-09-29': 12.43,
#       '2019-10-06': 12.27,
#       '2019-10-13': 12.27,
#       '2019-10-20': 12.21},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'ATH',
#      'CED',
#      'CEI',
#      'F02',
#      'FBB',
#      'LEA',
#      'LEB',
#      'M10',
#      'M11',
#      'ME1',
#      'ME4',
#      'PRM',
#      'SUM',
#      'WC97'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/0c9da8c81658758e',
#      'mtgstocks': 'https://mtgjson.com/links/9d6e942c9180b747',
#      'tcgplayer': 'https://mtgjson.com/links/deb4666a75564b9f'},
#     'rarity': 'uncommon',
#     'rulings': [],
#     'scryfallId': '36b94d0d-fbe5-4f32-af02-bbe3ab2e234a',
#     'scryfallIllustrationId': '1d2452e5-ca1f-4c39-8977-b816d334dd21',
#     'scryfallOracleId': '9456c5b6-946d-403a-8ed0-dff9f921d98c',
#     'subtypes': ['Human', 'Knight'],
#     'supertypes': [],
#     'tcgplayerProductId': 8988,
#     'text': "First strike (This creature deals combat damage before creatures without first strike.)\nProtection from white (This creature can't be blocked, targeted, dealt damage, or enchanted by anything white.)",
#     'toughness': '2',
#     'type': 'Creature — Human Knight',
#     'types': ['Creature'],
#     'uuid': 'ac2ec642-9a2c-580c-85bd-371199903cab'},
#    {'artist': 'Christopher Rush',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 0.0,
#     'edhrecRank': 19185,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'isReserved': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Banned',
#      'duel': 'Banned',
#      'legacy': 'Banned',
#      'oldschool': 'Restricted',
#      'vintage': 'Restricted'},
#     'manaCost': '{0}',
#     'mcmId': 5093,
#     'mcmMetaId': 548,
#     'mtgstocksId': 15770,
#     'multiverseId': 600,
#     'name': 'Black Lotus',
#     'number': '233',
#     'originalText': 'Adds 3 mana of any single color of your choice to your mana pool, then is discarded. Tapping this artifact can be played as an interrupt.',
#     'originalType': 'Mono Artifact',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 7799.99,
#       '2019-08-04': 7799.99,
#       '2019-08-11': 7900.0,
#       '2019-08-18': 7900.0,
#       '2019-08-25': 7900.0,
#       '2019-09-01': 9999.95,
#       '2019-09-08': 9999.95,
#       '2019-09-15': 9999.95,
#       '2019-09-22': 17724.99,
#       '2019-09-29': 16999.0,
#       '2019-10-06': 17999.99,
#       '2019-10-13': 17724.99,
#       '2019-10-20': 17724.99},
#      'paperFoil': {}},
#     'printings': ['2ED', 'CED', 'CEI', 'LEA', 'LEB', 'OVNT', 'PRM', 'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/2dd4210fab8a8928',
#      'mtgstocks': 'https://mtgjson.com/links/cd88c74308f3372f',
#      'tcgplayer': 'https://mtgjson.com/links/03aaef0fd45d47ee'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': '4a2e428c-dd25-484c-bbc8-2d6ce10ef42c',
#     'scryfallIllustrationId': '54436824-977b-4dc7-8de1-8498e73e5ef2',
#     'scryfallOracleId': '5089ec1a-f881-4d55-af14-5d996171203b',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8989,
#     'text': '{T}, Sacrifice Black Lotus: Add three mana of any one color.',
#     'type': 'Artifact',
#     'types': ['Artifact'],
#     'uuid': '57060797-ff37-58a3-b9b3-35d74ce0e2a1'},
#    {'artist': 'Richard Thomas',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 6654,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
# ...
#       '2019-10-13': 23.99,
#       '2019-10-20': 59.0},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '9ED',
#      'A25',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/910a9a07ac393fc2',
#      'mtgstocks': 'https://mtgjson.com/links/7c9e2d1ac4e7e6a9',
#      'tcgplayer': 'https://mtgjson.com/links/85f018871cacae45'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': '73a2a070-464e-4749-87f1-2df5c8b2a93b',
#     'scryfallIllustrationId': '9d133a85-1174-477a-beae-32373e8d71ee',
#     'scryfallOracleId': '8b60fcfe-fb90-4a00-a708-25b59bfc9b5a',
#     'subtypes': ['Spirit'],
#     'supertypes': [],
#     'tcgplayerProductId': 9268,
#     'text': "Flying (This creature can't be blocked except by creatures with flying or reach.)\n{B}: Regenerate Will-o'-the-Wisp. (The next time this creature would be destroyed this turn, it isn't. Instead tap it, remove all damage from it, and remove it from combat.)",
#     'toughness': '1',
#     'type': 'Creature — Spirit',
#     'types': ['Creature'],
#     'uuid': '76047173-5828-5ec1-b424-ab99d69981c0'},
#    {'artist': 'Mark Tedin',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 645,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{2}',
#     'mcmId': 5179,
#     'mcmMetaId': 6663,
#     'mtgstocksId': 16050,
#     'multiverseId': 643,
#     'name': 'Winter Orb',
#     'number': '276',
#     'originalText': 'Players can untap only one land each during untap phase. Creatures and artifacts are untapped as normal.',
#     'originalType': 'Continuous Artifact',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 85.15,
#       '2019-08-04': 89.75,
#       '2019-08-11': 83.39,
#       '2019-08-18': 92.48,
#       '2019-08-25': 89.55,
#       '2019-09-01': 89.55,
#       '2019-09-08': 75.0,
#       '2019-09-15': 75.0,
#       '2019-09-22': 75.0,
#       '2019-09-29': 75.0,
#       '2019-10-06': 72.25,
#       '2019-10-13': 72.25,
#       '2019-10-20': 89.55},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'CED',
#      'CEI',
#      'EMA',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME1',
#      'PRM',
#      'PTC',
#      'SUM',
#      'WC97'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/184be94a113c0ca3',
#      'mtgstocks': 'https://mtgjson.com/links/dcb81c8f5ef45a89',
#      'tcgplayer': 'https://mtgjson.com/links/c738b7bf89988cc0'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2016-06-08',
#       'text': 'All permanents untap during a player’s untap step at once. If Winter Orb is tapped as your untap step begins, your lands will all untap.'},
#      {'date': '2016-06-08',
#       'text': 'You can’t tap Winter Orb just because you want to. Another ability, such as that of Glare of Subdual, must instruct or allow you to do so.'}],
#     'scryfallId': 'ee9eb598-d2ef-4b3d-8038-bc33dc5e123e',
#     'scryfallIllustrationId': '702cc171-ec95-47ff-aae4-ad80d33736d2',
#     'scryfallOracleId': '1dcbd583-3388-4b34-a7cd-131648aa6abd',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 9269,
#     'text': "As long as Winter Orb is untapped, players can't untap more than one land during their untap steps.",
#     'type': 'Artifact',
#     'types': ['Artifact'],
#     'uuid': '7cdcb328-823f-5a73-b312-df4165a1f44c'},
#    {'artist': 'Mark Tedin',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 17330,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}',
#     'mcmId': 5181,
#     'mcmMetaId': 6702,
#     'mtgstocksId': 16051,
#     'multiverseId': 644,
#     'name': 'Wooden Sphere',
#     'number': '277',
#     'originalText': 'o1: Any green spell cast by any player gives you 1 life.',
#     'originalType': 'Poly Artifact',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 1.78,
#       '2019-08-04': 1.78,
#       '2019-08-11': 1.78,
#       '2019-08-18': 1.78,
#       '2019-08-25': 2.0,
#       '2019-09-01': 2.22,
#       '2019-09-08': 2.22,
#       '2019-09-15': 2.21,
#       '2019-09-22': 2.22,
#       '2019-09-29': 2.27,
#       '2019-10-06': 3.08,
#       '2019-10-13': 2.73,
#       '2019-10-20': 2.68},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      '7ED',
#      '8ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/a42879f7b22899be',
#      'mtgstocks': 'https://mtgjson.com/links/6f48fea770cfac0b',
#      'tcgplayer': 'https://mtgjson.com/links/5730cce9a8362d31'},
#     'rarity': 'uncommon',
#     'rulings': [],
#     'scryfallId': 'fb19b35e-e0b9-4575-b146-2682ad8a5175',
#     'scryfallIllustrationId': 'b7881d13-e753-4137-820a-f5a170bda717',
#     'scryfallOracleId': '0bd8917c-bec4-4603-bc3f-8e0c2afae56a',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 9270,
#     'text': 'Whenever a player casts a green spell, you may pay {1}. If you do, you gain 1 life.',
#     'type': 'Artifact',
#     'types': ['Artifact'],
#     'uuid': '474867e4-2b63-57d6-bd16-3612a6bc3382'},
#    {'artist': 'Jesper Myrfors',
#     'borderColor': 'white',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 11724,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'isReserved': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{B}{B}',
#     'mcmId': 4717,
#     'mcmMetaId': 6709,
#     'mtgstocksId': 16052,
#     'multiverseId': 689,
#     'name': 'Word of Command',
#     'number': '137',
#     'originalText': "You may look at opponent's hand and choose any card opponent can legally play using mana from his or her mana pool or lands. Opponent must play this card immediately; you make all the decisions it calls for. This spell may not be countered after you have looked at opponent's hand.",
#     'originalType': 'Instant',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 159.99,
#       '2019-08-04': 159.99,
#       '2019-08-11': 159.99,
#       '2019-08-18': 159.99,
#       '2019-08-25': 159.99,
#       '2019-09-01': 159.99,
#       '2019-09-08': 145.34,
#       '2019-09-15': 144.25,
#       '2019-09-22': 147.89,
#       '2019-09-29': 147.89,
#       '2019-10-06': 147.89,
#       '2019-10-13': 147.89,
#       '2019-10-20': 147.89},
#      'paperFoil': {}},
#     'printings': ['2ED', 'CED', 'CEI', 'LEA', 'LEB', 'ME4'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/d348596cff5b9c69',
#      'mtgstocks': 'https://mtgjson.com/links/11ca6b6cd210c04e',
#      'tcgplayer': 'https://mtgjson.com/links/c2816cd4c92c72ba'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2004-10-04',
#       'text': 'To “play a card” is to either cast a spell or to put a land onto the battlefield using the main phase special action.'},
#      {'date': '2009-10-01',
#       'text': 'You do get to choose which lands get tapped. You can make them choose an optional mana generating ability of the land that they tap, such as making them tap and sacrifice the land instead of just tap it.'},
#      {'date': '2011-01-01',
#       'text': 'You control the player while this spell is resolving, which means you get to see anything they can see. If that player is required to search their library as part of playing the card or as part of its resolution if it’s cast as a spell, then you can see the cards in that player’s library as well.'},
#      {'date': '2011-01-01',
#       'text': 'Your opponent can’t counter the Word of Command after letting you look at their hand, but they can attempt to counter the spell you force them to cast.'},
#      {'date': '2011-01-01',
#       'text': 'You may Command your opponent to play a land (if they have not already done so this turn).'},
#      {'date': '2011-01-01',
#       'text': 'If there is a non-mana way to cast a spell, as with Pitch Spells, you may require that way to be used if it is possible to do so.'},
#      {'date': '2011-01-01',
#       'text': 'Since this spell is an instant, your opponent gets a chance to respond to it as normal. Once this spell resolves, you look at your opponent’s hand and choose a card. Note that it is common practice to respond to Word of Command by using up any spells or mana you have prior to letting it resolve.'},
#      {'date': '2011-01-01',
#       'text': 'During the resolution of this spell, that player plays the chosen card.'},
#      {'date': '2011-01-01',
#       'text': 'You must order your opponent to play the chosen card if it is possible to do so.'},
#      {'date': '2011-01-01',
#       'text': 'Word of Command can’t be used to force a player to play a card that isn’t in their hand.'},
#      {'date': '2016-07-13',
#       'text': 'While controlling another player, you can see all cards in the game that player can see. This includes cards in that player’s hand, face-down cards that player controls, and any cards in that player’s library the player may look at.'},
#      {'date': '2016-07-13',
#       'text': 'Controlling a player doesn’t allow you to look at that player’s sideboard. If an effect instructs that player to choose a card from outside the game, you can’t have that player choose any card.'}],
#     'scryfallId': '239c8547-207b-41d1-a2be-8825bfc6ef7f',
#     'scryfallIllustrationId': '58147ab5-fb67-4102-9b17-64adac0a4482',
#     'scryfallOracleId': 'e8ad3a77-b293-4d69-b080-27ca9f95d443',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 9271,
#     'text': "Look at target opponent's hand and choose a card from it. You control that player until Word of Command finishes resolving. The player plays that card if able. While doing so, the player can activate mana abilities only if they're from lands that player controls and only if mana they produce is spent to activate other mana abilities of lands the player controls and/or to play that card. If the chosen card is cast as a spell, you control the player while that spell is resolving.",
#     'type': 'Instant',
#     'types': ['Instant'],
#     'uuid': '11ad7519-8481-5fad-ac1f-8c675c36fed9'},
#    {'artist': 'Quinton Hoover',
#     'borderColor': 'white',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 4.0,
#     'edhrecRank': 100,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{2}{W}{W}',
#     'mcmId': 5087,
#     'mcmMetaId': 6734,
#     'mtgstocksId': 16053,
#     'multiverseId': 874,
#     'name': 'Wrath of God',
#     'number': '46',
#     'originalText': 'All creatures in play are destroyed and cannot regenerate.',
#     'originalType': 'Sorcery',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 75.37,
#       '2019-08-04': 80.25,
#       '2019-08-11': 75.74,
#       '2019-08-18': 89.95,
#       '2019-08-25': 89.95,
#       '2019-09-01': 89.95,
#       '2019-09-08': 89.95,
#       '2019-09-15': 89.95,
#       '2019-09-22': 89.95,
#       '2019-09-29': 89.95,
#       '2019-10-06': 89.95,
#       '2019-10-13': 89.95,
#       '2019-10-20': 89.95},
#      'paperFoil': {}},
#     'printings': ['10E',
#      '2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      '7ED',
#      '8ED',
#      '9ED',
#      'BRB',
#      'C13',
#      'CED',
#      'CEI',
#      'EMA',
#      'FBB',
#      'LEA',
#      'LEB',
#      'MP2',
#      'P07',
#      'POR',
#      'PRM',
#      'PTC',
#      'PZ1',
#      'SUM',
#      'V14',
#      'WC00',
#      'WC03',
#      'WC04'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/3b8b6c205932699b',
#      'mtgstocks': 'https://mtgjson.com/links/2df9bce929437818',
#      'tcgplayer': 'https://mtgjson.com/links/4bd8de3d04560b7d'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': 'e57404bc-44ba-4909-87da-f4a71673168d',
#     'scryfallIllustrationId': 'e87a70b0-4485-4362-9a1d-7c320cd7755e',
#     'scryfallOracleId': '34515b16-c9a4-4f98-8c77-416a7a523407',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 9272,
#     'text': "Destroy all creatures. They can't be regenerated.",
#     'type': 'Sorcery',
#     'types': ['Sorcery'],
#     'uuid': '5b6a0bd0-1470-5060-a79a-9269380a64b5'},
#    {'artist': 'Jeff A. Menges',
#     'borderColor': 'white',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'convertedManaCost': 3.0,
#     'edhrecRank': 2067,
#     'flavorText': 'They say the Zombie Master controlled these foul creatures even before his own death, but now that he is one of them, nothing can make them betray him.',
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}{B}{B}',
#     'mcmId': 4719,
#     'mcmMetaId': 6821,
#     'mtgstocksId': 16054,
#     'multiverseId': 690,
#     'name': 'Zombie Master',
#     'number': '138',
#     'originalText': 'All zombies in play gain swampwalk and "ooB Regenerates" for as long as this card remains in play.',
#     'originalType': 'Summon - Lord',
#     'power': '2',
#     'prices': {'mtgo': {},
#      'mtgoFoil': {},
#      'paper': {'2019-07-28': 34.89,
#       '2019-08-04': 34.94,
#       '2019-08-11': 34.94,
#       '2019-08-18': 33.19,
#       '2019-08-25': 34.99,
#       '2019-09-01': 34.94,
#       '2019-09-08': 34.94,
#       '2019-09-15': 34.99,
#       '2019-09-22': 34.07,
#       '2019-09-29': 33.24,
#       '2019-10-06': 34.89,
#       '2019-10-13': 31.62,
#       '2019-10-20': 33.24},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME4',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/095f3e87bbec7a48',
#      'mtgstocks': 'https://mtgjson.com/links/d64f95ae430f9ff3',
#      'tcgplayer': 'https://mtgjson.com/links/0efb4e0fb40a77b2'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': 'd9b2accc-11e8-4bfd-97fc-d2f6bcd94c26',
#     'scryfallIllustrationId': '7441c48a-ca5a-415c-ad9d-2839e6e47f5b',
#     'scryfallOracleId': '5446c92f-ff22-4e9b-a2f6-e64c8560c1e0',
#     'subtypes': ['Zombie'],
#     'supertypes': [],
#     'tcgplayerProductId': 9273,
#     'text': 'Other Zombie creatures have swampwalk. (They can\'t be blocked as long as defending player controls a Swamp.)\nOther Zombies have "{B}: Regenerate this permanent."',
#     'toughness': '3',
#     'type': 'Creature — Zombie',
#     'types': ['Creature'],
#     'uuid': '8978d0f2-f50a-536f-84f7-4a4bc23d4524'}],
#   'code': '2ED',
#   'isFoilOnly': False,
#   'isOnlineOnly': False,
#   'keyruneCode': '2ED',
#   'mcmId': 3,
#   'mcmName': 'Unlimited',
#   'meta': {'date': '2019-11-03',
#    'pricesDate': '2019-11-03',
#    'version': '4.6.0+20191103'},
#   'name': 'Unlimited Edition',
#   'releaseDate': '1993-12-01',
#   'tcgplayerGroupId': 115,
#   'tokens': [],
#   'totalSetSize': 302,
#   'type': 'core'})

# %%
# code to see how many observations there are in mtg_archive_clean
len(list(mtg_archive_clean))
# Out:
# 460

# %% [markdown]
# ### Assessment

# %% [markdown]
# - need tcg player urls
# - need a name list

# %% [markdown]
# ## Clean

# %% [markdown]
# ### Define
# - write a loop that pulls out names and tcg player purchase url

# %% [markdown]
# ### Code

# %%
# loop that pulls out names and tcg player purchase url
tcg_player_card_urls = []
set_names = mtg_archive_clean.keys()
tcg_names = []
card_errors = []
for i in set_names:
    set_cards = mtg_archive_clean[i].get('cards')
    set_length = np.count_nonzero(mtg_archive_clean[i]['cards'])
    for a in np.arange(set_length):
        tcg_player_card_urls.append(set_cards[a].get('purchaseUrls')['tcgplayer'])
        tcg_names.append(set_cards[a]['name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-8d7670114145> in <module>
#       8     set_length = np.count_nonzero(mtg_archive_clean[i]['cards'])
#       9     for a in np.arange(set_length):
# ---> 10         tcg_player_card_urls.append(set_cards[a].get('purchaseUrls')['tcgplayer'])
#      11         tcg_names.append(set_cards[a]['name'])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
mtg_archive_clean['10E']['cards'][0].get('purchaseUrls')
# Out:
# {'cardmarket': 'https://mtgjson.com/links/2b93f05911c57179',
#  'mtgstocks': 'https://mtgjson.com/links/34f62da2f8c3ee65',
#  'tcgplayer': 'https://mtgjson.com/links/f4690a893091ee2d'}

# %% [markdown]
# ### Test

# %%
len(list(mtg_archive_clean['10E'].items()))
# Out:
# 18

# %%
np.count_nonzero(tcg_player_card_urls), np.count_nonzero(tcg_player_card_urls)
# Out:
# (0, 0)

# %%
tcg_names[0], tcg_player_card_urls[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-38eedc8f59cd> in <module>
# ----> 1 tcg_names[0], tcg_player_card_urls[0]
#
# IndexError: list index out of range

# %% [markdown]
# ### Define
# - combine names with urls to make tcg_cards

# %% [markdown]
# ### Code

# %%
# code to make a dataframe of the two tcg columns to make tcg_names dataframe
tcg_names = pd.DataFrame(data={'name': tcg_names})
tcg_names['url'] = tcg_player_card_urls

# %% [markdown]
# ### Test

# %%
tcg_names.head()

# %% [markdown]
# ### Define
# - get all the names and rarities

# %% [markdown]
# ### Code

# %%
mtg_rarities = pd.DataFrame(name = [], 
                            rarity = [])

for i in mtg_archive_clean.keys():
    names = mtg_archive_clean[i]['name']
    rarities = mtg_archive_clean[i]['rarity']

# %% [markdown]
# # standard_sets

# %% [markdown]
# ## Gather

# %%
# pull standard cards from mtgjson
standard_sets = requests.get('https://www.mtgjson.com/json/Standard.json')
standard_sets_clean = standard_sets.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-16-0ef8e2cffaaa> in <module>
#       1 # pull standard cards from mtgjson
#       2 standard_sets = requests.get('https://www.mtgjson.com/json/Standard.json')
# ----> 3 standard_sets_clean = standard_sets.json()
#
# ~\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# code to save standard_sets as a json file 
with open('standard_sets_clean.txt', 'w') as outfile:
    json.dump(standard_sets_clean, outfile)

# %%
# code to load standard_sets_clean
with open('standard_sets_clean.txt', encoding='utf-8') as file:
    standard_sets_clean = json.load(file)

# %% [markdown]
# ## Assess

# %%
list(standard_cards_clean.items())[3]

# %%
standard_sets_clean['ELD']['cards'][1]['rarity']

# %% [markdown]
# ### Assessment
# - need names and rarity of the card in one dataset

# %% [markdown]
# ## Clean

# %% [markdown]
# ### Define
# - use pandas to tidy the data by making it a dataframe with only two variables: name and rarity

# %% [markdown]
# ### Code

# %%
# code to get rarity in a list by themselves
card_rarities = []
for i in standard_sets_clean.keys():
    current_set = standard_sets_clean[i]['cards']
    for a in np.arange(np.count_nonzero(current_set)):
        rarity = current_set[a]['rarity']
        card_rarities.append(rarity)

# %%
# code to get names in a list by themselves
card_names = []
for i in standard_sets_clean.keys():
    current_set = standard_sets_clean[i]['cards']
    for a in np.arange(np.count_nonzero(current_set)):
        name = current_set[a]['name']
        card_names.append(name)

# %%
# code to create dataframe of card_rarities and card_names
mtg_card_rarities = pd.DataFrame({'name': card_names, 'rarity': card_rarities})
mtg_card_rarities_clean = mtg_card_rarities.copy()
mtg_card_rarities_clean.to_csv('mtg_card_rarities_clean.csv', index=False)

# %% [markdown]
# ### Test

# %%
card_rarities

# %%
card_names

# %%
np.count_nonzero(card_rarities), np.count_nonzero(card_names)

# %%
mtg_card_rarities_clean

# %%
mtg_card_rarities_clean = pd.read_csv('mtg_card_rarities_clean.csv')

# %% [markdown]
# ### Define
# - drop duplicates

# %% [markdown]
# ### Code

# %%
# drop duplicates in mtg_card_rarities_clean
mtg_card_rarities_clean.drop_duplicates(inplace=True)

# %%
mtg_card_rarities_clean.to_csv('mtg_card_rarities_clean.csv', index=False)

# %% [markdown]
# ### Test

# %%
mtg_card_rarities_clean.duplicated().sum()

# %%
mtg_card_rarities_clean = pd.read_csv('mtg_card_rarities_clean.csv')
print(mtg_card_rarities_clean)

# %% [markdown]
# # deck_type_urls

# %% [markdown]
# ## Gather

# %%
# make a webcrawler to gather the data from mtgtop8.com on competitive decks
url = 'https://www.mtgtop8.com/format?f=ST'
url_standard_page_response = requests.get(url)

# %%
# save the response
with open('url_standard_page_response.html', mode='wb') as file:
    file.write(url_standard_page_response.content)

# %%
# open response as a BeautifulSoup object
with open('url_standard_page_response.html') as file:
    soup = BeautifulSoup(file, 'lxml')

# %%
url = {'url': soup.find_all(href=re.compile(r"archetype\?a"))}
deck_type_urls = pd.DataFrame(data=url)

# %%
# create column for deck type and clean the column
deck_type_urls.url = deck_type_urls.url.astype('str')
deck_type_urls['type'] = deck_type_urls.url.str.extract('(>.+<)')
deck_type_urls['type'] = deck_type_urls.type.str.replace('>', '')
deck_type_urls['type'] = deck_type_urls.type.str.replace('<', '')
deck_type_urls['type'] = deck_type_urls.type.str.strip()
url_stripper(deck_type_urls['type'], deck_type_urls['url'], '(>.+<)')

# %%
# extract url from the url column
deck_type_urls['url'] = deck_type_urls.url.str.extract('(archetype.+f\=ST)')

# %%
# add root url to the data
urls = []
types = []

for i in np.arange(deck_type_urls.shape[0]):
    urls.append(str('https://www.mtgtop8.com/') + deck_type_urls.url[i])
    types.append(deck_type_urls.type[i] + str('.html'))

# %%
deck_type_urls['url'] = urls
deck_type_urls['type'] = types
deck_type_urls['type'] = deck_type_urls.type.str.replace(' ', '_')
deck_type_urls['type'] = deck_type_urls.type.str.replace('/', '-')

# %%
# create web crawler to request html pages from deck_type_urls

# create new path and name it newpath
newpath = str(os.path.abspath(os.curdir)) + '\\type_html_files'

# check to make sure that there is no path that matches newpath and create a folder called html_files if there isn't
if not os.path.exists(newpath):
    os.makedirs(newpath)

# change current directory to newpath
os.chdir(newpath)

# scrape all html files from urls in deck_type_urls and put them in html_files folder
for i in np.arange(deck_type_urls.shape[0]):
    type_html = requests.get(deck_type_urls.url[i])
    with open(deck_type_urls.type[i], 'wb') as file:
        file.write(type_html.content)

# %% [markdown]
# # deck_urls

# %% [markdown]
# ## Gather

# %%
# get a list of file names in html_files folder and name it dir_names
dir_names = []
cur_dir = os.path.abspath(os.curdir)

with os.scandir(cur_dir) as folder:
    for file in folder: 
        if file.is_file():
            dir_names.append(file.name)

# %%
# get a list of all urls in all files
deck_urls = []
for i in np.arange(np.count_nonzero(dir_names)):
    with open(dir_names[i]) as file:
        soup = BeautifulSoup(file, 'lxml')
    urls = soup.find_all(href=re.compile(r'event\?e\=.+\&d\=.+\&f\=ST'))
    for a in urls:
        deck_urls.append(a)

# %%
# get a list of all player names in all files
player_names = []
for i in np.arange(np.count_nonzero(dir_names)):
    with open(dir_names[i]) as file:
        soup = BeautifulSoup(file, 'lxml')
    urls = soup.find_all(href=re.compile(r'search\?player'))
    for a in urls:
        player_names.append(a)

# %%
# turn deck urls into a dataframe
deck_urls = {'url': deck_urls}
deck_urls = pd.DataFrame(data=deck_urls)

# %%
# get deck names and clean them up
deck_urls.url = deck_urls.url.astype('str')
deck_urls['name'] = deck_urls.url.str.extract('(>.+<)')
deck_urls.name = deck_urls.name.str.replace('>', '')
deck_urls.name = deck_urls.name.str.replace('<', '')
deck_urls.name = deck_urls.name.str.strip()
url_stripper(deck_urls['url'], deck_url['name'], '(>.+<)')

# %%
# extract url from the url column
deck_urls['url'] = deck_urls.url.str.extract('(event.+f\=ST)')

# %%
# add root url to the data
urls = []
names = []

for i in np.arange(deck_urls.shape[0]):
    urls.append(str('https://www.mtgtop8.com/') + deck_urls.url[i])
    names.append(deck_urls.name[i] + str('.html'))

# %%
# clean urls and name
deck_urls['url'] = urls
deck_urls['name'] = names
deck_urls['name'] = deck_urls.name.str.replace(' ', '_')
deck_urls['name'] = deck_urls.name.str.replace('/', '-')

# %%
# append player_names to deck_urls
deck_urls['player_name'] = player_names
deck_urls.player_name = deck_urls.player_name.str.extract('(>.+<)')
deck_urls.player_name = deck_urls.player_name.str.replace('>', '')
deck_urls.player_name = deck_urls.player_name.str.replace('<', '')
deck_urls.player_name = deck_urls.player_name.str.strip()
url_stripper(deck_urls['player_name'], deck_urls['player_name'], '(>.+<)')

# %% [markdown]
# ## decks

# %%
# create a web crawler to request html pages from deck_type_urls

# create a new path and name it newpath
oldpath = str(os.path.abspath(os.curdir))
newpath = oldpath.replace('\\type_html_files', '\\deck_html_files')

# check to make sure that there is no path that matches newpath and create a folder called html_files if there isn't
if not os.path.exists(newpath):
    os.makedirs(newpath)

# change the current directory to newpath
os.chdir(newpath)

# scrape all html files from urls in deck_urls and put them in html_files folder
deck_errors = []

for i in np.arange(deck_urls.shape[0]):
    try:
        if filecmp.cmp(deck_urls.name[i]) == True:
            deck_html = requests.get(deck_urls.url[i])
            with open(deck_urls.name[i], 'wb') as file:
                file.write(deck_html.content)
        else:
            deck_html = requests.get(deck_urls.url[i])
            with open(deck_urls.name[i] + str(i))
    except Exception as e:
        print(str(i) + ' ' + str(e))
        deck_errors.append(i)

# %%
filecmp.cmp(deck_urls.name[1], deck_urls.name[2])

# %%
os.path.abspath(os.curdir)

# %%
os.chdir('C:\\Users\\muroc\\Documents\\MTG\\type_html_files')
