# %%
# Load all packages necessary for analysis
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json
import re
import os
import timeit

# %% [markdown]
# # mtg_archive

# %% [markdown]
# ## Gather

# %%
mtg_card_rarities_clean = pd.read_csv('mtg_card_rarities_clean.csv')

# %%
# Code to create a function to see if url leads to a file that can be downloaded
def is_downloadable(url):
    """
    Does the url contain a downloadable resource
    """
    h = requests.head(url, allow_redirects=True)
    header = h.headers
    content_type = header.get('content-type')
    if 'text' in content_type.lower():
        return False
    if 'html' in content_type.lower():
        return False
    return True

# %%
# code to see if url is downloadable
print(is_downloadable('https://www.mtgjson.com/json/AllSets.json'))
# Out:
# True

# %%
# code to download data as a response object and make it into a json object
mtg_archive = requests.get('https://www.mtgjson.com/json/AllSets.json')
mtg_archive_clean = mtg_archive.json()

# %%
# code to save mtg_archive_clean as a json file
with open('mtg_archive.txt', 'w') as outfile: 
    json.dump(mtg_archive_clean, outfile)

# %%
# code to load all cards data
with open('mtg_archive.txt', encoding='utf-8') as file:
    mtg_archive_clean = json.load(file)

# %% [markdown]
# ## Assess

# %%
# code to assess the type of mtg_archive_clean
type(mtg_archive_clean)
# Out:
# dict

# %%
# code to get the 40th element from mtg_archive_clean as a list
list(mtg_archive_clean.items())[1]
# Out:
# ('2ED',
#  {'baseSetSize': 302,
#   'block': 'Core Set',
#   'boosterV3': ['rare',
#    'uncommon',
#    'uncommon',
#    'uncommon',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common'],
#   'cards': [{'artist': 'Richard Thomas',
#     'borderColor': 'white',
#     'colorIdentity': ['U'],
#     'colors': ['U'],
#     'convertedManaCost': 5.0,
#     'edhrecRank': 11987,
#     'flavorText': 'These spirits of the air are winsome and wild, and cannot be truly contained. Only marginally intelligent, they often substitute whimsy for strategy, delighting in mischief and mayhem.',
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'brawl': 'Legal',
#      'commander': 'Legal',
#      'duel': 'Legal',
#      'future': 'Legal',
#      'historic': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'standard': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{3}{U}{U}',
#     'mcmId': 4721,
#     'mcmMetaId': 81,
#     'mtgstocksId': 15753,
#     'multiverseId': 691,
#     'name': 'Air Elemental',
#     'number': '47',
#     'originalText': 'Flying',
#     'originalType': 'Summon - Elemental',
#     'power': '4',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 3.47,
#       '2019-07-21': 3.47,
#       '2019-07-28': 3.05,
#       '2019-08-04': 3.27,
#       '2019-08-11': 4.0,
#       '2019-08-18': 3.56,
#       '2019-08-25': 3.53,
#       '2019-09-01': 3.72,
#       '2019-09-08': 3.65,
#       '2019-09-15': 3.65,
#       '2019-09-22': 3.56,
#       '2019-09-29': 3.65,
#       '2019-10-06': 3.87},
#      'paperFoil': {}},
#     'printings': ['10E',
#      '2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      '7ED',
#      '8ED',
#      '9ED',
#      'BRB',
#      'BTD',
#      'CED',
#      'CEI',
#      'DD2',
#      'DPA',
#      'FBB',
#      'GNT',
#      'JVC',
#      'LEA',
#      'LEB',
#      'M10',
#      'M19',
#      'M20',
#      'ME4',
#      'P02',
#      'PS11',
#      'S99',
#      'SUM',
#      'W17',
#      'XLN'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/da7ee1a891c6dc07',
#      'mtgstocks': 'https://mtgjson.com/links/198ec7d5b2cbfe88',
#      'tcgplayer': 'https://mtgjson.com/links/3fa7c8121f5ff069'},
#     'rarity': 'uncommon',
#     'rulings': [],
#     'scryfallId': 'ef5b8140-a157-4c20-a428-fa7250ab34e1',
#     'scryfallIllustrationId': '67f66b28-3ee8-4ce0-a184-cb3d7c8fdb4f',
#     'scryfallOracleId': '7744bae4-a8b7-44a5-9b4c-0048ad4cc448',
#     'subtypes': ['Elemental'],
#     'supertypes': [],
#     'tcgplayerProductId': 8972,
#     'text': 'Flying',
#     'toughness': '4',
#     'type': 'Creature — Elemental',
#     'types': ['Creature'],
#     'uuid': '09c8f87f-aef0-56bf-861d-dae4b974a6e6'},
#    {'artist': 'Mark Poole',
#     'borderColor': 'white',
#     'colorIdentity': ['U'],
#     'colors': ['U'],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 17400,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'isReserved': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Banned',
#      'duel': 'Banned',
#      'legacy': 'Banned',
#      'oldschool': 'Restricted',
#      'vintage': 'Restricted'},
#     'manaCost': '{U}',
#     'mcmId': 4723,
#     'mcmMetaId': 161,
#     'mtgstocksId': 15754,
#     'multiverseId': 692,
#     'name': 'Ancestral Recall',
#     'number': '48',
#     'originalText': 'Draw 3 cards or force opponent to draw 3 cards.',
#     'originalType': 'Instant',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 2768.33,
#       '2019-07-21': 2768.33,
#       '2019-07-28': 2768.33,
#       '2019-08-04': 2768.33,
#       '2019-08-11': 2768.33,
#       '2019-08-18': 2768.33,
#       '2019-08-25': 2999.0,
#       '2019-09-01': 2999.0,
#       '2019-09-08': 2999.0,
#       '2019-09-15': 2999.0,
#       '2019-09-22': 2999.0,
#       '2019-09-29': 2999.0,
#       '2019-10-06': 2999.0},
#      'paperFoil': {}},
#     'printings': ['2ED', 'CED', 'CEI', 'LEA', 'LEB', 'OVNT', 'PRM', 'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/27ea4b196fba7c90',
#      'mtgstocks': 'https://mtgjson.com/links/4067a685624dbe6a',
#      'tcgplayer': 'https://mtgjson.com/links/d630d3deb695e147'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': '2dd41293-d7c8-4422-9f0c-b3e96350f5c9',
#     'scryfallIllustrationId': 'd20eda7b-a902-4c00-bdab-601059e417b5',
#     'scryfallOracleId': '550c74d4-1fcb-406a-b02a-639a760a4380',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8973,
#     'text': 'Target player draws three cards.',
#     'type': 'Instant',
#     'types': ['Instant'],
#     'uuid': 'e1a727f8-1653-5adc-b37b-35b444777cf6'},
#    {'artist': 'Douglas Shuler',
#     'borderColor': 'white',
#     'colorIdentity': ['U'],
#     'colors': ['U'],
#     'convertedManaCost': 4.0,
#     'edhrecRank': 16744,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{3}{U}',
#     'mcmId': 4725,
#     'mcmMetaId': 199,
#     'mtgstocksId': 15755,
#     'multiverseId': 693,
#     'name': 'Animate Artifact',
#     'number': '49',
#     'originalText': 'Target artifact is now a creature with both power and toughness equal to its casting cost; target retains all its original abilities as well. This will destroy artifacts with 0 casting cost.',
#     'originalType': 'Enchant Non-Creature Artifact',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 1.83,
#       '2019-07-21': 1.8,
#       '2019-07-28': 1.9,
#       '2019-08-04': 1.96,
#       '2019-08-11': 1.88,
#       '2019-08-18': 1.78,
#       '2019-08-25': 1.75,
#       '2019-09-01': 1.8,
#       '2019-09-08': 1.8,
#       '2019-09-15': 1.8,
#       '2019-09-22': 1.8,
#       '2019-09-29': 1.96,
#       '2019-10-06': 1.99},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME4',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/0987754305cff412',
#      'mtgstocks': 'https://mtgjson.com/links/f86dc7d07275b383',
#      'tcgplayer': 'https://mtgjson.com/links/51f857a7090afad9'},
#     'rarity': 'uncommon',
#     'rulings': [{'date': '2008-08-01',
#       'text': 'This card has been returned to its original functionality. If it is enchanting an artifact that’s already a creature, it won’t change its power and toughness.'},
#      {'date': '2008-08-01',
#       'text': 'A noncreature permanent that turns into a creature can attack, and its {T} abilities can be activated, only if its controller has continuously controlled that permanent since the beginning of their most recent turn. It doesn’t matter how long the permanent has been a creature.'}],
#     'scryfallId': 'caf1ee51-2852-44c0-a5d4-d0e415381738',
#     'scryfallIllustrationId': '3c8723a8-4f77-491b-9d6b-7ee13e08edb6',
#     'scryfallOracleId': '2dd7a4dc-902a-4e85-8a3b-c96a898fba86',
#     'subtypes': ['Aura'],
#     'supertypes': [],
#     'tcgplayerProductId': 8974,
#     'text': "Enchant artifact\nAs long as enchanted artifact isn't a creature, it's an artifact creature with power and toughness each equal to its converted mana cost.",
#     'type': 'Enchantment — Aura',
#     'types': ['Enchantment'],
#     'uuid': 'ff4f7f41-4612-52a4-94d3-d985e52d047a'},
#    {'artist': 'Anson Maddocks',
#     'borderColor': 'white',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 153,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}{B}',
#     'mcmId': 4629,
#     'mcmMetaId': 200,
#     'mtgstocksId': 15756,
#     'multiverseId': 645,
#     'name': 'Animate Dead',
#     'number': '93',
#     'originalText': "Any creature in either player's graveyard comes into play on your side with -1 to its original power. If this enchantment is removed, or at end of game, target creature is returned to its owner's graveyard. Target creature may be killed as normal.",
#     'originalType': 'Enchant Dead Creature',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 12.63,
#       '2019-07-21': 12.99,
#       '2019-07-28': 13.99,
#       '2019-08-04': 13.99,
#       '2019-08-11': 13.99,
#       '2019-08-18': 13.85,
#       '2019-08-25': 13.76,
#       '2019-09-01': 14.49,
#       '2019-09-08': 14.24,
#       '2019-09-15': 14.49,
#       '2019-09-22': 13.99,
#       '2019-09-29': 14.22,
#       '2019-10-06': 14.55},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'CED',
#      'CEI',
#      'EMA',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME1',
#      'PD3',
#      'SUM',
#      'TD0',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/a035a920d38839f7',
#      'mtgstocks': 'https://mtgjson.com/links/211d75d773ab60fd',
#      'tcgplayer': 'https://mtgjson.com/links/5c29bb6d691728a1'},
#     'rarity': 'uncommon',
#     'rulings': [{'date': '2016-06-08',
#       'text': 'Animate Dead is an Aura, albeit with an unusual enchant ability. You target a creature card in a graveyard when you cast it. It enters the battlefield attached to that card. Then it returns that card to the battlefield, and attaches itself to the card again (since the card is a new object on the battlefield). Animate Dead itself never moves into a graveyard during this process.'},
#      {'date': '2016-06-08',
#       'text': 'If Animate Dead isn’t on the battlefield as its triggered ability resolves, none of its effects happen. The creature card won’t be returned to the battlefield.'},
#      {'date': '2016-06-08',
#       'text': 'Abilities such as shroud and protection function only on the battlefield unless otherwise specified. A creature card with shroud may be targeted by Animate Dead, and Animate Dead will become attached to the creature that enters the battlefield.'},
#      {'date': '2016-06-08',
#       'text': 'If the creature put onto the battlefield has protection from black—or if the creature can’t legally be enchanted by Animate Dead for another reason—Animate Dead won’t be able to attach to it. It will be put into the graveyard as a state-based action, causing its delayed triggered ability to trigger. When the trigger resolves, if the creature’s still on the battlefield, its controller will sacrifice it.'},
#      {'date': '2016-06-08',
#       'text': 'Once the creature is returned to the battlefield, Animate Dead can’t be attached to anything other than it (unless Animate Dead somehow manages to put a different creature onto the battlefield). Attempting to move Animate Dead to another creature won’t work.'}],
#     'scryfallId': '0fc3ed63-96ee-420c-bde1-e0c904059931',
#     'scryfallIllustrationId': 'b19cb181-a679-4d68-b2cd-e0a809de03bc',
#     'scryfallOracleId': 'c0d8fef4-65f4-4769-982d-b397d2b7e977',
#     'subtypes': ['Aura'],
#     'supertypes': [],
#     'tcgplayerProductId': 8975,
#     'text': 'Enchant creature card in a graveyard\nWhen Animate Dead enters the battlefield, if it\'s on the battlefield, it loses "enchant creature card in a graveyard" and gains "enchant creature put onto the battlefield with Animate Dead." Return enchanted creature card to the battlefield under your control and attach Animate Dead to it. When Animate Dead leaves the battlefield, that creature\'s controller sacrifices it.\nEnchanted creature gets -1/-0.',
#     'type': 'Enchantment — Aura',
#     'types': ['Enchantment'],
#     'uuid': '810ceb8f-66ae-5fee-8033-fad5aaf0d25a'},
#    {'artist': 'Dan Frazier',
#     'borderColor': 'white',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 10355,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{W}',
#     'mcmId': 4997,
#     'mcmMetaId': 202,
#     'mtgstocksId': 15757,
#     'multiverseId': 829,
#     'name': 'Animate Wall',
#     'number': '1',
#     'originalText': "Target wall can now attack. Target wall's power and toughness are unchanged, even if its power is 0.",
#     'originalType': 'Enchant Wall',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 11.98,
#       '2019-07-21': 11.98,
#       '2019-07-28': 11.98,
#       '2019-08-04': 11.98,
#       '2019-08-11': 11.98,
#       '2019-08-18': 11.99,
#       '2019-08-25': 11.98,
#       '2019-09-01': 12.0,
#       '2019-09-08': 14.44,
#       '2019-09-15': 14.8,
#       '2019-09-22': 14.89,
#       '2019-09-29': 17.9,
#       '2019-10-06': 18.0},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME1',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/7e422871372e3867',
#      'mtgstocks': 'https://mtgjson.com/links/e638770374d66ca1',
#      'tcgplayer': 'https://mtgjson.com/links/d45b49a5c408c3a5'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2007-09-16',
#       'text': 'This is a change from the most recent wording. As was the case in the past, Animate Wall can now enchant only a Wall.'}],
#     'scryfallId': '05d7bed4-950a-4a4e-b79a-50e4aa416fe9',
#     'scryfallIllustrationId': '6757e04d-7bfc-4bdc-9dcb-02059a2d4e60',
#     'scryfallOracleId': 'c7a6a165-b709-46e0-ae42-6f69a17c0621',
#     'subtypes': ['Aura'],
#     'supertypes': [],
#     'tcgplayerProductId': 8976,
#     'text': "Enchant Wall\nEnchanted Wall can attack as though it didn't have defender.",
#     'type': 'Enchantment — Aura',
#     'types': ['Enchantment'],
#     'uuid': '4ba51671-c7be-5196-a211-aaa0cc33c5b7'},
#    {'artist': 'Amy Weber',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 3171,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{2}',
#     'mcmId': 5089,
#     'mcmMetaId': 203,
#     'mtgstocksId': 15758,
#     'multiverseId': 598,
#     'name': 'Ankh of Mishra',
#     'number': '231',
#     'originalText': 'Ankh does 2 damage to anyone who puts a new land into play.',
#     'originalType': 'Continuous Artifact',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 51.13,
#       '2019-07-21': 51.13,
#       '2019-07-28': 57.25,
#       '2019-08-04': 68.14,
#       '2019-08-11': 69.99,
#       '2019-08-18': 62.99,
#       '2019-08-25': 65.98,
#       '2019-09-01': 61.23,
#       '2019-09-08': 61.21,
#       '2019-09-15': 61.21,
#       '2019-09-22': 59.48,
#       '2019-09-29': 52.46,
#       '2019-10-06': 61.21},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME1',
#      'SUM',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/c77c2c6308a6a3cc',
#      'mtgstocks': 'https://mtgjson.com/links/b5a993d53cd2975d',
#      'tcgplayer': 'https://mtgjson.com/links/3309e3883ea9bcc8'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2004-10-04',
#       'text': 'This triggers on any land entering the battlefield. This includes playing a land or putting a land onto the battlefield using a spell or ability.'},
#      {'date': '2004-10-04',
#       'text': 'It determines the land’s controller at the time the ability resolves. If the land leaves the battlefield before the ability resolves, the land’s last controller before it left is used.'}],
#     'scryfallId': '808cad10-69d5-4e14-9834-476c53ec97e4',
#     'scryfallIllustrationId': 'f6b4406b-9216-4a41-b637-13a77b078ab9',
#     'scryfallOracleId': '63c1eda1-3e6f-4e9c-adf3-a43164df98bb',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8977,
#     'text': "Whenever a land enters the battlefield, Ankh of Mishra deals 2 damage to that land's controller.",
#     'type': 'Artifact',
#     'types': ['Artifact'],
#     'uuid': 'df3fc42f-2a53-575e-90b9-b7821d20bf92'},
#    {'artist': 'Jesper Myrfors',
#     'borderColor': 'white',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 4.0,
#     'edhrecRank': 893,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{3}{W}',
#     'mcmId': 4999,
#     'mcmMetaId': 283,
#     'mtgstocksId': 15759,
#     'multiverseId': 830,
#     'name': 'Armageddon',
#     'number': '2',
#     'originalText': 'All lands in play are destroyed.',
#     'originalType': 'Sorcery',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 98.59,
#       '2019-07-21': 99.3,
#       '2019-07-28': 94.29,
#       '2019-08-04': 89.99,
#       '2019-08-11': 89.99,
#       '2019-08-18': 89.99,
#       '2019-08-25': 89.98,
#       '2019-09-01': 89.99,
#       '2019-09-08': 89.98,
#       '2019-09-15': 89.98,
#       '2019-09-22': 87.0,
#       '2019-09-29': 87.0,
#       '2019-10-06': 85.0},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      'A25',
#      'ATH',
#      'CED',
#      'CEI',
#      'FBB',
#      'G04',
#      'LEA',
#      'LEB',
#      'ME1',
#      'ME4',
#      'MP2',
#      'P02',
#      'POR',
#      'PRM',
#      'PTC',
#      'S99',
#      'SUM',
#      'V14',
#      'VMA',
#      'WC00',
#      'WC98'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/a02da8ecf0dda549',
#      'mtgstocks': 'https://mtgjson.com/links/50b606c26f466ba7',
#      'tcgplayer': 'https://mtgjson.com/links/6e0fa02a857e9126'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': 'df2c5d5c-f1c9-4639-bf72-3f6bde554864',
#     'scryfallIllustrationId': 'be2ceead-1cc4-4e3b-8b0d-bb7010b91312',
#     'scryfallOracleId': 'c9ed8b01-959a-47d6-891e-0abbdccf6e4f',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8978,
#     'text': 'Destroy all lands.',
#     'type': 'Sorcery',
#     'types': ['Sorcery'],
#     'uuid': 'd0b5920c-ee6f-5211-9bc5-eb18838b6d32'},
#    {'artist': 'Jeff A. Menges',
#     'borderColor': 'white',
#     'colorIdentity': ['G'],
#     'colors': ['G'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 11596,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}{G}',
#     'mcmId': 4813,
#     'mcmMetaId': 320,
#     'mtgstocksId': 15760,
#     'multiverseId': 737,
#     'name': 'Aspect of Wolf',
#     'number': '185',
#     'originalText': "Target creature's power and toughness are increased by half the number of forests you have in play, rounding down for power and up for toughness.",
#     'originalType': 'Enchant Creature',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 17.2,
#       '2019-07-21': 10.69,
#       '2019-07-28': 10.0,
#       '2019-08-04': 10.0,
#       '2019-08-11': 11.38,
#       '2019-08-18': 11.38,
#       '2019-08-25': 10.0,
#       '2019-09-01': 9.98,
#       '2019-09-08': 13.5,
#       '2019-09-15': 9.74,
#       '2019-09-22': 9.05,
#       '2019-09-29': 9.09,
#       '2019-10-06': 9.98},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'PZ2',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/8e2d8f31e995a2d5',
#      'mtgstocks': 'https://mtgjson.com/links/1e75a5eb2eaebfce',
#      'tcgplayer': 'https://mtgjson.com/links/d8fe6b9b76a029c1'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2009-10-01',
#       'text': 'The effect is continuously updated based on the number of Forests you control at any given time.'}],
#     'scryfallId': '5aa02bb5-7365-4b8d-ac86-13721fb19d01',
#     'scryfallIllustrationId': 'e31bc7be-9082-475c-9fb6-7336354ad1e2',
#     'scryfallOracleId': '77b7277d-90a1-4774-a998-8c35c3f94e4a',
#     'subtypes': ['Aura'],
#     'supertypes': [],
#     'tcgplayerProductId': 8979,
#     'text': 'Enchant creature\nEnchanted creature gets +X/+Y, where X is half the number of Forests you control, rounded down, and Y is half the number of Forests you control, rounded up.',
#     'type': 'Enchantment — Aura',
#     'types': ['Enchantment'],
#     'uuid': '7277d11a-2476-52f8-8cfc-638c82aa987c'},
#    {'artist': 'Jesper Myrfors',
#     'borderColor': 'white',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 3858,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}{B}',
#     'mcmId': 4631,
#     'mcmMetaId': 405,
#     'mtgstocksId': 15761,
#     'multiverseId': 646,
#     'name': 'Bad Moon',
#     'number': '94',
#     'originalText': 'All black creatures in play gain +1/+1.',
#     'originalType': 'Enchantment',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 22.99,
#       '2019-07-21': 89.0,
#       '2019-07-28': 89.0,
#       '2019-08-04': 89.0,
#       '2019-08-11': 88.98,
#       '2019-08-18': 98.95,
#       '2019-08-25': 31.98,
#       '2019-09-01': 31.98,
#       '2019-09-08': 29.95,
#       '2019-09-15': 26.4,
#       '2019-09-22': 22.85,
#       '2019-09-29': 21.93,
#       '2019-10-06': 21.89},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'C14',
#      'CED',
#      'CEI',
#      'DDD',
#      'FBB',
#      'GVL',
#      'LEA',
#      'LEB',
#      'SUM',
#      'TSB'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/7f9b31c821322880',
#      'mtgstocks': 'https://mtgjson.com/links/d9db501bfca5a1bc',
#      'tcgplayer': 'https://mtgjson.com/links/1072aa7d027aeab3'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': '882fe528-1a84-4d34-bd15-330963b684ff',
#     'scryfallIllustrationId': '7a41f4a9-2cb2-4844-ac0a-85a8d3014d5e',
#     'scryfallOracleId': 'fc5d3341-cbce-49e5-93cc-8add92479dca',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8980,
#     'text': 'Black creatures get +1/+1.',
#     'type': 'Enchantment',
#     'types': ['Enchantment'],
#     'uuid': '89a5e7ed-2a95-53b6-b3c5-d7b676d78b42'},
#    {'artist': 'Rob Alexander',
#     'borderColor': 'white',
#     'colorIdentity': ['B', 'R'],
#     'colors': [],
#     'convertedManaCost': 0.0,
#     'edhrecRank': 540,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'isReserved': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'mcmId': 5183,
#     'mcmMetaId': 407,
#     'mtgstocksId': 15762,
#     'multiverseId': 878,
#     'name': 'Badlands',
#     'number': '278',
#     'originalText': 'Counts as both mountains and swamp and is affected by spells that affect either. Tap to add either oR or oB to your mana pool.',
#     'originalType': 'Land',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 601.45,
#       '2019-07-21': 601.45,
#       '2019-07-28': 550.72,
#       '2019-08-04': 550.72,
#       '2019-08-11': 550.72,
#       '2019-08-18': 601.45,
#       '2019-08-25': 601.45,
#       '2019-09-01': 601.45,
#       '2019-09-08': 601.45,
#       '2019-09-15': 601.45,
#       '2019-09-22': 550.23,
#       '2019-09-29': 550.23,
#       '2019-10-06': 550.72},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME2',
#      'ME4',
#      'OLGC',
#      'PRM',
#      'SUM',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/50faba082c868e53',
#      'mtgstocks': 'https://mtgjson.com/links/0be25fdae2677d86',
#      'tcgplayer': 'https://mtgjson.com/links/0bf366a6fdd64380'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2004-10-04',
#       'text': 'Land type changing effects that change a dual land’s land type will remove the old land types completely. Text-changing effects that just change one of the two land types will leave the other type unaffected.'},
#      {'date': '2004-10-04',
#       'text': 'This card is a Mountain and a Swamp even while in the graveyard, library, or any other zone.'},
#      {'date': '2008-10-01',
#       'text': 'This has the mana abilities associated with both of its basic land types.'},
#      {'date': '2008-10-01',
#       'text': 'This has basic land types, but it isn’t a basic land. Things that affect basic lands don’t affect it. Things that affect basic land types do.'}],
#     'scryfallId': '5804dcd3-d41d-4cbd-9f8f-9736f2d37a64',
#     'scryfallIllustrationId': '669aded5-981a-45ab-9e4e-5864a91c71e5',
#     'scryfallOracleId': '13ff3222-91cb-4796-a34e-899ed817694c',
#     'subtypes': ['Swamp', 'Mountain'],
#     'supertypes': [],
#     'tcgplayerProductId': 8981,
#     'text': '({T}: Add {B} or {R}.)',
#     'type': 'Land — Swamp Mountain',
#     'types': ['Land'],
#     'uuid': 'e4d53516-8187-5480-bf54-ae2ba755f1d4'},
#    {'artist': 'Mark Poole',
#     'borderColor': 'white',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 18342,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Banned',
#      'duel': 'Legal',
#      'legacy': 'Banned',
#      'oldschool': 'Restricted',
#      'vintage': 'Restricted'},
#     'manaCost': '{1}{W}',
#     'mcmId': 5001,
#     'mcmMetaId': 409,
#     'mtgstocksId': 15763,
#     'multiverseId': 831,
#     'name': 'Balance',
#     'number': '3',
#     'originalText': 'Whichever player has more lands in play must discard enough lands of his or her choice to equalize the number of lands both players have in play. Cards in hand and creatures in play must be equalized the same way. Creatures lost in this manner may not be regenerated.',
#     'originalType': 'Sorcery',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 37.5,
#       '2019-07-21': 41.28,
#       '2019-07-28': 41.28,
#       '2019-08-04': 40.92,
#       '2019-08-11': 40.92,
#       '2019-08-18': 40.92,
#       '2019-08-25': 35.97,
#       '2019-09-01': 60.99,
#       '2019-09-08': 60.99,
#       '2019-09-15': 59.99,
#       '2019-09-22': 59.49,
#       '2019-09-29': 61.99,
#       '2019-10-06': 60.99},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      'CED',
#      'CEI',
#      'EMA',
#      'FBB',
#      'G04',
#      'LEA',
#      'LEB',
#      'ME4',
#      'PRM',
#      'PTC',
#      'SUM',
#      'V09',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/55b66962e85ea8d5',
#      'mtgstocks': 'https://mtgjson.com/links/685a01bcbf7ff41e',
#      'tcgplayer': 'https://mtgjson.com/links/8a14280db61f034e'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2016-06-08',
#       'text': 'First the player whose turn it is chooses which lands (if any) to keep, then each other player in turn order does the same. Each player will know the choices made by the players who chose before them. All of the unchosen lands are then sacrificed simultaneously. Then the process is repeated for cards in hand, except that no cards are revealed until all players have chosen what to discard, at which point those cards are all discarded simultaneously. Lastly, the process is repeated for creatures, and players will again know earlier choices made when deciding what to sacrifice. All of the unchosen creatures are then sacrificed simultaneously.'},
#      {'date': '2016-06-08',
#       'text': 'Balance doesn’t have targets, so permanents that can’t be targeted, such as a creature with shroud or protection from white, are valid choices to be sacrificed.'},
#      {'date': '2016-06-08',
#       'text': 'Each type of object is counted during the corresponding part of the process. Cards in hand are counted after lands have been sacrificed, and creatures on the battlefield are counted after cards have been discarded. Thus, a land creature sacrificed to the first part of the spell would not be counted when determining how many creatures are on the battlefield for the last part.'}],
#     'scryfallId': '8352e8b6-c947-49f3-a653-a6af65d3e9c3',
#     'scryfallIllustrationId': 'e47fbe71-fcea-4aba-9d74-fc6fec8407f7',
#     'scryfallOracleId': '17fa98cd-ed8f-483f-9525-7e989a82ebb2',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8982,
#     'text': 'Each player chooses a number of lands they control equal to the number of lands controlled by the player who controls the fewest, then sacrifices the rest. Players discard cards and sacrifice creatures the same way.',
#     'type': 'Sorcery',
#     'types': ['Sorcery'],
#     'uuid': '39342ed8-f073-57b3-a741-ae2cd782d88a'},
#    {'artist': 'Jesper Myrfors',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 3.0,
#     'edhrecRank': 259,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{3}',
#     'mcmId': 5091,
#     'mcmMetaId': 470,
#     'mtgstocksId': 15764,
#     'multiverseId': 599,
#     'name': 'Basalt Monolith',
#     'number': '232',
#     'originalText': 'Tap to add 3 colorless mana to your mana pool. Does not untap as normal during untap phase; spend o3 to untap. Tapping this artifact can be played as an interrupt.',
#     'originalType': 'Mono Artifact',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 14.99,
#       '2019-07-21': 15.0,
#       '2019-07-28': 15.0,
#       '2019-08-04': 14.49,
#       '2019-08-11': 13.79,
#       '2019-08-18': 13.62,
#       '2019-08-25': 13.0,
#       '2019-09-01': 12.85,
#       '2019-09-08': 12.85,
#       '2019-09-15': 11.99,
#       '2019-09-22': 11.77,
#       '2019-09-29': 12.0,
#       '2019-10-06': 11.87},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      'C13',
#      'C15',
#      'CED',
#      'CEI',
#      'CM2',
#      'CMA',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME4',
#      'PRM',
#      'PZ1',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/b4db4e86d87a5aaf',
#      'mtgstocks': 'https://mtgjson.com/links/31db5ec18e9c8bb2',
#      'tcgplayer': 'https://mtgjson.com/links/6cbb65e4607f0fee'},
#     'rarity': 'uncommon',
#     'rulings': [{'date': '2004-10-04',
#       'text': 'It can be untapped as often as you can pay for it.'}],
#     'scryfallId': '5a72cd4b-5b47-46b8-b230-4b246f97221f',
#     'scryfallIllustrationId': '86e208e2-f67d-4dd2-9a46-48e704d43efb',
#     'scryfallOracleId': '6b8cf2a0-b045-4d91-9d91-c602d40c6237',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8983,
#     'text': "Basalt Monolith doesn't untap during your untap step.\n{T}: Add {C}{C}{C}.\n{3}: Untap Basalt Monolith.",
#     'type': 'Artifact',
#     'types': ['Artifact'],
#     'uuid': 'f1cd5807-b3f4-58ee-9b39-87e028296b65'},
#    {'artist': 'Jesper Myrfors',
#     'borderColor': 'white',
#     'colorIdentity': ['B', 'G'],
#     'colors': [],
#     'convertedManaCost': 0.0,
#     'edhrecRank': 493,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'isReserved': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'mcmId': 5185,
#     'mcmMetaId': 492,
#     'mtgstocksId': 15765,
#     'multiverseId': 879,
#     'name': 'Bayou',
#     'number': '279',
#     'originalText': 'Counts as both swamp and forest and is affected by spells that affect either. Tap to add either oB or oG to your mana pool.',
#     'originalType': 'Land',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 759.0,
#       '2019-07-21': 750.0,
#       '2019-07-28': 759.0,
#       '2019-08-04': 748.75,
#       '2019-08-11': 692.0,
#       '2019-08-18': 759.0,
#       '2019-08-25': 725.0,
#       '2019-09-01': 792.0,
#       '2019-09-08': 769.0,
#       '2019-09-15': 709.5,
#       '2019-09-22': 693.25,
#       '2019-09-29': 708.25,
#       '2019-10-06': 799.0},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME3',
#      'ME4',
#      'OLGC',
#      'PRM',
#      'SUM',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/0000e6ae11886e5a',
#      'mtgstocks': 'https://mtgjson.com/links/ade6800a35b089aa',
#      'tcgplayer': 'https://mtgjson.com/links/946b10af6556fa2a'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2008-10-01',
#       'text': 'This has the mana abilities associated with both of its basic land types.'},
#      {'date': '2008-10-01',
#       'text': 'This has basic land types, but it isn’t a basic land. Things that affect basic lands don’t affect it. Things that affect basic land types do.'}],
#     'scryfallId': 'd66e43f0-1558-409f-8248-cc1d76c6bd8e',
#     'scryfallIllustrationId': '8cb160a9-900b-420e-bce8-3a62f689d2c8',
#     'scryfallOracleId': 'b76d1ae6-ad1d-4bac-b4c3-2e03e0e84d9b',
#     'subtypes': ['Swamp', 'Forest'],
#     'supertypes': [],
#     'tcgplayerProductId': 8984,
#     'text': '({T}: Add {B} or {G}.)',
#     'type': 'Land — Swamp Forest',
#     'types': ['Land'],
#     'uuid': 'fbcd5538-9879-5b5f-84e1-5c200fb3ea7f'},
#    {'artist': 'Douglas Shuler',
#     'borderColor': 'white',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 13728,
#     'flavorText': 'Benalia has a complex caste system that changes with the lunar year. No matter what the season, the only caste that cannot be attained by either heredity or money is that of the hero.',
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'pauper': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{W}',
#     'mcmId': 5003,
#     'mcmMetaId': 518,
#     'mtgstocksId': 15766,
#     'multiverseId': 832,
#     'name': 'Benalish Hero',
#     'number': '4',
#     'originalText': 'Bands',
#     'originalType': 'Summon - Hero',
#     'power': '1',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 0.7,
#       '2019-07-21': 0.54,
#       '2019-07-28': 0.54,
#       '2019-08-04': 0.53,
#       '2019-08-11': 0.51,
#       '2019-08-18': 0.54,
#       '2019-08-25': 0.55,
#       '2019-09-01': 0.6,
#       '2019-09-08': 0.58,
#       '2019-09-15': 0.6,
#       '2019-09-22': 0.57,
#       '2019-09-29': 0.54,
#       '2019-10-06': 0.55},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME1',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/8c37bcea87c0dc9c',
#      'mtgstocks': 'https://mtgjson.com/links/137605df6f07f6b9',
#      'tcgplayer': 'https://mtgjson.com/links/89cfcea2d8153d71'},
#     'rarity': 'common',
#     'rulings': [{'date': '2008-10-01',
#       'text': 'If a creature with banding attacks, it can team up with any number of other attacking creatures with banding (and up to one nonbanding creature) and attack as a unit called a “band.” The band can be blocked by any creature that could block a single creature in the band. Blocking any creature in a band blocks the entire band. If a creature with banding is blocked, the attacking player chooses how the blockers’ damage is assigned.'},
#      {'date': '2008-10-01',
#       'text': 'A maximum of one nonbanding creature can join an attacking band no matter how many creatures with banding are in it.'},
#      {'date': '2008-10-01',
#       'text': 'Creatures in the same band must all attack the same player or planeswalker.'},
#      {'date': '2009-10-01',
#       'text': 'If a creature in combat has banding, its controller assigns damage for creatures blocking or blocked by it. That player can ignore the damage assignment order when making this assignment.'}],
#     'scryfallId': '9404e779-2065-4c4f-95d1-6997c7fea156',
#     'scryfallIllustrationId': '36cd4598-d058-49f8-b39e-0a5997ca5a42',
#     'scryfallOracleId': '4c81cfb7-8765-4e28-ae33-4287fa9a86cc',
#     'subtypes': ['Human', 'Soldier'],
#     'supertypes': [],
#     'tcgplayerProductId': 8985,
#     'text': "Banding (Any creatures with banding, and up to one without, can attack in a band. Bands are blocked as a group. If any creatures with banding you control are blocking or being blocked by a creature, you divide that creature's combat damage, not its controller, among any of the creatures it's being blocked by or is blocking.)",
#     'toughness': '1',
#     'type': 'Creature — Human Soldier',
#     'types': ['Creature'],
#     'uuid': '26eeede1-1658-557e-97c1-885ae835546c'},
#    {'artist': 'Dan Frazier',
#     'borderColor': 'white',
#     'colorIdentity': ['G'],
#     'colors': ['G'],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 2861,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{G}',
#     'mcmId': 4815,
#     'mcmMetaId': 532,
#     'mtgstocksId': 15767,
#     'multiverseId': 738,
#     'name': 'Berserk',
#     'number': '186',
#     'originalText': "Until end of turn, target creature's current power doubles and it gains trample ability. If it attacks, target creature is destroyed at end of turn. This spell cannot be cast after current turn's attack is completed.",
#     'originalType': 'Instant',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 75.0,
#       '2019-07-21': 77.46,
#       '2019-07-28': 78.01,
#       '2019-08-04': 75.0,
#       '2019-08-11': 76.75,
#       '2019-08-18': 76.75,
#       '2019-08-25': 78.58,
#       '2019-09-01': 76.24,
#       '2019-09-08': 76.24,
#       '2019-09-15': 74.12,
#       '2019-09-22': 76.24,
#       '2019-09-29': 76.24,
#       '2019-10-06': 76.24},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      'CED',
#      'CEI',
#      'CN2',
#      'LEA',
#      'LEB',
#      'ME1',
#      'V09',
#      'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/8564cb6ad9529539',
#      'mtgstocks': 'https://mtgjson.com/links/9b8e27c00ad4e318',
#      'tcgplayer': 'https://mtgjson.com/links/7e162e2951e5e5cd'},
#     'rarity': 'uncommon',
#     'rulings': [{'date': '2004-10-04',
#       'text': 'If the permanent stops being a creature before the end of the turn, it is still destroyed.'}],
#     'scryfallId': 'fd082697-493f-48e3-a41f-123700435025',
#     'scryfallIllustrationId': '9b8e590c-8a0c-4805-ba5d-60fc2f243e86',
#     'scryfallOracleId': '8b67d192-9a05-4a47-82ae-5fc4b7834d88',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8986,
#     'text': 'Cast this spell only before the combat damage step.\nTarget creature gains trample and gets +X/+0 until end of turn, where X is its power. At the beginning of the next end step, destroy that creature if it attacked this turn.',
#     'type': 'Instant',
#     'types': ['Instant'],
#     'uuid': '9833721b-dcb5-52c2-ab3c-46f673632d14'},
#    {'artist': 'Mark Poole',
#     'borderColor': 'white',
#     'colorIdentity': ['G'],
#     'colors': ['G'],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 77,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{G}',
#     'mcmId': 4817,
#     'mcmMetaId': 545,
#     'mtgstocksId': 15768,
#     'multiverseId': 739,
#     'name': 'Birds of Paradise',
#     'number': '187',
#     'originalText': 'Flying\nTap to add one mana of any color to your mana pool. This tap may be played as an interrupt.',
#     'originalType': 'Summon - Mana Birds',
#     'power': '0',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 322.5,
#       '2019-07-21': 344.99,
#       '2019-07-28': 300.0,
#       '2019-08-04': 300.0,
#       '2019-08-11': 300.0,
#       '2019-08-18': 312.5,
#       '2019-08-25': 312.5,
#       '2019-09-01': 312.5,
#       '2019-09-08': 312.5,
#       '2019-09-15': 312.5,
#       '2019-09-22': 280.0,
#       '2019-09-29': 312.5,
#       '2019-10-06': 312.5},
#      'paperFoil': {}},
#     'printings': ['10E',
#      '2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      '7ED',
#      '8ED',
#      'CED',
#      'CEI',
#      'CN2',
#      'FBB',
#      'GK2',
#      'LEA',
#      'LEB',
#      'M10',
#      'M11',
#      'M12',
#      'PM11',
#      'PRM',
#      'PTC',
#      'RAV',
#      'SUM',
#      'WC00',
#      'WC01',
#      'WC02',
#      'WC98'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/9103bf4e554db164',
#      'mtgstocks': 'https://mtgjson.com/links/7345e3a1ace6b75e',
#      'tcgplayer': 'https://mtgjson.com/links/b2327bdfba5a1f75'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': '4e50454c-3927-4e7e-b4f6-7f5d5fd9b913',
#     'scryfallIllustrationId': '96b78cb9-847b-428f-a887-e330c2d9f9ee',
#     'scryfallOracleId': 'd3a0b660-358c-41bd-9cd2-41fbf3491b1a',
#     'subtypes': ['Bird'],
#     'supertypes': [],
#     'tcgplayerProductId': 8987,
#     'text': 'Flying\n{T}: Add one mana of any color.',
#     'toughness': '1',
#     'type': 'Creature — Bird',
#     'types': ['Creature'],
#     'uuid': 'd139d0ae-8a22-50cc-9e8c-77aec3b4ba72'},
#    {'artist': 'Jeff A. Menges',
#     'borderColor': 'white',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 7104,
#     'flavorText': "Battle doesn't need a purpose; the battle is its own purpose. You don't ask why a plague spreads or a field burns. Don't ask why I fight.",
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{B}{B}',
#     'mcmId': 4633,
#     'mcmMetaId': 547,
#     'mtgstocksId': 15769,
#     'multiverseId': 647,
#     'name': 'Black Knight',
#     'number': '95',
#     'originalText': 'Protection from white, first strike',
#     'originalType': 'Summon - Knight',
#     'power': '2',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 15.95,
#       '2019-07-21': 15.95,
#       '2019-07-28': 15.94,
#       '2019-08-04': 15.95,
#       '2019-08-11': 15.46,
#       '2019-08-18': 14.99,
#       '2019-08-25': 14.99,
#       '2019-09-01': 14.98,
#       '2019-09-08': 14.49,
#       '2019-09-15': 12.51,
#       '2019-09-22': 13.1,
#       '2019-09-29': 12.43,
#       '2019-10-06': 12.27},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'ATH',
#      'CED',
#      'CEI',
#      'F02',
#      'FBB',
#      'LEA',
#      'LEB',
#      'M10',
#      'M11',
#      'ME1',
#      'ME4',
#      'PRM',
#      'SUM',
#      'WC97'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/0c9da8c81658758e',
#      'mtgstocks': 'https://mtgjson.com/links/9d6e942c9180b747',
#      'tcgplayer': 'https://mtgjson.com/links/deb4666a75564b9f'},
#     'rarity': 'uncommon',
#     'rulings': [],
#     'scryfallId': '36b94d0d-fbe5-4f32-af02-bbe3ab2e234a',
#     'scryfallIllustrationId': '1d2452e5-ca1f-4c39-8977-b816d334dd21',
#     'scryfallOracleId': '9456c5b6-946d-403a-8ed0-dff9f921d98c',
#     'subtypes': ['Human', 'Knight'],
#     'supertypes': [],
#     'tcgplayerProductId': 8988,
#     'text': "First strike (This creature deals combat damage before creatures without first strike.)\nProtection from white (This creature can't be blocked, targeted, dealt damage, or enchanted by anything white.)",
#     'toughness': '2',
#     'type': 'Creature — Human Knight',
#     'types': ['Creature'],
#     'uuid': 'ac2ec642-9a2c-580c-85bd-371199903cab'},
#    {'artist': 'Christopher Rush',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 0.0,
#     'edhrecRank': 19169,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'isReserved': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Banned',
#      'duel': 'Banned',
#      'legacy': 'Banned',
#      'oldschool': 'Restricted',
#      'vintage': 'Restricted'},
#     'manaCost': '{0}',
#     'mcmId': 5093,
#     'mcmMetaId': 548,
#     'mtgstocksId': 15770,
#     'multiverseId': 600,
#     'name': 'Black Lotus',
#     'number': '233',
#     'originalText': 'Adds 3 mana of any single color of your choice to your mana pool, then is discarded. Tapping this artifact can be played as an interrupt.',
#     'originalType': 'Mono Artifact',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 7000.0,
#       '2019-07-21': 8900.0,
#       '2019-07-28': 7799.99,
#       '2019-08-04': 7799.99,
#       '2019-08-11': 7900.0,
#       '2019-08-18': 7900.0,
#       '2019-08-25': 7900.0,
#       '2019-09-01': 9999.95,
#       '2019-09-08': 9999.95,
#       '2019-09-15': 9999.95,
#       '2019-09-22': 17724.99,
#       '2019-09-29': 16999.0,
#       '2019-10-06': 17999.99},
#      'paperFoil': {}},
#     'printings': ['2ED', 'CED', 'CEI', 'LEA', 'LEB', 'OVNT', 'PRM', 'VMA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/2dd4210fab8a8928',
#      'mtgstocks': 'https://mtgjson.com/links/cd88c74308f3372f',
#      'tcgplayer': 'https://mtgjson.com/links/03aaef0fd45d47ee'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': '4a2e428c-dd25-484c-bbc8-2d6ce10ef42c',
#     'scryfallIllustrationId': '54436824-977b-4dc7-8de1-8498e73e5ef2',
#     'scryfallOracleId': '5089ec1a-f881-4d55-af14-5d996171203b',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 8989,
#     'text': '{T}, Sacrifice Black Lotus: Add three mana of any one color.',
#     'type': 'Artifact',
#     'types': ['Artifact'],
#     'uuid': '57060797-ff37-58a3-b9b3-35d74ce0e2a1'},
#    {'artist': 'Richard Thomas',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 6609,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
# ...
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '9ED',
#      'A25',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/910a9a07ac393fc2',
#      'mtgstocks': 'https://mtgjson.com/links/7c9e2d1ac4e7e6a9',
#      'tcgplayer': 'https://mtgjson.com/links/85f018871cacae45'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': '73a2a070-464e-4749-87f1-2df5c8b2a93b',
#     'scryfallIllustrationId': '9d133a85-1174-477a-beae-32373e8d71ee',
#     'scryfallOracleId': '8b60fcfe-fb90-4a00-a708-25b59bfc9b5a',
#     'subtypes': ['Spirit'],
#     'supertypes': [],
#     'tcgplayerProductId': 9268,
#     'text': "Flying (This creature can't be blocked except by creatures with flying or reach.)\n{B}: Regenerate Will-o'-the-Wisp. (The next time this creature would be destroyed this turn, it isn't. Instead tap it, remove all damage from it, and remove it from combat.)",
#     'toughness': '1',
#     'type': 'Creature — Spirit',
#     'types': ['Creature'],
#     'uuid': '76047173-5828-5ec1-b424-ab99d69981c0'},
#    {'artist': 'Mark Tedin',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 639,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{2}',
#     'mcmId': 5179,
#     'mcmMetaId': 6663,
#     'mtgstocksId': 16050,
#     'multiverseId': 643,
#     'name': 'Winter Orb',
#     'number': '276',
#     'originalText': 'Players can untap only one land each during untap phase. Creatures and artifacts are untapped as normal.',
#     'originalType': 'Continuous Artifact',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 85.15,
#       '2019-07-21': 85.15,
#       '2019-07-28': 85.15,
#       '2019-08-04': 89.75,
#       '2019-08-11': 83.39,
#       '2019-08-18': 92.48,
#       '2019-08-25': 89.55,
#       '2019-09-01': 89.55,
#       '2019-09-08': 75.0,
#       '2019-09-15': 75.0,
#       '2019-09-22': 75.0,
#       '2019-09-29': 75.0,
#       '2019-10-06': 72.25},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      'CED',
#      'CEI',
#      'EMA',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME1',
#      'PRM',
#      'PTC',
#      'SUM',
#      'WC97'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/184be94a113c0ca3',
#      'mtgstocks': 'https://mtgjson.com/links/dcb81c8f5ef45a89',
#      'tcgplayer': 'https://mtgjson.com/links/c738b7bf89988cc0'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2016-06-08',
#       'text': 'All permanents untap during a player’s untap step at once. If Winter Orb is tapped as your untap step begins, your lands will all untap.'},
#      {'date': '2016-06-08',
#       'text': 'You can’t tap Winter Orb just because you want to. Another ability, such as that of Glare of Subdual, must instruct or allow you to do so.'}],
#     'scryfallId': 'ee9eb598-d2ef-4b3d-8038-bc33dc5e123e',
#     'scryfallIllustrationId': '702cc171-ec95-47ff-aae4-ad80d33736d2',
#     'scryfallOracleId': '1dcbd583-3388-4b34-a7cd-131648aa6abd',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 9269,
#     'text': "As long as Winter Orb is untapped, players can't untap more than one land during their untap steps.",
#     'type': 'Artifact',
#     'types': ['Artifact'],
#     'uuid': '7cdcb328-823f-5a73-b312-df4165a1f44c'},
#    {'artist': 'Mark Tedin',
#     'borderColor': 'white',
#     'colorIdentity': [],
#     'colors': [],
#     'convertedManaCost': 1.0,
#     'edhrecRank': 17234,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'penny': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}',
#     'mcmId': 5181,
#     'mcmMetaId': 6702,
#     'mtgstocksId': 16051,
#     'multiverseId': 644,
#     'name': 'Wooden Sphere',
#     'number': '277',
#     'originalText': 'o1: Any green spell cast by any player gives you 1 life.',
#     'originalType': 'Poly Artifact',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 2.21,
#       '2019-07-21': 2.13,
#       '2019-07-28': 1.78,
#       '2019-08-04': 1.78,
#       '2019-08-11': 1.78,
#       '2019-08-18': 1.78,
#       '2019-08-25': 2.0,
#       '2019-09-01': 2.22,
#       '2019-09-08': 2.22,
#       '2019-09-15': 2.21,
#       '2019-09-22': 2.22,
#       '2019-09-29': 2.27,
#       '2019-10-06': 3.08},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      '7ED',
#      '8ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/a42879f7b22899be',
#      'mtgstocks': 'https://mtgjson.com/links/6f48fea770cfac0b',
#      'tcgplayer': 'https://mtgjson.com/links/5730cce9a8362d31'},
#     'rarity': 'uncommon',
#     'rulings': [],
#     'scryfallId': 'fb19b35e-e0b9-4575-b146-2682ad8a5175',
#     'scryfallIllustrationId': 'b7881d13-e753-4137-820a-f5a170bda717',
#     'scryfallOracleId': '0bd8917c-bec4-4603-bc3f-8e0c2afae56a',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 9270,
#     'text': 'Whenever a player casts a green spell, you may pay {1}. If you do, you gain 1 life.',
#     'type': 'Artifact',
#     'types': ['Artifact'],
#     'uuid': '474867e4-2b63-57d6-bd16-3612a6bc3382'},
#    {'artist': 'Jesper Myrfors',
#     'borderColor': 'white',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 11593,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'isReserved': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{B}{B}',
#     'mcmId': 4717,
#     'mcmMetaId': 6709,
#     'mtgstocksId': 16052,
#     'multiverseId': 689,
#     'name': 'Word of Command',
#     'number': '137',
#     'originalText': "You may look at opponent's hand and choose any card opponent can legally play using mana from his or her mana pool or lands. Opponent must play this card immediately; you make all the decisions it calls for. This spell may not be countered after you have looked at opponent's hand.",
#     'originalType': 'Instant',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 159.99,
#       '2019-07-21': 159.99,
#       '2019-07-28': 159.99,
#       '2019-08-04': 159.99,
#       '2019-08-11': 159.99,
#       '2019-08-18': 159.99,
#       '2019-08-25': 159.99,
#       '2019-09-01': 159.99,
#       '2019-09-08': 145.34,
#       '2019-09-15': 144.25,
#       '2019-09-22': 147.89,
#       '2019-09-29': 147.89,
#       '2019-10-06': 147.89},
#      'paperFoil': {}},
#     'printings': ['2ED', 'CED', 'CEI', 'LEA', 'LEB', 'ME4'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/d348596cff5b9c69',
#      'mtgstocks': 'https://mtgjson.com/links/11ca6b6cd210c04e',
#      'tcgplayer': 'https://mtgjson.com/links/c2816cd4c92c72ba'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2004-10-04',
#       'text': 'To “play a card” is to either cast a spell or to put a land onto the battlefield using the main phase special action.'},
#      {'date': '2009-10-01',
#       'text': 'You do get to choose which lands get tapped. You can make them choose an optional mana generating ability of the land that they tap, such as making them tap and sacrifice the land instead of just tap it.'},
#      {'date': '2011-01-01',
#       'text': 'You control the player while this spell is resolving, which means you get to see anything they can see. If that player is required to search their library as part of playing the card or as part of its resolution if it’s cast as a spell, then you can see the cards in that player’s library as well.'},
#      {'date': '2011-01-01',
#       'text': 'Your opponent can’t counter the Word of Command after letting you look at their hand, but they can attempt to counter the spell you force them to cast.'},
#      {'date': '2011-01-01',
#       'text': 'You may Command your opponent to play a land (if they have not already done so this turn).'},
#      {'date': '2011-01-01',
#       'text': 'If there is a non-mana way to cast a spell, as with Pitch Spells, you may require that way to be used if it is possible to do so.'},
#      {'date': '2011-01-01',
#       'text': 'Since this spell is an instant, your opponent gets a chance to respond to it as normal. Once this spell resolves, you look at your opponent’s hand and choose a card. Note that it is common practice to respond to Word of Command by using up any spells or mana you have prior to letting it resolve.'},
#      {'date': '2011-01-01',
#       'text': 'During the resolution of this spell, that player plays the chosen card.'},
#      {'date': '2011-01-01',
#       'text': 'You must order your opponent to play the chosen card if it is possible to do so.'},
#      {'date': '2011-01-01',
#       'text': 'Word of Command can’t be used to force a player to play a card that isn’t in their hand.'},
#      {'date': '2016-07-13',
#       'text': 'While controlling another player, you can see all cards in the game that player can see. This includes cards in that player’s hand, face-down cards that player controls, and any cards in that player’s library the player may look at.'},
#      {'date': '2016-07-13',
#       'text': 'Controlling a player doesn’t allow you to look at that player’s sideboard. If an effect instructs that player to choose a card from outside the game, you can’t have that player choose any card.'}],
#     'scryfallId': '239c8547-207b-41d1-a2be-8825bfc6ef7f',
#     'scryfallIllustrationId': '58147ab5-fb67-4102-9b17-64adac0a4482',
#     'scryfallOracleId': 'e8ad3a77-b293-4d69-b080-27ca9f95d443',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 9271,
#     'text': "Look at target opponent's hand and choose a card from it. You control that player until Word of Command finishes resolving. The player plays that card if able. While doing so, the player can activate mana abilities only if they're from lands that player controls and only if mana they produce is spent to activate other mana abilities of lands the player controls and/or to play that card. If the chosen card is cast as a spell, you control the player while that spell is resolving.",
#     'type': 'Instant',
#     'types': ['Instant'],
#     'uuid': '11ad7519-8481-5fad-ac1f-8c675c36fed9'},
#    {'artist': 'Quinton Hoover',
#     'borderColor': 'white',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 4.0,
#     'edhrecRank': 98,
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{2}{W}{W}',
#     'mcmId': 5087,
#     'mcmMetaId': 6734,
#     'mtgstocksId': 16053,
#     'multiverseId': 874,
#     'name': 'Wrath of God',
#     'number': '46',
#     'originalText': 'All creatures in play are destroyed and cannot regenerate.',
#     'originalType': 'Sorcery',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 72.71,
#       '2019-07-21': 75.0,
#       '2019-07-28': 75.37,
#       '2019-08-04': 80.25,
#       '2019-08-11': 75.74,
#       '2019-08-18': 89.95,
#       '2019-08-25': 89.95,
#       '2019-09-01': 89.95,
#       '2019-09-08': 89.95,
#       '2019-09-15': 89.95,
#       '2019-09-22': 89.95,
#       '2019-09-29': 89.95,
#       '2019-10-06': 89.95},
#      'paperFoil': {}},
#     'printings': ['10E',
#      '2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      '7ED',
#      '8ED',
#      '9ED',
#      'BRB',
#      'C13',
#      'CED',
#      'CEI',
#      'EMA',
#      'FBB',
#      'LEA',
#      'LEB',
#      'MP2',
#      'P07',
#      'POR',
#      'PRM',
#      'PTC',
#      'PZ1',
#      'SUM',
#      'V14',
#      'WC00',
#      'WC03',
#      'WC04'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/3b8b6c205932699b',
#      'mtgstocks': 'https://mtgjson.com/links/2df9bce929437818',
#      'tcgplayer': 'https://mtgjson.com/links/4bd8de3d04560b7d'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': 'e57404bc-44ba-4909-87da-f4a71673168d',
#     'scryfallIllustrationId': 'e87a70b0-4485-4362-9a1d-7c320cd7755e',
#     'scryfallOracleId': '34515b16-c9a4-4f98-8c77-416a7a523407',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 9272,
#     'text': "Destroy all creatures. They can't be regenerated.",
#     'type': 'Sorcery',
#     'types': ['Sorcery'],
#     'uuid': '5b6a0bd0-1470-5060-a79a-9269380a64b5'},
#    {'artist': 'Jeff A. Menges',
#     'borderColor': 'white',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'convertedManaCost': 3.0,
#     'edhrecRank': 2049,
#     'flavorText': 'They say the Zombie Master controlled these foul creatures even before his own death, but now that he is one of them, nothing can make them betray him.',
#     'foreignData': [],
#     'frameVersion': '1993',
#     'hasFoil': False,
#     'hasNonFoil': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'commander': 'Legal',
#      'duel': 'Legal',
#      'legacy': 'Legal',
#      'oldschool': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}{B}{B}',
#     'mcmId': 4719,
#     'mcmMetaId': 6821,
#     'mtgstocksId': 16054,
#     'multiverseId': 690,
#     'name': 'Zombie Master',
#     'number': '138',
#     'originalText': 'All zombies in play gain swampwalk and "ooB Regenerates" for as long as this card remains in play.',
#     'originalType': 'Summon - Lord',
#     'power': '2',
#     'prices': {'mtgo': None,
#      'mtgoFoil': None,
#      'paper': {'2019-07-14': 34.94,
#       '2019-07-21': 34.89,
#       '2019-07-28': 34.89,
#       '2019-08-04': 34.94,
#       '2019-08-11': 34.94,
#       '2019-08-18': 33.19,
#       '2019-08-25': 34.99,
#       '2019-09-01': 34.94,
#       '2019-09-08': 34.94,
#       '2019-09-15': 34.99,
#       '2019-09-22': 34.07,
#       '2019-09-29': 33.24,
#       '2019-10-06': 34.89},
#      'paperFoil': {}},
#     'printings': ['2ED',
#      '3ED',
#      '4BB',
#      '4ED',
#      '5ED',
#      '6ED',
#      'CED',
#      'CEI',
#      'FBB',
#      'LEA',
#      'LEB',
#      'ME4',
#      'SUM'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/095f3e87bbec7a48',
#      'mtgstocks': 'https://mtgjson.com/links/d64f95ae430f9ff3',
#      'tcgplayer': 'https://mtgjson.com/links/0efb4e0fb40a77b2'},
#     'rarity': 'rare',
#     'rulings': [],
#     'scryfallId': 'd9b2accc-11e8-4bfd-97fc-d2f6bcd94c26',
#     'scryfallIllustrationId': '7441c48a-ca5a-415c-ad9d-2839e6e47f5b',
#     'scryfallOracleId': '5446c92f-ff22-4e9b-a2f6-e64c8560c1e0',
#     'subtypes': ['Zombie'],
#     'supertypes': [],
#     'tcgplayerProductId': 9273,
#     'text': 'Other Zombie creatures have swampwalk. (They can\'t be blocked as long as defending player controls a Swamp.)\nOther Zombies have "{B}: Regenerate this permanent."',
#     'toughness': '3',
#     'type': 'Creature — Zombie',
#     'types': ['Creature'],
#     'uuid': '8978d0f2-f50a-536f-84f7-4a4bc23d4524'}],
#   'code': '2ED',
#   'isFoilOnly': False,
#   'isOnlineOnly': False,
#   'keyruneCode': '2ED',
#   'mcmId': 3,
#   'mcmName': 'Unlimited',
#   'meta': {'date': '2019-10-13',
#    'pricesDate': '2019-10-13',
#    'version': '4.5.1-rebuild.4'},
#   'name': 'Unlimited Edition',
#   'releaseDate': '1993-12-01',
#   'tcgplayerGroupId': 115,
#   'tokens': [],
#   'totalSetSize': 302,
#   'translations': {},
#   'type': 'core'})

# %%
# code to see how many observations there are in mtg_archive_clean
len(list(mtg_archive_clean))
# Out:
# 460

# %% [markdown]
# ### Assessment

# %% [markdown]
# - need tcg player urls
# - need a name list

# %% [markdown]
# ## Clean

# %% [markdown]
# ### Define
# - write a loop that pulls out names and tcg player purchase url

# %% [markdown]
# ### Code

# %%
# loop that pulls out names and tcg player purchase url
tcg_player_card_urls = []
card_names = mtg_archive_clean.keys()
tcg_names = []
card_errors = []
for i in card_names:
    try: 
        tcg_player_card_urls.append(mtg_archive_clean[i]['purchaseUrls']['tcgplayer'])
        tcg_names.append(mtg_archive_clean[i]['name'])
    except Exception as e:
        print(str(i) + ' ' + str(e))
        card_errors.append(i)
# Out:
# 1996 World Champion 'purchaseUrls'
# A Display of My Dark Power 'purchaseUrls'
# A Reckoning Approaches 'purchaseUrls'
# Abbot of Keral Keep 'purchaseUrls'
# Abhorrent Overlord 'purchaseUrls'
# Absolute Law 'purchaseUrls'
# Abyssal Persecutor 'purchaseUrls'
# Abyssal Specter 'purchaseUrls'
# Abzan Ascendancy 'purchaseUrls'
# Abzan Beastmaster 'purchaseUrls'
# Academy Rector 'purchaseUrls'
# Academy at Tolaria West 'purchaseUrls'
# Acid Rain 'purchaseUrls'
# Adanto, the First Fort 'purchaseUrls'
# Adarkar Sentinel 'purchaseUrls'
# Addle 'purchaseUrls'
# Adun Oakenshield 'purchaseUrls'
# Aeolipile 'purchaseUrls'
# Aeronaut Tinkerer 'purchaseUrls'
# Aether Hub 'purchaseUrls'
# Aether Mutation 'purchaseUrls'
# Aetherflux Reservoir 'purchaseUrls'
# Aethersnatch 'purchaseUrls'
# Aethersquall Ancient 'purchaseUrls'
# Aetherstorm Roc 'purchaseUrls'
# Aetherworks Marvel 'purchaseUrls'
# Aftershock 'purchaseUrls'
# Aggressive Instinct 'purchaseUrls'
# Agyrem 'purchaseUrls'
# Ainok Tracker 'purchaseUrls'
# Aisling Leprechaun 'purchaseUrls'
# Ajani Vengeant 'purchaseUrls'
# Ajani, the Greathearted 'purchaseUrls'
# Akoum 'purchaseUrls'
# Akoum Firebird 'purchaseUrls'
# Akoum Hellkite 'purchaseUrls'
# Akroma's Blessing 'purchaseUrls'
# Akroma, Angel of Wrath Avatar 'purchaseUrls'
# Al-abara's Carpet 'purchaseUrls'
# Alabaster Potion 'purchaseUrls'
# Albino Troll 'purchaseUrls'
# Alchor's Tomb 'purchaseUrls'
# Alhammarret, High Arbiter 'purchaseUrls'
# Aligned Hedron Network 'purchaseUrls'
# All Hallow's Eve 'purchaseUrls'
# All Shall Smolder in My Wake 'purchaseUrls'
# All in Good Time 'purchaseUrls'
# Ally Encampment 'purchaseUrls'
# Alms Collector 'purchaseUrls'
# Alpha Myr 'purchaseUrls'
# Altar of Mogis 'purchaseUrls'
# Altar of the Brood 'purchaseUrls'
# Altered Ego 'purchaseUrls'
# Ambition's Cost 'purchaseUrls'
# Aminatou's Augury 'purchaseUrls'
# Aminatou, the Fateshifter 'purchaseUrls'
# Amnesia 'purchaseUrls'
# Anafenza, Kin-Tree Spirit 'purchaseUrls'
# Anafenza, the Foremost 'purchaseUrls'
# Anarchy 'purchaseUrls'
# Anathemancer 'purchaseUrls'
# Ancestor Dragon 'purchaseUrls'
# Ancient Den 'purchaseUrls'
# Ancient Grudge 'purchaseUrls'
# Ancient Hellkite 'purchaseUrls'
# Ancient Stone Idol 'purchaseUrls'
# Ancient Tomb 'purchaseUrls'
# Angel of Deliverance 'purchaseUrls'
# Angel of Invention 'purchaseUrls'
# Angelic Captain 'purchaseUrls'
# Angelic Guardian 'purchaseUrls'
# Angelic Reward 'purchaseUrls'
# Angelic Skirmisher 'purchaseUrls'
# Anger 'purchaseUrls'
# Angler Turtle 'purchaseUrls'
# Angrath, Captain of Chaos 'purchaseUrls'
# Angry Mob 'purchaseUrls'
# Anguished Unmaking 'purchaseUrls'
# Angus Mackenzie 'purchaseUrls'
# Animar, Soul of Elements 'purchaseUrls'
# Animation Module 'purchaseUrls'
# Anje Falkenrath 'purchaseUrls'
# Anthousa, Setessan Hero 'purchaseUrls'
# Anurid Brushhopper 'purchaseUrls'
# Anya, Merciless Angel 'purchaseUrls'
# Apprentice Wizard 'purchaseUrls'
# Approach My Molten Realm 'purchaseUrls'
# Aquamoeba 'purchaseUrls'
# Arachnogenesis 'purchaseUrls'
# Arahbo, Roar of the World 'purchaseUrls'
# Arashin Foremost 'purchaseUrls'
# Arashin Sovereign 'purchaseUrls'
# Arashin War Beast 'purchaseUrls'
# Arbiter of the Ideal 'purchaseUrls'
# Arboria 'purchaseUrls'
# Arc Lightning 'purchaseUrls'
# Arcane Sanctum 'purchaseUrls'
# Arcanis, the Omnipotent Avatar 'purchaseUrls'
# Arcbond 'purchaseUrls'
# Arcbound Overseer Avatar 'purchaseUrls'
# Archdemon of Greed 'purchaseUrls'
# Architect of the Untamed 'purchaseUrls'
# Archon of the Triumvirate 'purchaseUrls'
# Ardent Recruit 'purchaseUrls'
# Arena 'purchaseUrls'
# Aretopolis 'purchaseUrls'
# Argent Sphinx 'purchaseUrls'
# Argivian Archaeologist 'purchaseUrls'
# Argivian Blacksmith 'purchaseUrls'
# Argothian Pixies 'purchaseUrls'
# Argothian Treefolk 'purchaseUrls'
# Arixmethes, Slumbering Isle 'purchaseUrls'
# Arjun, the Shifting Flame 'purchaseUrls'
# Arlinn, Voice of the Pack 'purchaseUrls'
# Armadillo Cloak 'purchaseUrls'
# Armor Thrull 'purchaseUrls'
# Armor of Faith 'purchaseUrls'
# Armor of Thorns 'purchaseUrls'
# Armored Whirl Turtle 'purchaseUrls'
# Arrest 'purchaseUrls'
# Arrogant Wurm 'purchaseUrls'
# Artifact Blast 'purchaseUrls'
# Ascendant Evincar 'purchaseUrls'
# Ashen Ghoul 'purchaseUrls'
# Ashiok, Dream Render 'purchaseUrls'
# Ashling the Pilgrim Avatar 'purchaseUrls'
# Ashling, the Extinguisher Avatar 'purchaseUrls'
# Ashnod's Coupon 'purchaseUrls'
# Ashnod's Transmogrant 'purchaseUrls'
# Astral Arena 'purchaseUrls'
# Astral Slide 'purchaseUrls'
# Asylum Visitor 'purchaseUrls'
# Atarka's Command 'purchaseUrls'
# Atarka, World Render 'purchaseUrls'
# Attunement 'purchaseUrls'
# Augur of Bolas 'purchaseUrls'
# Aurochs 'purchaseUrls'
# Authority of the Consuls 'purchaseUrls'
# Avacyn's Judgment 'purchaseUrls'
# Avacyn's Pilgrim 'purchaseUrls'
# Avalanche Riders 'purchaseUrls'
# Avalanche Tusker 'purchaseUrls'
# Avatar of Discord 'purchaseUrls'
# Avatar of the Resolute 'purchaseUrls'
# Awaken the Sky Tyrant 'purchaseUrls'
# Awakening of Vitu-Ghazi 'purchaseUrls'
# Awoken Horror 'purchaseUrls'
# Axe of the Warmonger 'purchaseUrls'
# Axegrinder Giant 'purchaseUrls'
# Azcanta, the Sunken Ruin 'purchaseUrls'
# Bad River 'purchaseUrls'
# Balan, Wandering Knight 'purchaseUrls'
# Balduvian Conjurer 'purchaseUrls'
# Balduvian Hydra 'purchaseUrls'
# Baleful Force 'purchaseUrls'
# Banewasp Affliction 'purchaseUrls'
# Banisher Priest 'purchaseUrls'
# Banshee of the Dread Choir 'purchaseUrls'
# Bant 'purchaseUrls'
# Barktooth Warbeard 'purchaseUrls'
# Barrage Tyrant 'purchaseUrls'
# Bartel Runeaxe 'purchaseUrls'
# Basal Thrull 'purchaseUrls'
# Basalt Monolith 'purchaseUrls'
# Basking Rootwalla 'purchaseUrls'
# Bastion Protector 'purchaseUrls'
# Battering Ram 'purchaseUrls'
# Beast Attack 'purchaseUrls'
# Beastcaller Savant 'purchaseUrls'
# Because I Have Willed It 'purchaseUrls'
# Beetleback Chief 'purchaseUrls'
# Behemoth Sledge 'purchaseUrls'
# Behold My Grandeur 'purchaseUrls'
# Behold the Beyond 'purchaseUrls'
# Behold the Power of Destruction 'purchaseUrls'
# Benalish Trapper 'purchaseUrls'
# Benevolent Bodyguard 'purchaseUrls'
# Bestial Fury 'purchaseUrls'
# Betrayal of Flesh 'purchaseUrls'
# Bile Blight 'purchaseUrls'
# Binding Grasp 'purchaseUrls'
# Bioessence Hydra 'purchaseUrls'
# Birds of Paradise Avatar 'purchaseUrls'
# Bishop of Rebirth 'purchaseUrls'
# Black Sun's Zenith 'purchaseUrls'
# Blade of Selves 'purchaseUrls'
# Blaring Captain 'purchaseUrls'
# Blaring Recruiter 'purchaseUrls'
# Blast Zone 'purchaseUrls'
# Blasting Station 'purchaseUrls'
# Blastoderm 'purchaseUrls'
# Blazing Specter 'purchaseUrls'
# Blessed Reincarnation 'purchaseUrls'
# Blight 'purchaseUrls'
# Blight Herder 'purchaseUrls'
# Blighted Fen 'purchaseUrls'
# Blinding Radiance 'purchaseUrls'
# Blinkmoth Nexus 'purchaseUrls'
# Blood-Chin Fanatic 'purchaseUrls'
# Bloodcrazed Neonate 'purchaseUrls'
# Bloodforged Battle-Axe 'purchaseUrls'
# Bloodhill Bastion 'purchaseUrls'
# Bloodline Necromancer 'purchaseUrls'
# Bloodmark Mentor 'purchaseUrls'
# Bloodsoaked Champion 'purchaseUrls'
# Bloodspore Thrinax 'purchaseUrls'
# Bloodsworn Steward 'purchaseUrls'
# Bloodtracker 'purchaseUrls'
# Blooming Marsh 'purchaseUrls'
# Bog Humbugs 'purchaseUrls'
# Boil 'purchaseUrls'
# Bojuka Bog 'purchaseUrls'
# Bolas's Citadel 'purchaseUrls'
# Boltwing Marauder 'purchaseUrls'
# Bomat Courier 'purchaseUrls'
# Bonesplitter 'purchaseUrls'
# Boneyard Scourge 'purchaseUrls'
# Boreas Charger 'purchaseUrls'
# Boris Devilboon 'purchaseUrls'
# Bosh, Iron Golem Avatar 'purchaseUrls'
# Botanical Sanctum 'purchaseUrls'
# Bottle Gnomes 'purchaseUrls'
# Bow of the Hunter 'purchaseUrls'
# Bow to My Command 'purchaseUrls'
# Braids, Conjurer Adept Avatar 'purchaseUrls'
# Brain Freeze 'purchaseUrls'
# Brain in a Jar 'purchaseUrls'
# Brainstorm 'purchaseUrls'
# Brassclaw Orcs 'purchaseUrls'
# Brave the Elements 'purchaseUrls'
# Brawn 'purchaseUrls'
# Breath of Fire 'purchaseUrls'
# Breath of Malfegor 'purchaseUrls'
# Breeding Pit 'purchaseUrls'
# Briber's Purse 'purchaseUrls'
# Brilliant Halo 'purchaseUrls'
# Brilliant Plan 'purchaseUrls'
# Brindle Shoat 'purchaseUrls'
# Brine Shaman 'purchaseUrls'
# Bring to Light 'purchaseUrls'
# Bristling Hydra 'purchaseUrls'
# Brood Butcher 'purchaseUrls'
# Broodbirth Viper 'purchaseUrls'
# Brothers of Fire 'purchaseUrls'
# Browbeat 'purchaseUrls'
# Brudiclad, Telchor Engineer 'purchaseUrls'
# Brutal Expulsion 'purchaseUrls'
# Budoka Pupil 'purchaseUrls'
# Bull Cerodon 'purchaseUrls'
# Bull Hippo 'purchaseUrls'
# Burn from Within 'purchaseUrls'
# Burning Sun's Avatar 'purchaseUrls'
# Burning of Xinye 'purchaseUrls'
# Burning-Tree Bloodscale 'purchaseUrls'
# Burnt Offering 'purchaseUrls'
# Butcher of the Horde 'purchaseUrls'
# Bygone Bishop 'purchaseUrls'
# Cabal Ritual 'purchaseUrls'
# Calciderm 'purchaseUrls'
# Caldera Lake 'purchaseUrls'
# Call the Bloodline 'purchaseUrls'
# Caller of the Pack 'purchaseUrls'
# Candelabra of Tawnos 'purchaseUrls'
# Canopy Vista 'purchaseUrls'
# Cao Ren, Wei Commander 'purchaseUrls'
# Captured by the Consulate 'purchaseUrls'
# Careful Study 'purchaseUrls'
# Caribou Range 'purchaseUrls'
# Carnival Hellsteed 'purchaseUrls'
# Carnivorous Plant 'purchaseUrls'
# Carnophage 'purchaseUrls'
# Carrion Beetles 'purchaseUrls'
# Cast Down 'purchaseUrls'
# Castigate 'purchaseUrls'
# Casualties of War 'purchaseUrls'
# Cataclysmic Gearhulk 'purchaseUrls'
# Cathedral of War 'purchaseUrls'
# Celestial Archon 'purchaseUrls'
# Celestine Reef 'purchaseUrls'
# Centaur Archer 'purchaseUrls'
# Centaur Vinecrasher 'purchaseUrls'
# Cephalid Coliseum 'purchaseUrls'
# Chain Lightning 'purchaseUrls'
# Chainer's Edict 'purchaseUrls'
# Chains of Mephistopheles 'purchaseUrls'
# Chakram Retriever 'purchaseUrls'
# Chakram Slinger 'purchaseUrls'
# Chandra's Ignition 'purchaseUrls'
# Chandra's Spitfire 'purchaseUrls'
# Chandra, Fire Artisan 'purchaseUrls'
# Chandra, Gremlin Wrangler 'purchaseUrls'
# Chandra, Torch of Defiance 'purchaseUrls'
# Chaos Warp 'purchaseUrls'
# Chaotic Aether 'purchaseUrls'
# Chief of the Foundry 'purchaseUrls'
# Chill 'purchaseUrls'
# Chimeric Idol 'purchaseUrls'
# Cho-Manno, Revolutionary 'purchaseUrls'
# Choke 'purchaseUrls'
# Choked Estuary 'purchaseUrls'
# Choking Sands 'tcgplayer'
# Choose Your Champion 'purchaseUrls'
# Choose Your Demise 'purchaseUrls'
# Chronatog Avatar 'purchaseUrls'
# Chub Toad 'purchaseUrls'
# Cinder Glade 'purchaseUrls'
# Cinder Pyromancer 'purchaseUrls'
# Circle of Protection: Black 'tcgplayer'
# Circle of Protection: Red 'tcgplayer'
# Circular Logic 'purchaseUrls'
# Citanul Druid 'purchaseUrls'
# City of Traitors 'purchaseUrls'
# Clash of Wills 'purchaseUrls'
# Claws of Wirewood 'purchaseUrls'
# Cleanse 'purchaseUrls'
# Cleansing Screech 'purchaseUrls'
# Cliffside Market 'purchaseUrls'
# Cloak of Confusion 'purchaseUrls'
# Cloak of Mists 'purchaseUrls'
# Cloak of the Philosopher 'purchaseUrls'
# Cloud Pirates 'purchaseUrls'
# Cloud Sprite 'purchaseUrls'
# Cloud of Faeries 'purchaseUrls'
# Cloudcrown Oak 'purchaseUrls'
# Cloudpost 'purchaseUrls'
# Coastal Tower 'purchaseUrls'
# Coffin Purge 'purchaseUrls'
# Colorful Feiyi Sparrow 'purchaseUrls'
# Colossal Whale 'purchaseUrls'
# Combat Medic 'purchaseUrls'
# Combustible Gearhulk 'purchaseUrls'
# Command Beacon 'purchaseUrls'
# Command Tower 'purchaseUrls'
# Command the Dreadhorde 'purchaseUrls'
# Commence the Endgame 'purchaseUrls'
# Compost 'purchaseUrls'
# Compulsive Research 'purchaseUrls'
# Concealed Courtyard 'purchaseUrls'
# Conclave Naturalists 'purchaseUrls'
# Condemn 'purchaseUrls'
# Condescend 'purchaseUrls'
# Conduit of Ruin 'purchaseUrls'
# Confidence from Strength 'purchaseUrls'
# Confirm Suspicions 'purchaseUrls'
# Confiscation Coup 'purchaseUrls'
# Confront the Assault 'purchaseUrls'
# Conqueror's Foothold 'purchaseUrls'
# Conqueror's Galleon 'purchaseUrls'
# Constant Mists 'purchaseUrls'
# Consuming Rage 'purchaseUrls'
# Contagion Clasp 'purchaseUrls'
# Containment Priest 'purchaseUrls'
# Corpse Augur 'purchaseUrls'
# Corpse Dance 'purchaseUrls'
# Corpse Knight 'tcgplayer'
# Corrupt 'purchaseUrls'
# Corrupted Grafstone 'purchaseUrls'
# Counterbore 'purchaseUrls'
# Counterspell 'tcgplayer'
# Coveted Jewel 'purchaseUrls'
# Covetous Dragon 'purchaseUrls'
# Crash of Rhino Beetles 'purchaseUrls'
# Crater Elemental 'purchaseUrls'
# Crater Hellion 'purchaseUrls'
# Crater's Claws 'purchaseUrls'
# Crimson Honor Guard 'purchaseUrls'
# Crimson Kobolds 'purchaseUrls'
# Crookshank Kobolds 'purchaseUrls'
# Crovax the Cursed 'purchaseUrls'
# Crowd of Cinders 'purchaseUrls'
# Crucible of Fire 'purchaseUrls'
# Cruel Bargain 'purchaseUrls'
# Cruel Cut 'purchaseUrls'
# Cruel Tutor 'purchaseUrls'
# Crumble 'tcgplayer'
# Crumbling Necropolis 'purchaseUrls'
# Crumbling Vestige 'purchaseUrls'
# Crypt Angel 'purchaseUrls'
# Cryptborn Horror 'purchaseUrls'
# Cryptolith Rite 'purchaseUrls'
# Crystalline Sliver 'purchaseUrls'
# Cultivate 'purchaseUrls'
# Cultivator of Blades 'purchaseUrls'
# Cultivator's Caravan 'purchaseUrls'
# Cunning Sparkmage 'purchaseUrls'
# Cunning Wish 'purchaseUrls'
# Curse of Bounty 'purchaseUrls'
# Curse of Disturbance 'purchaseUrls'
# Curse of Opulence 'purchaseUrls'
# Curse of Thirst 'purchaseUrls'
# Curse of Verbosity 'purchaseUrls'
# Curse of Vitality 'purchaseUrls'
# Curse of the Bloody Tome 'purchaseUrls'
# Cursed Rack 'purchaseUrls'
# Cursed Scroll 'purchaseUrls'
# Dack Fayden 'purchaseUrls'
# Daggerclaw Imp 'purchaseUrls'
# Daghatar the Adamant 'purchaseUrls'
# Dakkon Blackblade 'purchaseUrls'
# Dakkon Blackblade Avatar 'purchaseUrls'
# Damnable Pact 'purchaseUrls'
# Damnation 'purchaseUrls'
# Dance of Flame 'purchaseUrls'
# Dance of Panic 'purchaseUrls'
# Dance of the Dead 'purchaseUrls'
# Dance, Pathetic Marionette 'purchaseUrls'
# Daretti, Scrap Savant 'purchaseUrls'
# Dark Petition 'purchaseUrls'
# Darksteel Gargoyle 'purchaseUrls'
# Darksteel Juggernaut 'purchaseUrls'
# Darksteel Sentinel 'purchaseUrls'
# Dauntless Dourbark 'purchaseUrls'
# Dauntless Escort Avatar 'purchaseUrls'
# Dauthi Mercenary 'purchaseUrls'
# Dauthi Slayer 'purchaseUrls'
# Davriel, Rogue Shadowmage 'purchaseUrls'
# Dawnbreak Reclaimer 'purchaseUrls'
# Daxos the Returned 'purchaseUrls'
# Daxos's Torment 'purchaseUrls'
# Deadbridge Goliath 'purchaseUrls'
# Deadlock Trap 'purchaseUrls'
# Deadly Tempest 'purchaseUrls'
# Death Pit Offering 'purchaseUrls'
# Deathbringer Thoctar 'purchaseUrls'
# Deathcap Cultivator 'purchaseUrls'
# Deathless Angel 'purchaseUrls'
# Debilitating Injury 'purchaseUrls'
# Deceiver Exarch 'purchaseUrls'
# Declaration in Stone 'purchaseUrls'
# Decree of Pain 'purchaseUrls'
# Deep Analysis 'purchaseUrls'
# Deep Spawn 'purchaseUrls'
# Defiant Bloodlord 'purchaseUrls'
# Deflecting Palm 'purchaseUrls'
# Deft Duelist 'purchaseUrls'
# Delight in the Hunt 'purchaseUrls'
# Deliver Unto Evil 'purchaseUrls'
# Deluge 'purchaseUrls'
# Demon of Dark Schemes 'purchaseUrls'
# Demonic Consultation 'purchaseUrls'
# Demonic Torment 'purchaseUrls'
# Denizen of the Deep 'purchaseUrls'
# Depala, Pilot Exemplar 'purchaseUrls'
# Deranged Hermit 'purchaseUrls'
# Derelor 'purchaseUrls'
# Derevi, Empyrial Tactician 'purchaseUrls'
# Descend on the Prey 'purchaseUrls'
# Descend upon the Sinful 'purchaseUrls'
# Desecration Elemental 'purchaseUrls'
# Desertion 'purchaseUrls'
# Desolation Twin 'purchaseUrls'
# Despise 'purchaseUrls'
# Despoiler of Souls 'purchaseUrls'
# Despotic Scepter 'purchaseUrls'
# Detonate 'purchaseUrls'
# Devils' Playground 'purchaseUrls'
# Devout Witness 'purchaseUrls'
# Diabolic Servitude 'purchaseUrls'
# Diabolical Salvation 'purchaseUrls'
# Diamond Faerie Avatar 'purchaseUrls'
# Diaochan, Artful Beauty 'purchaseUrls'
# Diminishing Returns 'purchaseUrls'
# Dimir Charm 'purchaseUrls'
# Diregraf Colossus 'purchaseUrls'
# Dirtcowl Wurm 'purchaseUrls'
# Dirty Wererat 'purchaseUrls'
# Disenchant 'tcgplayer'
# Disharmony 'purchaseUrls'
# Disintegrate 'tcgplayer'
# Dismember 'purchaseUrls'
# Disorienting Glower 'purchaseUrls'
# Disrupt Decorum 'purchaseUrls'
# Dissolve 'purchaseUrls'
# Distract the Hydra 'purchaseUrls'
# Divine Intervention 'purchaseUrls'
# Divine Transformation 'purchaseUrls'
# Domri, Anarch of Bolas 'purchaseUrls'
# Dovin Baan 'purchaseUrls'
# Dovin's Veto 'purchaseUrls'
# Dovin, Hand of Control 'purchaseUrls'
# Dowsing Dagger 'purchaseUrls'
# Drafna's Restoration 'purchaseUrls'
# Dragon Broodmother 'purchaseUrls'
# Dragon Fodder 'purchaseUrls'
# Dragon Roost 'purchaseUrls'
# Dragon Throne of Tarkir 'purchaseUrls'
# Dragon's Presence 'purchaseUrls'
# Dragon-Style Twins 'purchaseUrls'
# Dragonlair Spider 'purchaseUrls'
# Dragonlord Atarka 'purchaseUrls'
# Dragonlord Dromoka 'purchaseUrls'
# Dragonlord Kolaghan 'purchaseUrls'
# Dragonlord Ojutai 'purchaseUrls'
# Dragonlord Silumgar 'purchaseUrls'
# Dragonlord's Servant 'purchaseUrls'
# Dragonmaster Outcast 'purchaseUrls'
# Dragonscale Boon 'purchaseUrls'
# Dragonscale General 'purchaseUrls'
# Drana, Liberator of Malakir 'purchaseUrls'
# Dread Summons 'purchaseUrls'
# Dreadhorde Arcanist 'purchaseUrls'
# Dreadhorde Butcher 'purchaseUrls'
# Dreadhorde Invasion 'purchaseUrls'
# Dreadship Reef 'purchaseUrls'
# Dream Pillager 'purchaseUrls'
# Dreampod Druid 'purchaseUrls'
# Dreams of the Dead 'purchaseUrls'
# Drench the Soil in Their Blood 'purchaseUrls'
# Drift of the Dead 'purchaseUrls'
# Drogskol Cavalry 'purchaseUrls'
# Dromoka's Command 'purchaseUrls'
# Dromoka, the Eternal 'purchaseUrls'
# Drove of Elves 'purchaseUrls'
# Drown in Shapelessness 'purchaseUrls'
# Drowner of Hope 'purchaseUrls'
# Drownyard Temple 'purchaseUrls'
# Dryad Militant 'purchaseUrls'
# Dubious Challenge 'purchaseUrls'
# Dungeon Master 'purchaseUrls'
# Duplicant 'purchaseUrls'
# Dusk Imp 'purchaseUrls'
# Duskdale Wurm 'purchaseUrls'
# Dust Stalker 'purchaseUrls'
# Dust to Dust 'purchaseUrls'
# Dwarven Catapult 'purchaseUrls'
# Dwarven Soldier 'purchaseUrls'
# Dwynen, Gilt-Leaf Daen 'purchaseUrls'
# Dynavolt Tower 'purchaseUrls'
# Earth-Origin Yak 'purchaseUrls'
# Earthlink 'purchaseUrls'
# Earthshaking Si 'purchaseUrls'
# Eater of Hope 'purchaseUrls'
# Eater of the Dead 'purchaseUrls'
# Ebon Praetor 'purchaseUrls'
# Echo Storm 'purchaseUrls'
# Edgar Markov 'purchaseUrls'
# Edge of Malacol 'purchaseUrls'
# Edric, Spymaster of Trest 'purchaseUrls'
# Eight-and-a-Half-Tails Avatar 'purchaseUrls'
# Eladamri, Lord of Leaves Avatar 'purchaseUrls'
# Elder Land Wurm 'purchaseUrls'
# Electrostatic Pummeler 'purchaseUrls'
# Elemental Augury 'purchaseUrls'
# Eliminate the Competition 'purchaseUrls'
# Elite Inquisitor 'purchaseUrls'
# Eloren Wilds 'purchaseUrls'
# Elspeth, Sun's Champion 'purchaseUrls'
# Elusive Tormentor 'purchaseUrls'
# Elven Lyre 'purchaseUrls'
# Elven Riders 'purchaseUrls'
# Elvish Champion Avatar 'purchaseUrls'
# Elvish Farmer 'purchaseUrls'
# Elvish Hunter 'purchaseUrls'
# Elvish Lyrist 'purchaseUrls'
# Ember Swallower 'purchaseUrls'
# Embermaw Hellion 'purchaseUrls'
# Embrace My Diabolical Vision 'purchaseUrls'
# Emerald Charm 'tcgplayer'
# Emeria Shepherd 'purchaseUrls'
# Emissary of Grudges 'purchaseUrls'
# Empyrial Storm 'purchaseUrls'
# Emrakul, the Aeons Torn 'purchaseUrls'
# Enchanter's Bane 'purchaseUrls'
# Encroaching Wastes 'purchaseUrls'
# Endless Atlas 'purchaseUrls'
# Endless One 'purchaseUrls'
# Energy Arc 'purchaseUrls'
# Energy Field 'purchaseUrls'
# Energy Storm 'purchaseUrls'
# Enervate 'purchaseUrls'
# Engulfing Flames 'purchaseUrls'
# Enigma Sphinx Avatar 'purchaseUrls'
# Enlightened Tutor 'purchaseUrls'
# Enter the God-Eternals 'purchaseUrls'
# Entreat the Dead 'purchaseUrls'
# Ephemeron 'purchaseUrls'
# Epic Struggle 'purchaseUrls'
# Epiphany at the Drownyard 'purchaseUrls'
# Erhnam Djinn Avatar 'purchaseUrls'
# Errantry 'purchaseUrls'
# Erratic Portal 'purchaseUrls'
# Essence Extraction 'purchaseUrls'
# Essence Filter 'purchaseUrls'
# Essence Flare 'purchaseUrls'
# Estrid's Invocation 'purchaseUrls'
# Estrid, the Masked 'purchaseUrls'
# Etched Oracle Avatar 'purchaseUrls'
# Eternal Dragon 'purchaseUrls'
# Eternal Witness 'purchaseUrls'
# Eureka 'purchaseUrls'
# Ever After 'purchaseUrls'
# Ever-Watching Threshold 'purchaseUrls'
# Every Dream a Nightmare 'purchaseUrls'
# Every Hope Shall Vanish 'purchaseUrls'
# Every Last Vestige Shall Rot 'purchaseUrls'
# Evil Comes to Fruition 'purchaseUrls'
# Evil Presents 'purchaseUrls'
# Evincar's Justice 'purchaseUrls'
# Evolutionary Leap 'purchaseUrls'
# Evolving Wilds 'purchaseUrls'
# Exert Influence 'purchaseUrls'
# Exhume 'purchaseUrls'
# Exile 'tcgplayer'
# Experiment One 'purchaseUrls'
# Expunge 'purchaseUrls'
# Exquisite Firecraft 'purchaseUrls'
# Eyeblight's Ending 'purchaseUrls'
# Ezuri's Predation 'purchaseUrls'
# Ezuri, Claw of Progress 'purchaseUrls'
# Fact or Fiction 'purchaseUrls'
# Faithless Looting 'purchaseUrls'
# Falkenrath Gorger 'purchaseUrls'
# Fallen Angel Avatar 'purchaseUrls'
# Falter 'purchaseUrls'
# Famine 'purchaseUrls'
# Fanatic of Xenagos 'purchaseUrls'
# Farhaven Elf 'purchaseUrls'
# Farrel's Mantle 'purchaseUrls'
# Farrel's Zealot 'purchaseUrls'
# Fatal Push 'purchaseUrls'
# Fated Conflagration 'purchaseUrls'
# Fated Intervention 'purchaseUrls'
# Fateful Showdown 'purchaseUrls'
# Fathom Feeder 'purchaseUrls'
# Fblthp, the Lost 'purchaseUrls'
# Feather, the Redeemed 'purchaseUrls'
# Feed the Machine 'purchaseUrls'
# Feeding Grounds 'purchaseUrls'
# Feiyi Snake 'purchaseUrls'
# Feldon's Cane 'purchaseUrls'
# Feral Roar 'purchaseUrls'
# Feral Thallid 'purchaseUrls'
# Ferocious Zheng 'purchaseUrls'
# Fevered Visions 'purchaseUrls'
# Field of Dreams 'purchaseUrls'
# Fields of Summer 'purchaseUrls'
# Fierce Invocation 'purchaseUrls'
# Fiery Confluence 'purchaseUrls'
# Fiery Temper 'purchaseUrls'
# Figure of Destiny 'purchaseUrls'
# Figure of Destiny Avatar 'purchaseUrls'
# Finale of Devastation 'purchaseUrls'
# Finale of Eternity 'purchaseUrls'
# Finale of Glory 'purchaseUrls'
# Finale of Promise 'purchaseUrls'
# Finale of Revelation 'purchaseUrls'
# Fire Covenant 'purchaseUrls'
# Fire Diamond 'purchaseUrls'
# Fire Dragon 'purchaseUrls'
# Fire Sprites 'purchaseUrls'
# Fire-Omen Crane 'purchaseUrls'
# Fireblast 'purchaseUrls'
# Firemane Avenger 'purchaseUrls'
# Fireslinger 'purchaseUrls'
# Firesong and Sunspeaker 'purchaseUrls'
# Firespout 'purchaseUrls'
# Firestorm Phoenix 'purchaseUrls'
# Fissure 'purchaseUrls'
# Flame Sweep 'tcgplayer'
# Flameblade Angel 'purchaseUrls'
# Flamekin Brawler 'purchaseUrls'
# Flamerush Rider 'purchaseUrls'
# Flametongue Kavu 'purchaseUrls'
# Flametongue Kavu Avatar 'purchaseUrls'
# Flamewake Phoenix 'purchaseUrls'
# Flaying Tendrils 'purchaseUrls'
# Fleetwheel Cruiser 'purchaseUrls'
# Flesh-Eater Imp 'purchaseUrls'
# Flood Plain 'purchaseUrls'
# Flowstone Flood 'purchaseUrls'
# Flowstone Hellion 'purchaseUrls'
# Flowstone Sculpture 'purchaseUrls'
# Flusterstorm 'purchaseUrls'
# Flying Crane Technique 'purchaseUrls'
# Foe-Razer Regent 'purchaseUrls'
# For Each of You, a Gift 'purchaseUrls'
# Forbidden Alchemy 'purchaseUrls'
# Forbidden Lore 'purchaseUrls'
# Forbidding Watchtower 'purchaseUrls'
# Foreboding Ruins 'purchaseUrls'
# Forge of Heroes 'purchaseUrls'
# Forgestoker Dragon 'purchaseUrls'
# Forgotten Creation 'purchaseUrls'
# Forgotten Lore 'purchaseUrls'
# Forked Lightning 'purchaseUrls'
# Formless Nurturing 'purchaseUrls'
# Forsaken Wastes 'tcgplayer'
# Fortified Village 'purchaseUrls'
# Fortunate Few 'purchaseUrls'
# Foundry Champion 'purchaseUrls'
# Fractured Identity 'purchaseUrls'
# Frantic Search 'purchaseUrls'
# Fraternal Exaltation 'purchaseUrls'
# Frenetic Efreet 'tcgplayer'
# Frenetic Efreet Avatar 'purchaseUrls'
# Freyalise, Llanowar's Fury 'purchaseUrls'
# From Beyond 'purchaseUrls'
# From Under the Floorboards 'purchaseUrls'
# Frost Giant 'purchaseUrls'
# Frost Walker 'purchaseUrls'
# Fruitcake Elemental 'purchaseUrls'
# Fumarole 'purchaseUrls'
# Fume Spitter 'purchaseUrls'
# Fumigate 'purchaseUrls'
# Fungal Bloom 'purchaseUrls'
# Fungal Reaches 'purchaseUrls'
# Fungal Shambler 'purchaseUrls'
# Furnace Layer 'purchaseUrls'
# Fury Storm 'purchaseUrls'
# Fyndhorn Pollen 'purchaseUrls'
# Gaea's Avenger 'purchaseUrls'
# Gaea's Cradle 'purchaseUrls'
# Gaea's Embrace 'purchaseUrls'
# Gaea's Herald 'purchaseUrls'
# Gaea's Revenge 'purchaseUrls'
# Gahiji, Honored One 'purchaseUrls'
# Galecaster Colossus 'purchaseUrls'
# Gamble 'purchaseUrls'
# Game Trail 'purchaseUrls'
# Game of Chaos 'purchaseUrls'
# Gangrenous Zombies 'purchaseUrls'
# Gargantuan Gorilla 'purchaseUrls'
# Garruk the Slayer 'purchaseUrls'
# Garza Zol, Plague Queen 'purchaseUrls'
# Gate to Phyrexia 'purchaseUrls'
# Gavony 'purchaseUrls'
# Geier Reach Bandit 'purchaseUrls'
# Genesis Hydra 'purchaseUrls'
# Genesis Storm 'purchaseUrls'
# Geode Golem 'purchaseUrls'
# Geralf's Masterpiece 'purchaseUrls'
# Gerrard's Battle Cry 'purchaseUrls'
# Gerrard's Verdict 'purchaseUrls'
# Ghastly Demise 'purchaseUrls'
# Ghave, Guru of Spores 'purchaseUrls'
# Ghazbán Ogre 'tcgplayer'
# Ghirapur Orrery 'purchaseUrls'
# Ghired, Conclave Exile 'purchaseUrls'
# Ghitu Encampment 'purchaseUrls'
# Ghor-Clan Savage 'purchaseUrls'
# Ghost-Lit Raider 'purchaseUrls'
# Ghostfire Blade 'purchaseUrls'
# Ghostly Prison 'purchaseUrls'
# Ghosts of the Damned 'purchaseUrls'
# Giant Badger 'purchaseUrls'
# Giant Mantis 'purchaseUrls'
# Giant Strength 'purchaseUrls'
# Gideon Blackblade 'purchaseUrls'
# Gideon of the Trials 'purchaseUrls'
# Gideon's Phalanx 'purchaseUrls'
# Gideon, Ally of Zendikar 'purchaseUrls'
# Gifts Given 'purchaseUrls'
# Gigantoplasm 'purchaseUrls'
# Gigapede 'purchaseUrls'
# Gilt-Leaf Winnower 'purchaseUrls'
# Gitaxian Probe 'purchaseUrls'
# Glacial Crevasses 'purchaseUrls'
# Glaze Fiend 'purchaseUrls'
# Gleemox 'purchaseUrls'
# Glen Elendra 'purchaseUrls'
# Glimmerpoint Stag 'purchaseUrls'
# Glimmervoid Basin 'purchaseUrls'
# Glissa, the Traitor 'purchaseUrls'
# Glistener Elf 'purchaseUrls'
# Global Ruin 'purchaseUrls'
# Glory 'purchaseUrls'
# Go for the Throat 'purchaseUrls'
# Goblin Artisans 'purchaseUrls'
# Goblin Bruiser 'purchaseUrls'
# Goblin Chirurgeon 'purchaseUrls'
# Goblin Commando 'purchaseUrls'
# Goblin Gang Leader 'purchaseUrls'
# Goblin General 'purchaseUrls'
# Goblin Legionnaire 'purchaseUrls'
# Goblin Mutant 'purchaseUrls'
# Goblin Patrol 'purchaseUrls'
# Goblin Piledriver 'purchaseUrls'
# Goblin Settler 'purchaseUrls'
# Goblin Sharpshooter 'purchaseUrls'
# Goblin Ski Patrol 'purchaseUrls'
# Goblin Sleigh Ride 'purchaseUrls'
# Goblin Trenches 'purchaseUrls'
# Goblin Warchief 'purchaseUrls'
# Goblin Warchief Avatar 'purchaseUrls'
# Goblin Wizard 'purchaseUrls'
# Goblins of the Flarg 'purchaseUrls'
# God-Eternal Bontu 'purchaseUrls'
# God-Eternal Kefnet 'purchaseUrls'
# God-Eternal Oketra 'purchaseUrls'
# God-Eternal Rhonas 'purchaseUrls'
# Gold Myr 'purchaseUrls'
# Goldenglow Moth 'purchaseUrls'
# Goldmeadow 'purchaseUrls'
# Goldnight Castigator 'purchaseUrls'
# Golem's Heart 'purchaseUrls'
# Gonti, Lord of Luxury 'purchaseUrls'
# Gorm the Great 'purchaseUrls'
# Grafted Exoskeleton 'purchaseUrls'
# Grand Architect 'purchaseUrls'
# Grand Ossuary 'purchaseUrls'
# Grasp of Fate 'purchaseUrls'
# Grasslands 'purchaseUrls'
# Graveblade Marauder 'purchaseUrls'
# Gravestorm 'purchaseUrls'
# Great Oak Guardian 'purchaseUrls'
# Greater Realm of Preservation 'purchaseUrls'
# Greenwarden of Murasa 'purchaseUrls'
# Greenweaver Druid 'purchaseUrls'
# Grim Haruspex 'purchaseUrls'
# Grim Monolith 'purchaseUrls'
# Grimgrin, Corpse-Born 'purchaseUrls'
# Grimlock, Dinobot Leader 'purchaseUrls'
# Grimlock, Ferocious King 'purchaseUrls'
# Grindstone 'purchaseUrls'
# Grinning Demon Avatar 'purchaseUrls'
# Grisly Salvage 'purchaseUrls'
# Grixis 'purchaseUrls'
# Grixis Battlemage 'purchaseUrls'
# Grizzly Fate 'purchaseUrls'
# Grove of the Dreampods 'purchaseUrls'
# Grove of the Guardian 'purchaseUrls'
# Growing Rites of Itlimoc 'purchaseUrls'
# Grown from the Stump 'purchaseUrls'
# Gruesome Slaughter 'purchaseUrls'
# Gruul Guildmage 'purchaseUrls'
# Gruul Nodorog 'purchaseUrls'
# Gruul Scrapper 'purchaseUrls'
# Guardian of Tazeem 'purchaseUrls'
# Guardian's Magemark 'purchaseUrls'
# Gush 'purchaseUrls'
# Gustcloak Harrier 'purchaseUrls'
# Guul Draz Assassin 'purchaseUrls'
# Guul Draz Overseer 'purchaseUrls'
# Gwendlyn Di Corci 'purchaseUrls'
# Gyrus, Waker of Corpses 'purchaseUrls'
# Haakon, Stromgald Scourge Avatar 'purchaseUrls'
# Halfdane 'purchaseUrls'
# Hallowed Ground 'purchaseUrls'
# Hammer of Nazahn 'purchaseUrls'
# Hammerheim 'purchaseUrls'
# Hand of Justice 'purchaseUrls'
# Hanweir Militia Captain 'purchaseUrls'
# Harbinger of the Hunt 'purchaseUrls'
# Hardened-Scale Armor 'purchaseUrls'
# Harmonize 'purchaseUrls'
# Harness the Storm 'purchaseUrls'
# Hatred 'purchaseUrls'
# Hazezon Tamar 'purchaseUrls'
# Headless Horseman 'purchaseUrls'
# Heart of Yavimaya 'tcgplayer'
# Heartwood Storyteller Avatar 'purchaseUrls'
# Heavenly Blademaster 'purchaseUrls'
# Heavenly Qilin 'purchaseUrls'
# Hecatomb 'purchaseUrls'
# Hedge Troll 'purchaseUrls'
# Hedron Fields of Agadeem 'purchaseUrls'
# Heir of the Wilds 'purchaseUrls'
# Heirloom Blade 'purchaseUrls'
# Hell's Caretaker Avatar 'purchaseUrls'
# Hellfire 'purchaseUrls'
# Hellkite Charger 'purchaseUrls'
# Helm of Kaldra 'purchaseUrls'
# Herald of Anafenza 'purchaseUrls'
# Herald of the Host 'purchaseUrls'
# Herald's Horn 'purchaseUrls'
# Hermit Druid 'purchaseUrls'
# Hermit Druid Avatar 'purchaseUrls'
# Hero of Bladehold 'purchaseUrls'
# Hero of Goma Fada 'purchaseUrls'
# Hero's Downfall 'purchaseUrls'
# Hewed Stone Retainers 'purchaseUrls'
# Hibernation 'purchaseUrls'
# Hidden Dragonslayer 'purchaseUrls'
# High Sentinels of Arashin 'purchaseUrls'
# High Tide 'purchaseUrls'
# Higure, the Still Wind Avatar 'purchaseUrls'
# Hive Stirrings 'purchaseUrls'
# Hixus, Prison Warden 'purchaseUrls'
# Holy Light 'purchaseUrls'
# Homarid Spawning Bed 'purchaseUrls'
# Homeward Path 'purchaseUrls'
# Honored Hierarch 'purchaseUrls'
# Hoodwink 'purchaseUrls'
# Horizon Boughs 'purchaseUrls'
# Hostage Taker 'purchaseUrls'
# Howlpack Alpha 'purchaseUrls'
# Huang Zhong, Shu General 'purchaseUrls'
# Huatli, the Sun's Heart 'purchaseUrls'
# Hulking Goblin 'purchaseUrls'
# Hull Breach 'purchaseUrls'
# Hunding Gjornersen 'purchaseUrls'
# Hungry Lynx 'purchaseUrls'
# Hurricane 'purchaseUrls'
# Hyalopterous Lemure 'purchaseUrls'
# Hydra's Impenetrable Hide 'purchaseUrls'
# Hydroblast 'tcgplayer'
# Hymn of Rebirth 'purchaseUrls'
# Hymn to Tourach 'purchaseUrls'
# Hypersonic Dragon 'purchaseUrls'
# I Bask in Your Silent Awe 'purchaseUrls'
# I Call on the Ancient Magics 'purchaseUrls'
# I Delight in Your Convulsions 'purchaseUrls'
# I Know All, I See All 'purchaseUrls'
# Icatian Javelineers 'purchaseUrls'
# Icatian Lieutenant 'purchaseUrls'
# Icatian Phalanx 'purchaseUrls'
# Icatian Scout 'purchaseUrls'
# Icatian Town 'purchaseUrls'
# Ice Floe 'purchaseUrls'
# Iceberg 'purchaseUrls'
# Icequake 'purchaseUrls'
# Ichiga, Who Topples Oaks 'purchaseUrls'
# Ichorid 'purchaseUrls'
# Icy Blast 'purchaseUrls'
# Icy Prison 'purchaseUrls'
# Ignite the Beacon 'purchaseUrls'
# Ignite the Cloneforge! 'purchaseUrls'
# Ilharg, the Raze-Boar 'purchaseUrls'
# Illusionary Forces 'purchaseUrls'
# Illusionary Wall 'purchaseUrls'
# Illusions of Grandeur 'purchaseUrls'
# Illusory Ambusher 'purchaseUrls'
# Immaculate Magistrate 'purchaseUrls'
# Immersturm 'purchaseUrls'
# Immortal Phoenix 'purchaseUrls'
# Impelled Giant 'purchaseUrls'
# Impetuous Protege 'purchaseUrls'
# Imprison This Insolent Wretch 'purchaseUrls'
# Impulsive Charge 'purchaseUrls'
# Impulsive Destruction 'purchaseUrls'
# Impulsive Return 'purchaseUrls'
# In the Eye of Chaos 'purchaseUrls'
# Inalla, Archmage Ritualist 'purchaseUrls'
# Incinerate 'tcgplayer'
# Incorrigible Youths 'purchaseUrls'
# Indrik Stomphowler 'purchaseUrls'
# Indulgent Tormentor 'purchaseUrls'
# Inexorable Blob 'purchaseUrls'
# Infernal Darkness 'purchaseUrls'
# Infiltrator's Magemark 'purchaseUrls'
# Ink-Eyes, Servant of Oni Avatar 'purchaseUrls'
# Inkmoth Nexus 'purchaseUrls'
# Innocent Blood 'purchaseUrls'
# Insidious Mist 'purchaseUrls'
# Insidious Will 'purchaseUrls'
# Inspiring Commander 'purchaseUrls'
# Inspiring Vantage 'purchaseUrls'
# Interplanar Tunnel 'purchaseUrls'
# Intervention of Keranos 'purchaseUrls'
# Into the Earthen Maw 'purchaseUrls'
# Intrepid Hero 'purchaseUrls'
# Introductions Are in Order 'purchaseUrls'
# Inventors' Fair 'purchaseUrls'
# Invigorate 'purchaseUrls'
# Invocation of Saint Traft 'purchaseUrls'
# Inzerva, Master of Insights 'purchaseUrls'
# Isle of Vesuva 'purchaseUrls'
# Isleback Spawn 'purchaseUrls'
# Isolated Watchtower 'purchaseUrls'
# Itlimoc, Cradle of the Sun 'purchaseUrls'
# Ivory Tower 'purchaseUrls'
# Ivorytusk Fortress 'purchaseUrls'
# Izzet Steam Maze 'purchaseUrls'
# Jace, Cunning Castaway 'purchaseUrls'
# Jace, Unraveler of Secrets 'purchaseUrls'
# Jace, Wielder of Mysteries 'purchaseUrls'
# Jacques le Vert 'purchaseUrls'
# Jagged Lightning 'purchaseUrls'
# Jagged-Scar Archers 'purchaseUrls'
# Jamuraan Lion 'purchaseUrls'
# Jareth, Leonine Titan 'purchaseUrls'
# Jaya Ballard Avatar 'purchaseUrls'
# Jaya, Venerated Firemage 'purchaseUrls'
# Jedit Ojanen 'purchaseUrls'
# Jedit Ojanen of Efrava 'purchaseUrls'
# Jeering Instigator 'purchaseUrls'
# Jeleva, Nephalia's Scourge 'purchaseUrls'
# Jerrard of the Closed Fist 'purchaseUrls'
# Jeskai Ascendancy 'purchaseUrls'
# Jeskai Infiltrator 'purchaseUrls'
# Jester's Mask 'purchaseUrls'
# Jeweled Amulet 'purchaseUrls'
# Jhoira of the Ghitu Avatar 'purchaseUrls'
# Jiang Yanggu 'purchaseUrls'
# Jiang Yanggu, Wildcrafter 'purchaseUrls'
# Johtull Wurm 'purchaseUrls'
# Jokulhaups 'purchaseUrls'
# Jolrael's Centaur 'tcgplayer'
# Journey for the Elixir 'purchaseUrls'
# Judge's Familiar 'purchaseUrls'
# Jund 'purchaseUrls'
# Jungle Shrine 'purchaseUrls'
# Jungle Wurm 'purchaseUrls'
# Juxtapose 'purchaseUrls'
# Kaalia of the Vast 'purchaseUrls'
# Kadena, Slinking Sorcerer 'purchaseUrls'
# Kaervek's Torch 'purchaseUrls'
# Kalemne's Captain 'purchaseUrls'
# Kalemne, Disciple of Iroas 'purchaseUrls'
# Kamahl, Pit Fighter 'purchaseUrls'
# Kambal, Consul of Allocation 'purchaseUrls'
# Karametra's Acolyte 'purchaseUrls'
# Karlov of the Ghost Council 'purchaseUrls'
# Karmic Guide 'purchaseUrls'
# Karn's Bastion 'purchaseUrls'
# Karn, Silver Golem 'purchaseUrls'
# Karn, the Great Creator 'purchaseUrls'
# Karona, False God Avatar 'purchaseUrls'
# Karplusan Giant 'purchaseUrls'
# Karrthus, Tyrant of Jund 'purchaseUrls'
# Kaseto, Orochi Archmage 'purchaseUrls'
# Kasmina, Enigmatic Mentor 'purchaseUrls'
# Kavu Chameleon 'purchaseUrls'
# Kaya, Bane of the Dead 'purchaseUrls'
# Keldon Necropolis 'purchaseUrls'
# Keldon Vandals 'purchaseUrls'
# Kessig 'purchaseUrls'
# Kestia, the Cultivator 'purchaseUrls'
# Key to the City 'purchaseUrls'
# Kezzerdrix 'purchaseUrls'
# Khalni Garden 'purchaseUrls'
# Kharasha Foothills 'purchaseUrls'
# Kheru Lich Lord 'purchaseUrls'
# Kheru Mind-Eater 'purchaseUrls'
# Khorvath Brightflame 'purchaseUrls'
# Killer Whale 'purchaseUrls'
# Kilnspire District 'purchaseUrls'
# Kindred Boon 'purchaseUrls'
# Kindred Charge 'purchaseUrls'
# Kindred Discovery 'purchaseUrls'
# Kindred Dominance 'purchaseUrls'
# Kindred Summons 'purchaseUrls'
# Kiora's Follower 'purchaseUrls'
# Kiora, Behemoth Beckoner 'purchaseUrls'
# Kiora, Master of the Depths 'purchaseUrls'
# Kiora, the Crashing Wave 'purchaseUrls'
# Kiss of the Amesha 'purchaseUrls'
# Kitchen Finks 'purchaseUrls'
# Kiyomaro, First to Stand 'purchaseUrls'
# Kjeldoran Elite Guard 'purchaseUrls'
# Kjeldoran Skycaptain 'purchaseUrls'
# Knight of New Alara 'purchaseUrls'
# Knight of the White Orchid 'purchaseUrls'
# Knights of Thorn 'purchaseUrls'
# Know Evil 'purchaseUrls'
# Know Naught but Fire 'purchaseUrls'
# Knowledge Vault 'purchaseUrls'
# Kobold Drill Sergeant 'purchaseUrls'
# Kobold Overlord 'purchaseUrls'
# Kobold Taskmaster 'purchaseUrls'
# Kobolds of Kher Keep 'purchaseUrls'
# Kolaghan's Command 'purchaseUrls'
# Kolaghan, the Storm's Fury 'purchaseUrls'
# Kothophed, Soul Hoarder 'purchaseUrls'
# Krark-Clan Ironworks 'purchaseUrls'
# Krav, the Unredeemed 'purchaseUrls'
# Krenko, Tin Street Kingpin 'purchaseUrls'
# Kresh the Bloodbraided Avatar 'purchaseUrls'
# Krosa 'purchaseUrls'
# Krosan Grip 'purchaseUrls'
# Krosan Verge 'purchaseUrls'
# Krosan Warchief 'purchaseUrls'
# Krovikan Fetish 'purchaseUrls'
# Krovikan Sorcerer 'purchaseUrls'
# Krovikan Vampire 'purchaseUrls'
# Kuldotha Forgemaster 'purchaseUrls'
# Kuldotha Phoenix 'purchaseUrls'
# Kytheon's Irregulars 'purchaseUrls'
# Lady Caleria 'purchaseUrls'
# Lady Evangela 'purchaseUrls'
# Lady Orca 'purchaseUrls'
# Lady Sun 'purchaseUrls'
# Lady Zhurong, Warrior Queen 'purchaseUrls'
# Lair of the Ashen Idol 'purchaseUrls'
# Lake of the Dead 'purchaseUrls'
# Land Equilibrium 'purchaseUrls'
# Lantern Scout 'purchaseUrls'
# Larceny 'purchaseUrls'
# Lash of the Tyrant 'purchaseUrls'
# Lathnu Hellion 'purchaseUrls'
# Lava Coil 'purchaseUrls'
# Legion's Landing 'purchaseUrls'
# Leonin Scimitar 'purchaseUrls'
# Leopard-Spotted Jiao 'purchaseUrls'
# Lesser Werewolf 'purchaseUrls'
# Lethe Lake 'purchaseUrls'
# Ley Weaver 'purchaseUrls'
# Leyline of the Meek 'purchaseUrls'
# Licia, Sanguine Tribune 'purchaseUrls'
# Life Chisel 'purchaseUrls'
# Lightning Dragon 'purchaseUrls'
# Lightning Greaves 'purchaseUrls'
# Lightning Hounds 'purchaseUrls'
# Lightning Rift 'purchaseUrls'
# Liliana's Triumph 'purchaseUrls'
# Liliana, Death's Majesty 'purchaseUrls'
# Liliana, Dreadhorde General 'purchaseUrls'
# Lilting Refrain 'purchaseUrls'
# Lim-Dûl's Vault 'purchaseUrls'
# Lingering Souls 'purchaseUrls'
# Lion's Eye Diamond 'purchaseUrls'
# Living Plane 'purchaseUrls'
# Living Twister 'purchaseUrls'
# Livonya Silone 'purchaseUrls'
# Llanowar 'purchaseUrls'
# Llanowar Elite 'purchaseUrls'
# Lobotomy 'purchaseUrls'
# Look Skyward and Despair 'purchaseUrls'
# Lord Windgrace 'purchaseUrls'
# Lord of Shatterskull Pass 'purchaseUrls'
# Lord of Tresserhorn 'purchaseUrls'
# Lore Weaver 'purchaseUrls'
# Lost Legacy 'purchaseUrls'
# Lost Order of Jarkeld 'purchaseUrls'
# Lost Soul 'purchaseUrls'
# Lost Vale 'purchaseUrls'
# Lovisa Coldeyes 'purchaseUrls'
# Lowland Oaf 'purchaseUrls'
# Loxodon Hierarch Avatar 'purchaseUrls'
# Loyal Apprentice 'purchaseUrls'
# Loyal Drake 'purchaseUrls'
# Loyal Guardian 'purchaseUrls'
# Loyal Retainers 'purchaseUrls'
# Loyal Subordinate 'purchaseUrls'
# Loyal Unicorn 'purchaseUrls'
# Lu Bu, Master-at-Arms 'purchaseUrls'
# Lu Su, Wu Advisor 'purchaseUrls'
# Ludevic's Abomination 'purchaseUrls'
# Ludevic's Test Subject 'purchaseUrls'
# Lumbering Falls 'purchaseUrls'
# Lumengrid Gargoyle 'purchaseUrls'
# Lurking Evil 'purchaseUrls'
# Lyzolda, the Blood Witch Avatar 'purchaseUrls'
# M'Odo, the Gnarled Oracle 'purchaseUrls'
# Ma Chao, Western Warrior 'purchaseUrls'
# Madcap Experiment 'purchaseUrls'
# Maelstrom Archangel Avatar 'purchaseUrls'
# Maelstrom Wanderer 'purchaseUrls'
# Magma Jet 'purchaseUrls'
# Magmaquake 'purchaseUrls'
# Magus of the Balance 'purchaseUrls'
# Magus of the Mind 'purchaseUrls'
# Magus of the Unseen 'purchaseUrls'
# Magus of the Wheel 'purchaseUrls'
# Make Yourself Useful 'purchaseUrls'
# Malfegor Avatar 'purchaseUrls'
# Mana Crypt 'purchaseUrls'
# Mana Drain 'purchaseUrls'
# Mana Matrix 'purchaseUrls'
# Mana Maze 'purchaseUrls'
# Mana Prism 'purchaseUrls'
# Mana Tithe 'purchaseUrls'
# Maralen of the Mornsong Avatar 'purchaseUrls'
# Marath, Will of the Wild 'purchaseUrls'
# March from the Tomb 'purchaseUrls'
# Marchesa, the Black Rose 'purchaseUrls'
# Mardu Ascendancy 'purchaseUrls'
# Mardu Shadowspear 'purchaseUrls'
# Mardu Strike Leader 'purchaseUrls'
# Marionette Master 'purchaseUrls'
# Marisi's Twinclaws 'purchaseUrls'
# Markov Dreadknight 'purchaseUrls'
# Maro Avatar 'purchaseUrls'
# Martyrs of Korlis 'purchaseUrls'
# Mass Calcify 'purchaseUrls'
# Massacre 'purchaseUrls'
# Massacre Girl 'purchaseUrls'
# Massacre Totem 'purchaseUrls'
# Master Trinketeer 'purchaseUrls'
# Master of Pearls 'purchaseUrls'
# Master of the Wild Hunt Avatar 'purchaseUrls'
# Master's Call 'purchaseUrls'
# Mastery of the Unseen 'purchaseUrls'
# Masticore 'purchaseUrls'
# Mathas, Fiend Seeker 'purchaseUrls'
# May Civilization Collapse 'purchaseUrls'
# Mayael the Anima 'purchaseUrls'
# Mayael the Anima Avatar 'purchaseUrls'
# Mayor of Avabruck 'purchaseUrls'
# Maze of Ith 'purchaseUrls'
# Mazirek, Kraul Death Priest 'purchaseUrls'
# Megantic Sliver 'purchaseUrls'
# Memnite 'purchaseUrls'
# Memoricide 'purchaseUrls'
# Memory Jar 'purchaseUrls'
# Mental Note 'purchaseUrls'
# Mercurial Pretender 'purchaseUrls'
# Meren of Clan Nel Toth 'purchaseUrls'
# Merrow Reejerey 'purchaseUrls'
# Mesmeric Trance 'purchaseUrls'
# Metallurgic Summonings 'purchaseUrls'
# Metalwork Colossus 'purchaseUrls'
# Metalworker 'purchaseUrls'
# Meteor Blast 'purchaseUrls'
# Meteor Shower 'purchaseUrls'
# Midnight Oil 'purchaseUrls'
# Mightstone 'purchaseUrls'
# Minamo 'purchaseUrls'
# Mind Slash 'purchaseUrls'
# Mind's Desire 'purchaseUrls'
# Mind's Eye 'purchaseUrls'
# Mindstab Thrull 'purchaseUrls'
# Minion of Leshrac 'purchaseUrls'
# Mirari's Wake 'purchaseUrls'
# Mirran Crusader 'purchaseUrls'
# Mirri the Cursed Avatar 'purchaseUrls'
# Mirri's Guile 'purchaseUrls'
# Mirri, Cat Warrior 'purchaseUrls'
# Mirri, Weatherlight Duelist 'purchaseUrls'
# Mirror Entity Avatar 'purchaseUrls'
# Mirror Match 'purchaseUrls'
# Mirror Universe 'purchaseUrls'
# Mirror of the Forebears 'purchaseUrls'
# Mirrored Depths 'purchaseUrls'
# Mishra's Helix 'purchaseUrls'
# Mishra's Toy Workshop 'purchaseUrls'
# Mishra's Workshop 'purchaseUrls'
# Mitotic Slime 'purchaseUrls'
# Mizzium Meddler 'purchaseUrls'
# Mizzium Tank 'purchaseUrls'
# Mizzix of the Izmagnus 'purchaseUrls'
# Mizzix's Mastery 'purchaseUrls'
# Moat 'purchaseUrls'
# Mobilized District 'purchaseUrls'
# Mogg Fanatic 'purchaseUrls'
# Molimo, Maro-Sorcerer 'purchaseUrls'
# Molten Slagheap 'purchaseUrls'
# Momir Vig, Simic Visionary Avatar 'purchaseUrls'
# Monastery Mentor 'purchaseUrls'
# Mondronen Shaman 'purchaseUrls'
# Monstrous Hound 'purchaseUrls'
# Moon-Eating Dog 'purchaseUrls'
# Moonglove Winnower 'purchaseUrls'
# Morbid Plunder 'purchaseUrls'
# Morinfen Avatar 'purchaseUrls'
# Morphic Tide 'purchaseUrls'
# Morphling 'purchaseUrls'
# Mortal Flesh Is Weak 'purchaseUrls'
# Mortarpod 'purchaseUrls'
# Mount Keralia 'purchaseUrls'
# Mountain Valley 'purchaseUrls'
# Mountain Yeti 'purchaseUrls'
# Mox Opal 'purchaseUrls'
# Mu Yanling 'purchaseUrls'
# Mudslide 'purchaseUrls'
# Mulldrifter 'purchaseUrls'
# Multiform Wonder 'purchaseUrls'
# Munda, Ambush Leader 'purchaseUrls'
# Murasa 'purchaseUrls'
# Murderous Redcap 'purchaseUrls'
# Murderous Redcap Avatar 'purchaseUrls'
# Murk Dwellers 'purchaseUrls'
# Muscle Sliver 'purchaseUrls'
# Musician 'purchaseUrls'
# Mutual Epiphany 'purchaseUrls'
# Mwonvuli Beast Tracker 'purchaseUrls'
# My Crushing Masterstroke 'purchaseUrls'
# My Forces Are Innumerable 'purchaseUrls'
# My Genius Knows No Bounds 'purchaseUrls'
# My Laughter Echoes 'purchaseUrls'
# My Undead Horde Awakens 'purchaseUrls'
# My Wish Is Your Command 'purchaseUrls'
# Mycoid Shepherd 'purchaseUrls'
# Myr Enforcer 'purchaseUrls'
# Myr Sire 'purchaseUrls'
# Mystic Confluence 'purchaseUrls'
# Mystic Remora 'purchaseUrls'
# Mystic Zealot 'purchaseUrls'
# Myth Realized 'purchaseUrls'
# Myth Unbound 'purchaseUrls'
# Márton Stromgald 'purchaseUrls'
# Naar Isle 'purchaseUrls'
# Nahiri, Storm of Stone 'purchaseUrls'
# Nahiri, the Harbinger 'purchaseUrls'
# Nahiri, the Lithomancer 'purchaseUrls'
# Nalathni Dragon 'purchaseUrls'
# Nameless Inversion 'purchaseUrls'
# Narset's Reversal 'purchaseUrls'
# Narset, Enlightened Master 'purchaseUrls'
# Narset, Parter of Veils 'purchaseUrls'
# Nature Demands an Offering 'purchaseUrls'
# Nature Shields Its Own 'purchaseUrls'
# Nature's Lore 'purchaseUrls'
# Nature's Ruin 'purchaseUrls'
# Naughty 'purchaseUrls'
# Naya 'purchaseUrls'
# Naya Sojourners 'purchaseUrls'
# Nazahn, Revered Bladesmith 'purchaseUrls'
# Nearheath Stalker 'purchaseUrls'
# Neck Tangle 'purchaseUrls'
# Necrite 'purchaseUrls'
# Necromaster Dragon 'purchaseUrls'
# Necropolis Fiend 'purchaseUrls'
# Necropotence Avatar 'purchaseUrls'
# Necroskitter 'purchaseUrls'
# Neheb, Dreadhorde Champion 'purchaseUrls'
# Nekrataal Avatar 'purchaseUrls'
# Nekusar, the Mindrazer 'purchaseUrls'
# Nephalia 'purchaseUrls'
# Nephalia Moondrakes 'purchaseUrls'
# Nerf War 'purchaseUrls'
# Nessian Wilds Ravager 'purchaseUrls'
# Nest Invader 'purchaseUrls'
# Nesting Dragon 'purchaseUrls'
# Nether Void 'purchaseUrls'
# Neurok Stealthsuit 'purchaseUrls'
# Nice 'purchaseUrls'
# Nicol Bolas, Dragon-God 'purchaseUrls'
# Nicol Bolas, God-Pharaoh 'purchaseUrls'
# Night Incarnate 'purchaseUrls'
# Night Soil 'purchaseUrls'
# Nighthowler 'purchaseUrls'
# Nightscape Familiar 'purchaseUrls'
# Nightveil Specter 'purchaseUrls'
# Nimble Pilferer 'purchaseUrls'
# Nine-Tail White Fox 'purchaseUrls'
# Nira, Hellkite Duelist 'purchaseUrls'
# Nissa's Pilgrimage 'purchaseUrls'
# Nissa's Renewal 'purchaseUrls'
# Nissa's Revelation 'purchaseUrls'
# Nissa, Steward of Elements 'purchaseUrls'
# Nissa, Vital Force 'purchaseUrls'
# Nissa, Who Shakes the World 'purchaseUrls'
# Niv-Mizzet Reborn 'purchaseUrls'
# No One Will Hear Your Cries 'purchaseUrls'
# Norn's Dominion 'purchaseUrls'
# Norwood Priestess 'purchaseUrls'
# Nostalgic Dreams 'purchaseUrls'
# Nothing Can Stop Me Now 'purchaseUrls'
# Nova Pentacle 'purchaseUrls'
# Noxious Gearhulk 'purchaseUrls'
# Noxious Hydra Breath 'purchaseUrls'
# Noyan Dar, Roil Shaper 'purchaseUrls'
# Nylea's Colossus 'purchaseUrls'
# O-Kagachi, Vengeful Kami 'purchaseUrls'
# Oakgnarl Warrior 'purchaseUrls'
# Oath of Kaya 'purchaseUrls'
# Ob Nixilis Reignited 'purchaseUrls'
# Ob Nixilis of the Black Oath 'purchaseUrls'
# Ob Nixilis, the Hate-Twisted 'purchaseUrls'
# Obelisk of Grixis 'purchaseUrls'
# Obelisk of Undoing 'purchaseUrls'
# Oblivion Ring 'purchaseUrls'
# Obsessive Search 'purchaseUrls'
# Octopus Umbra 'purchaseUrls'
# Odric, Lunarch Marshal 'purchaseUrls'
# Ogre Painbringer 'purchaseUrls'
# Ojutai's Command 'purchaseUrls'
# Ojutai, Soul of Winter 'purchaseUrls'
# Okaun, Eye of Chaos 'purchaseUrls'
# Okina Nightwatch 'purchaseUrls'
# Olivia, Mobilized for War 'purchaseUrls'
# Oloro, Ageless Ascetic 'purchaseUrls'
# Omnath, Locus of Rage 'purchaseUrls'
# Onakke Catacomb 'purchaseUrls'
# One Dozen Eyes 'purchaseUrls'
# Oni of Wild Places Avatar 'purchaseUrls'
# Only Blood Ends Your Nightmares 'purchaseUrls'
# Onyx Goblet 'purchaseUrls'
# Opalescence 'purchaseUrls'
# Oran-Rief Hydra 'purchaseUrls'
# Orator of Ojutai 'purchaseUrls'
# Orcish Captain 'purchaseUrls'
# Orcish Conscripts 'purchaseUrls'
# Orcish Farmer 'purchaseUrls'
# Orcish Lumberjack 'purchaseUrls'
# Orcish Mechanics 'purchaseUrls'
# Orcish Squatters 'purchaseUrls'
# Orcish Squatters Avatar 'purchaseUrls'
# Orcish Veteran 'purchaseUrls'
# Order of Leitbur 'purchaseUrls'
# Order of the Ebon Hand 'purchaseUrls'
# Order of the White Shield 'purchaseUrls'
# Oreskos Explorer 'purchaseUrls'
# Ormendahl, Profane Prince 'purchaseUrls'
# Orochi Colony 'purchaseUrls'
# Orzhova 'purchaseUrls'
# Otaria 'purchaseUrls'
# Outland Colossus 'purchaseUrls'
# Overbeing of Myth 'purchaseUrls'
# Overeager Apprentice 'purchaseUrls'
# Overflowing Insight 'purchaseUrls'
# Overtaker 'purchaseUrls'
# Oviya Pashiri, Sage Lifecrafter 'purchaseUrls'
# Owl Familiar 'purchaseUrls'
# Padeem, Consul of Innovation 'purchaseUrls'
# Pain Seer 'purchaseUrls'
# Painful Truths 'purchaseUrls'
# Palinchron 'purchaseUrls'
# Pang Tong, "Young Phoenix" 'purchaseUrls'
# Panharmonicon 'purchaseUrls'
# Panic 'purchaseUrls'
# Panopticon 'purchaseUrls'
# Paradise Druid 'purchaseUrls'
# Paradoxical Outcome 'purchaseUrls'
# Parallax Dementia 'purchaseUrls'
# Parallax Tide 'purchaseUrls'
# Parallax Wave 'purchaseUrls'
# Parhelion II 'purchaseUrls'
# Part the Waterveil 'purchaseUrls'
# Path of Ancestry 'purchaseUrls'
# Pathbreaker Ibex 'purchaseUrls'
# Patron of the Vein 'purchaseUrls'
# Pavel Maliki 'purchaseUrls'
# Pay Tribute to Me 'purchaseUrls'
# Peacekeeper Avatar 'purchaseUrls'
# Penumbra Wurm 'purchaseUrls'
# Perhaps You've Met My Cohort 'purchaseUrls'
# Perish 'purchaseUrls'
# Persecute 'purchaseUrls'
# Persistent Nightmare 'purchaseUrls'
# Personal Tutor 'purchaseUrls'
# Pestilence Demon 'purchaseUrls'
# Petra Sphinx 'purchaseUrls'
# Phage the Untouchable Avatar 'purchaseUrls'
# Phantasmal Mount 'purchaseUrls'
# Phantom Centaur 'purchaseUrls'
# Phantom Flock 'purchaseUrls'
# Phantom Nishoba 'purchaseUrls'
# Phantom Nomad 'purchaseUrls'
# Phelddagrif 'purchaseUrls'
# Phoenix Heart 'purchaseUrls'
# Phyrexian Altar 'purchaseUrls'
# Phyrexian Boon 'purchaseUrls'
# Phyrexian Defiler 'purchaseUrls'
# Phyrexian Juggernaut 'purchaseUrls'
# Phyrexian Negator 'purchaseUrls'
# Phyrexian Plaguelord 'purchaseUrls'
# Phyrexian Processor 'purchaseUrls'
# Phyrexian Rager 'purchaseUrls'
# Phyrexian War Beast 'purchaseUrls'
# Phytotitan 'purchaseUrls'
# Pia Nalaar 'purchaseUrls'
# Pia and Kiran Nalaar 'purchaseUrls'
# Pianna, Nomad Captain 'purchaseUrls'
# Pierce Strider 'purchaseUrls'
# Pillaging Horde 'purchaseUrls'
# Pillar of Flame 'purchaseUrls'
# Pine Barrens 'purchaseUrls'
# Pir, Imaginative Rascal 'purchaseUrls'
# Pitiless Horde 'purchaseUrls'
# Plague Myr 'purchaseUrls'
# Plague Spitter 'purchaseUrls'
# Plague Stinger 'purchaseUrls'
# Plaguemaw Beast 'purchaseUrls'
# Planar Gate 'purchaseUrls'
# Planar Outburst 'purchaseUrls'
# Planewide Celebration 'purchaseUrls'
# Planewide Disaster 'purchaseUrls'
# Plant Elemental 'purchaseUrls'
# Platinum Angel Avatar 'purchaseUrls'
# Plots That Span Centuries 'purchaseUrls'
# Plow Under 'purchaseUrls'
# Plundered Statue 'purchaseUrls'
# Polar Kraken 'purchaseUrls'
# Pools of Becoming 'purchaseUrls'
# Port Town 'purchaseUrls'
# Portent 'purchaseUrls'
# Pouncing Jaguar 'purchaseUrls'
# Powder Keg 'purchaseUrls'
# Power Artifact 'purchaseUrls'
# Power Without Equal 'purchaseUrls'
# Pox 'purchaseUrls'
# Prahv 'purchaseUrls'
# Prairie Stream 'purchaseUrls'
# Preacher 'purchaseUrls'
# Predator, Flagship 'purchaseUrls'
# Predatory Nightstalker 'purchaseUrls'
# Priest of the Blood Rite 'purchaseUrls'
# Primal Amulet 'purchaseUrls'
# Primal Wellspring 'purchaseUrls'
# Primordial Mist 'purchaseUrls'
# Princess Lucrezia 'purchaseUrls'
# Prism Array 'purchaseUrls'
# Pristine Skywise 'purchaseUrls'
# Prized Amalgam 'purchaseUrls'
# Prodigal Sorcerer Avatar 'purchaseUrls'
# Profaner of the Dead 'purchaseUrls'
# Prognostic Sphinx 'purchaseUrls'
# Propaganda 'purchaseUrls'
# Prophet of Kruphix 'purchaseUrls'
# Proposal 'purchaseUrls'
# Proud Mentor 'purchaseUrls'
# Psychatog 'purchaseUrls'
# Psychic Purge 'purchaseUrls'
# Punishing Fire 'purchaseUrls'
# Purge 'purchaseUrls'
# Purple-Crystal Crab 'purchaseUrls'
# Putrid Imp 'purchaseUrls'
# Pyroblast 'tcgplayer'
# Pyrokinesis 'tcgplayer'
# Pyrotechnics 'purchaseUrls'
# ...
# Sir Shandlar of Eberyn 'purchaseUrls'
# Sire of Stagnation 'purchaseUrls'
# Sisters of Stone Death Avatar 'purchaseUrls'
# Skarrg Goliath 'purchaseUrls'
# Skeletal Vampire 'purchaseUrls'
# Skeleton Ship 'purchaseUrls'
# Skirge Familiar 'purchaseUrls'
# Skittering Skirge 'purchaseUrls'
# Skull Storm 'purchaseUrls'
# Skullwinder 'purchaseUrls'
# Sky Ruin Drake 'purchaseUrls'
# Skybreen 'purchaseUrls'
# Skyhunter Skirmisher 'purchaseUrls'
# Skyrider Trainee 'purchaseUrls'
# Skyship Stalker 'purchaseUrls'
# Skyship Weatherlight 'purchaseUrls'
# Skyshroud Forest 'purchaseUrls'
# Skysovereign, Consul Flagship 'purchaseUrls'
# Skywing Aven 'purchaseUrls'
# Slagwurm Armor 'purchaseUrls'
# Slayer's Plate 'purchaseUrls'
# Slice and Dice 'purchaseUrls'
# Sliver Queen 'purchaseUrls'
# Sliver Queen Avatar 'purchaseUrls'
# Smash to Smithereens 'purchaseUrls'
# Smite the Monstrous 'purchaseUrls'
# Smokestack 'purchaseUrls'
# Smoldering Marsh 'purchaseUrls'
# Smothering Abomination 'purchaseUrls'
# Smuggler's Copter 'purchaseUrls'
# Snow Fortress 'purchaseUrls'
# Snow Mercy 'purchaseUrls'
# Snuff Out 'purchaseUrls'
# Sokenzan 'purchaseUrls'
# Sol Ring 'purchaseUrls'
# Solar Blast 'purchaseUrls'
# Solar Blaze 'purchaseUrls'
# Soldevi Simulacrum 'purchaseUrls'
# Soltari Emissary 'purchaseUrls'
# Soltari Trooper 'purchaseUrls'
# Some Disassembly Required 'purchaseUrls'
# Sorin, Grim Nemesis 'purchaseUrls'
# Sorin, Vengeful Bloodlord 'purchaseUrls'
# Sorrow's Path 'purchaseUrls'
# Soul Diviner 'purchaseUrls'
# Soul Exchange 'purchaseUrls'
# Soul Kiss 'purchaseUrls'
# Soul Snuffers 'purchaseUrls'
# Soul Summons 'purchaseUrls'
# Soul Swallower 'purchaseUrls'
# Soul of Theros 'purchaseUrls'
# Soulblade Corrupter 'purchaseUrls'
# Soulblade Djinn 'purchaseUrls'
# Soulblade Renewer 'purchaseUrls'
# Soulfire Grand Master 'purchaseUrls'
# Soulflayer 'purchaseUrls'
# Soulhunter Rakshasa 'purchaseUrls'
# Sower of Discord 'purchaseUrls'
# Spark Double 'purchaseUrls'
# Spark Spray 'purchaseUrls'
# Spatial Contortion 'purchaseUrls'
# Spatial Merging 'purchaseUrls'
# Spawning Pit 'purchaseUrls'
# Spawning Pool 'purchaseUrls'
# Spear of the General 'purchaseUrls'
# Spellshock 'purchaseUrls'
# Spellstutter Sprite 'purchaseUrls'
# Sphere of Resistance 'purchaseUrls'
# Sphinx of Jwar Isle 'purchaseUrls'
# Spinal Graft 'purchaseUrls'
# Spinal Villain 'purchaseUrls'
# Spire Serpent 'purchaseUrls'
# Spirebluff Canal 'purchaseUrls'
# Spires of Orazca 'purchaseUrls'
# Spirit Cairn 'purchaseUrls'
# Spirit Mantle 'purchaseUrls'
# Spirit Mirror 'purchaseUrls'
# Spiritual Guardian 'purchaseUrls'
# Spitfire Bastion 'purchaseUrls'
# Splendid Genesis 'purchaseUrls'
# Spore Cloud 'purchaseUrls'
# Spore Flower 'purchaseUrls'
# Spread the Sickness 'purchaseUrls'
# Sprouting Thrinax 'purchaseUrls'
# Squee, Goblin Nabob Avatar 'purchaseUrls'
# Staff of Nin 'purchaseUrls'
# Staff of Zegon 'purchaseUrls'
# Staggershock 'purchaseUrls'
# Stairs to Infinity 'purchaseUrls'
# Stalking Leonin 'purchaseUrls'
# Stalking Tiger Avatar 'purchaseUrls'
# Stampede 'purchaseUrls'
# Standstill 'purchaseUrls'
# Starstorm 'purchaseUrls'
# Startled Awake 'purchaseUrls'
# Stasis Snare 'purchaseUrls'
# Steel Wall 'purchaseUrls'
# Steelshaper's Gift 'purchaseUrls'
# Stensia 'purchaseUrls'
# Sterling Grove 'purchaseUrls'
# Stocking Tiger 'purchaseUrls'
# Stoic Rebuttal 'purchaseUrls'
# Stoke the Flames 'purchaseUrls'
# Stone Calendar 'purchaseUrls'
# Stone Rain 'purchaseUrls'
# Stone Spirit 'purchaseUrls'
# Stone-Tongue Basilisk 'purchaseUrls'
# Stonebrow, Krosan Hero 'purchaseUrls'
# Stonehands 'purchaseUrls'
# Stonehewer Giant Avatar 'purchaseUrls'
# Storm Seeker 'purchaseUrls'
# Storm Spirit 'purchaseUrls'
# Storm World 'purchaseUrls'
# Stormcloud Spirit 'purchaseUrls'
# Storrev, Devkarin Lich 'purchaseUrls'
# Strangleroot Geist 'purchaseUrls'
# Stratus Dancer 'purchaseUrls'
# Stream of Acid 'purchaseUrls'
# Strike the Weak Spot 'purchaseUrls'
# Stroke of Genius 'purchaseUrls'
# Stromgald Cabal 'purchaseUrls'
# Stronghold Furnace 'purchaseUrls'
# Stuffy Doll Avatar 'purchaseUrls'
# Stunted Growth 'purchaseUrls'
# Stupor 'purchaseUrls'
# Su-Chi 'purchaseUrls'
# Submerge 'purchaseUrls'
# Sudden Shock 'purchaseUrls'
# Sudden Strength 'purchaseUrls'
# Sultai Ascendancy 'purchaseUrls'
# Sultai Charm 'purchaseUrls'
# Sultai Emissary 'purchaseUrls'
# Sunastian Falconer 'purchaseUrls'
# Sunken City 'purchaseUrls'
# Sunken Hollow 'purchaseUrls'
# Sunscorch Regent 'purchaseUrls'
# Supplant Form 'purchaseUrls'
# Suppress 'purchaseUrls'
# Supreme Verdict 'purchaseUrls'
# Surging Flame 'purchaseUrls'
# Surrak Dragonclaw 'purchaseUrls'
# Surrak, the Hunt Caller 'purchaseUrls'
# Surrender Your Thoughts 'purchaseUrls'
# Survival of the Fittest 'purchaseUrls'
# Suspension Field 'purchaseUrls'
# Swallow the Hero Whole 'purchaseUrls'
# Swiftfoot Boots 'purchaseUrls'
# Sword of Feast and Famine 'tcgplayer'
# Sword of Kaldra 'purchaseUrls'
# Sword of the Ages 'purchaseUrls'
# Sylvan Caryatid 'purchaseUrls'
# Sylvan Library 'purchaseUrls'
# Sylvan Scrying 'purchaseUrls'
# Sylvia Brightspear 'purchaseUrls'
# Symbiotic Elf 'purchaseUrls'
# Syndicate Trafficker 'purchaseUrls'
# Synthetic Destiny 'purchaseUrls'
# Tablet of Epityr 'purchaseUrls'
# Tactical Advantage 'purchaseUrls'
# Taigam, Ojutai Master 'purchaseUrls'
# Taigam, Sidisi's Hand 'purchaseUrls'
# Takenuma 'purchaseUrls'
# Talara's Battalion 'purchaseUrls'
# Talent of the Telepath 'purchaseUrls'
# Talisman of Progress 'purchaseUrls'
# Talon Gates 'purchaseUrls'
# Tamiyo's Journal 'purchaseUrls'
# Tamiyo, Collector of Tales 'purchaseUrls'
# Tangle 'purchaseUrls'
# Tawnos's Coffin 'purchaseUrls'
# Tawnos, Urza's Apprentice 'purchaseUrls'
# Tazeem 'purchaseUrls'
# Tectonic Edge 'purchaseUrls'
# Teferi's Response 'purchaseUrls'
# Teferi, Temporal Archmage 'purchaseUrls'
# Teferi, Time Raveler 'purchaseUrls'
# Telekinesis 'purchaseUrls'
# Tember City 'purchaseUrls'
# Tempered Steel 'purchaseUrls'
# Temple of Mystery 'purchaseUrls'
# Temple of the False God 'purchaseUrls'
# Temporal Aperture 'purchaseUrls'
# Temporal Fissure 'purchaseUrls'
# Temur Ascendancy 'purchaseUrls'
# Temur War Shaman 'purchaseUrls'
# Tendrils of Agony 'purchaseUrls'
# Teroh's Faithful 'purchaseUrls'
# Territorial Gorger 'purchaseUrls'
# Territorial Hellkite 'purchaseUrls'
# Test of Faith 'purchaseUrls'
# Tetsuo Umezawa 'purchaseUrls'
# Teyo, the Shieldmage 'purchaseUrls'
# Teysa, Orzhov Scion Avatar 'purchaseUrls'
# Thalakos Drifters 'purchaseUrls'
# Thalia's Lieutenant 'purchaseUrls'
# Thallid 'purchaseUrls'
# Thallid Devourer 'purchaseUrls'
# Thantis, the Warweaver 'purchaseUrls'
# Thaumatic Compass 'purchaseUrls'
# Thawing Glaciers 'tcgplayer'
# The Abyss 'purchaseUrls'
# The Aether Flues 'purchaseUrls'
# The Avenger 'purchaseUrls'
# The Champion 'purchaseUrls'
# The Dark Barony 'purchaseUrls'
# The Dead Shall Serve 'purchaseUrls'
# The Destined 'purchaseUrls'
# The Elderspell 'purchaseUrls'
# The Eon Fog 'purchaseUrls'
# The Explorer 'purchaseUrls'
# The Fallen 'purchaseUrls'
# The Fate of the Flammable 'purchaseUrls'
# The Fourth Sphere 'purchaseUrls'
# The General 'purchaseUrls'
# The Gitrog Monster 'purchaseUrls'
# The Great Forest 'purchaseUrls'
# The Harvester 'purchaseUrls'
# The Hippodrome 'purchaseUrls'
# The Hunter 'purchaseUrls'
# The Iron Guardian Stirs 'purchaseUrls'
# The Lady of the Mountain 'purchaseUrls'
# The Maelstrom 'purchaseUrls'
# The Mighty Will Fall 'purchaseUrls'
# The Mimeoplasm 'purchaseUrls'
# The Philosopher 'purchaseUrls'
# The Pieces Are Coming Together 'purchaseUrls'
# The Protector 'purchaseUrls'
# The Provider 'purchaseUrls'
# The Savant 'purchaseUrls'
# The Slayer 'purchaseUrls'
# The Tabernacle at Pendrell Vale 'purchaseUrls'
# The Tyrant 'purchaseUrls'
# The Ur-Dragon 'purchaseUrls'
# The Vanquisher 'purchaseUrls'
# The Very Soil Shall Shake 'purchaseUrls'
# The Wanderer 'purchaseUrls'
# The Warmonger 'purchaseUrls'
# The Warrior 'purchaseUrls'
# The Zephyr Maze 'purchaseUrls'
# Thelonite Druid 'purchaseUrls'
# There Is No Refuge 'purchaseUrls'
# Thermokarst 'purchaseUrls'
# Thief of Blood 'purchaseUrls'
# Thing in the Ice 'purchaseUrls'
# Thirst for Knowledge 'purchaseUrls'
# This World Belongs to Me 'purchaseUrls'
# Thopter Pie Network 'purchaseUrls'
# Thopter Spy Network 'purchaseUrls'
# Thopter Squadron 'purchaseUrls'
# Thorn Elemental 'purchaseUrls'
# Thorn Thallid 'purchaseUrls'
# Thought Vessel 'purchaseUrls'
# Thran Dynamo 'purchaseUrls'
# Thran Foundry 'purchaseUrls'
# Thraximundar 'purchaseUrls'
# Thrull Champion 'purchaseUrls'
# Thrull Retainer 'purchaseUrls'
# Thunder Spirit 'purchaseUrls'
# Thunder Wall 'purchaseUrls'
# Thunderbreak Regent 'purchaseUrls'
# Thunderstaff 'purchaseUrls'
# Tibalt, Rakish Instigator 'purchaseUrls'
# Ticking Gnomes 'purchaseUrls'
# Tidehollow Sculler 'purchaseUrls'
# Tidehollow Strix 'purchaseUrls'
# Tidings 'purchaseUrls'
# Time Bomb 'purchaseUrls'
# Time Distortion 'purchaseUrls'
# Time Elemental 'purchaseUrls'
# Time Spiral 'purchaseUrls'
# Time Wipe 'purchaseUrls'
# Tinder Wall 'purchaseUrls'
# Tireless Tracker 'purchaseUrls'
# Titania, Protector of Argoth 'purchaseUrls'
# Titanic Pelagosaur 'purchaseUrls'
# Tivadar's Crusade 'purchaseUrls'
# To the Slaughter 'purchaseUrls'
# Tolarian Academy 'purchaseUrls'
# Tolsimir, Friend to Wolves 'purchaseUrls'
# Tomik, Distinguished Advokist 'purchaseUrls'
# Toolcraft Exemplar 'purchaseUrls'
# Tooth, Claw, and Tail 'purchaseUrls'
# Toothy, Imaginary Friend 'purchaseUrls'
# Tormented Hero 'purchaseUrls'
# Torn Between Heads 'purchaseUrls'
# Tornado 'purchaseUrls'
# Torrent Elemental 'purchaseUrls'
# Torrential Gearhulk 'purchaseUrls'
# Torsten Von Ursus 'purchaseUrls'
# Touch of the Horned God 'purchaseUrls'
# Tovolar's Magehunter 'purchaseUrls'
# Toxic Deluge 'purchaseUrls'
# Tradewind Rider 'purchaseUrls'
# Tradewind Rider Avatar 'purchaseUrls'
# Tragic Arrogance 'purchaseUrls'
# Tragic Slip 'purchaseUrls'
# Trail of Mystery 'purchaseUrls'
# Trail of the Mage-Rings 'purchaseUrls'
# Transmute Artifact 'purchaseUrls'
# Trap Essence 'purchaseUrls'
# Traverse the Outlands 'purchaseUrls'
# Traverse the Ulvenwald 'purchaseUrls'
# Treasure Cove 'purchaseUrls'
# Treasure Hunt 'purchaseUrls'
# Treasure Map 'purchaseUrls'
# Treasure Nabber 'purchaseUrls'
# Treasury Thrull 'purchaseUrls'
# Treetop Village 'purchaseUrls'
# Treetop Warden 'purchaseUrls'
# Triangle of War 'purchaseUrls'
# Tromokratis 'purchaseUrls'
# True-Name Nemesis 'purchaseUrls'
# Truga Jungle 'purchaseUrls'
# Trusty Machete 'purchaseUrls'
# Tsabo's Assassin 'purchaseUrls'
# Tsabo's Decree 'purchaseUrls'
# Tsabo's Web 'purchaseUrls'
# Tuknir Deathlock 'purchaseUrls'
# Tundra Wolves 'purchaseUrls'
# Turn the Tide 'purchaseUrls'
# Turnabout 'purchaseUrls'
# Turntimber Sower 'purchaseUrls'
# Turri Island 'purchaseUrls'
# Tuvasa the Sunlit 'purchaseUrls'
# Two-Headed Giant of Foriys Avatar 'purchaseUrls'
# Ugin's Construct 'purchaseUrls'
# Ugin's Insight 'purchaseUrls'
# Ugin, the Ineffable 'purchaseUrls'
# Ugin, the Spirit Dragon 'purchaseUrls'
# Uktabi Orangutan 'tcgplayer'
# Ulamog, the Ceaseless Hunger 'purchaseUrls'
# Ultimate Price 'purchaseUrls'
# Ulvenwald Hydra 'purchaseUrls'
# Undercity Reaches 'purchaseUrls'
# Underground River 'tcgplayer'
# Undergrowth Champion 'purchaseUrls'
# Undiscovered Paradise 'tcgplayer'
# Unified Lunge 'purchaseUrls'
# Unlicensed Disintegration 'purchaseUrls'
# Unquenchable Fury 'purchaseUrls'
# Untamed Wilds 'purchaseUrls'
# Upheaval 'purchaseUrls'
# Urborg 'purchaseUrls'
# Urborg Emissary 'purchaseUrls'
# Urborg Uprising 'purchaseUrls'
# Urza's Bauble 'purchaseUrls'
# Urza's Chalice 'purchaseUrls'
# Urza's Miter 'purchaseUrls'
# Valorous Stance 'purchaseUrls'
# Vampire Bats 'purchaseUrls'
# Vampire Nocturnus Avatar 'purchaseUrls'
# Vampiric Dragon 'purchaseUrls'
# Vance's Blasting Cannons 'purchaseUrls'
# Varchild's War-Riders 'purchaseUrls'
# Varchild, Betrayer of Kjeldor 'purchaseUrls'
# Varina, Lich Queen 'purchaseUrls'
# Vedalken Certarch 'purchaseUrls'
# Vedalken Humiliator 'purchaseUrls'
# Vela the Night-Clad 'purchaseUrls'
# Velis Vel 'purchaseUrls'
# Vengeant Vampire 'purchaseUrls'
# Verdant Confluence 'purchaseUrls'
# Verdurous Gearhulk 'purchaseUrls'
# Vicious Hunger 'purchaseUrls'
# Vigor 'purchaseUrls'
# Vildin-Pack Alpha 'purchaseUrls'
# Villainous Wealth 'purchaseUrls'
# Vine Trellis 'purchaseUrls'
# Violent Ultimatum 'purchaseUrls'
# Viridian Claw 'purchaseUrls'
# Viridian Corrupter 'purchaseUrls'
# Viridian Emissary 'purchaseUrls'
# Viridian Zealot Avatar 'purchaseUrls'
# Virtus the Veiled 'purchaseUrls'
# Visara the Dreadful 'purchaseUrls'
# Viscera Seer 'purchaseUrls'
# Vitality Salve 'purchaseUrls'
# Vivid Flying Fish 'purchaseUrls'
# Vivien's Arkbow 'purchaseUrls'
# Vivien, Champion of the Wilds 'purchaseUrls'
# Vodalian Knights 'purchaseUrls'
# Vodalian Merchant 'purchaseUrls'
# Void Winnower 'purchaseUrls'
# Volrath's Shapeshifter 'purchaseUrls'
# Volrath's Stronghold 'purchaseUrls'
# Voltaic Key 'purchaseUrls'
# Vow of Duty 'purchaseUrls'
# Vow of Flight 'purchaseUrls'
# Vow of Lightning 'purchaseUrls'
# Vow of Malice 'purchaseUrls'
# Vow of Wildness 'purchaseUrls'
# Vraska, Swarm's Eminence 'purchaseUrls'
# Vryn Wingmare 'purchaseUrls'
# Walk the Plank 'purchaseUrls'
# Walking Ballista 'purchaseUrls'
# Walking Wall 'purchaseUrls'
# Wall of Blossoms 'purchaseUrls'
# Wall of Diffusion 'purchaseUrls'
# Wall of Light 'purchaseUrls'
# Wall of Omens 'purchaseUrls'
# Wall of Spears 'purchaseUrls'
# Wanderer's Twig 'purchaseUrls'
# Wane 'purchaseUrls'
# Warchief Giant 'purchaseUrls'
# Warden of the First Tree 'purchaseUrls'
# Warmonger 'purchaseUrls'
# Warning 'purchaseUrls'
# Wasitora, Nekoru Queen 'purchaseUrls'
# Wasteland 'purchaseUrls'
# Wasteland Strangler 'purchaseUrls'
# Watcher of the Roost 'purchaseUrls'
# Watchwolf 'purchaseUrls'
# Waterfront Bouncer 'purchaseUrls'
# Wax 'purchaseUrls'
# Weakstone 'purchaseUrls'
# Weatherseed Treefolk 'purchaseUrls'
# Welcome to the Fold 'purchaseUrls'
# Werebear 'purchaseUrls'
# Werewolf of Ancient Hunger 'purchaseUrls'
# Westvale Abbey 'purchaseUrls'
# Westvale Cult Leader 'purchaseUrls'
# What's Yours Is Now Mine 'purchaseUrls'
# When Will You Learn? 'purchaseUrls'
# Whetstone 'purchaseUrls'
# Which of You Burns Brightest? 'purchaseUrls'
# Whip of Erebos 'purchaseUrls'
# Whiptongue Hydra 'purchaseUrls'
# Whirling Dervish 'tcgplayer'
# White Sun's Zenith 'purchaseUrls'
# Whiteout 'purchaseUrls'
# Widespread Brutality 'purchaseUrls'
# Wiitigo 'purchaseUrls'
# Wild Dogs 'purchaseUrls'
# Wild Mongrel 'purchaseUrls'
# Wild Nacatl 'purchaseUrls'
# Wild Swing 'purchaseUrls'
# Wildcall 'purchaseUrls'
# Wildest Dreams 'purchaseUrls'
# Wildfire 'purchaseUrls'
# Will Kenrith 'purchaseUrls'
# Willbreaker 'purchaseUrls'
# Willow Satyr 'purchaseUrls'
# Windgrace's Judgment 'purchaseUrls'
# Windriddle Palaces 'purchaseUrls'
# Winds of Change 'purchaseUrls'
# Winds of Rath 'purchaseUrls'
# Windseeker Centaur 'purchaseUrls'
# Wings of Aesthir 'purchaseUrls'
# Winter Blast 'purchaseUrls'
# Withering Wisps 'purchaseUrls'
# Wolf of Devil's Breach 'purchaseUrls'
# Wonder 'purchaseUrls'
# Wood Elemental 'purchaseUrls'
# Woodland Wanderer 'purchaseUrls'
# Woolly Mammoths 'purchaseUrls'
# Woolly Thoctar 'purchaseUrls'
# Word of Undoing 'purchaseUrls'
# Worldgorger Dragon 'purchaseUrls'
# Worn Powerstone 'purchaseUrls'
# Wrath of God 'purchaseUrls'
# Wren's Run Vanquisher 'purchaseUrls'
# Wretched Confluence 'purchaseUrls'
# Write into Being 'purchaseUrls'
# Xantcha, Sleeper Agent 'purchaseUrls'
# Xathrid Gorgon 'purchaseUrls'
# Xathrid Necromancer 'purchaseUrls'
# Xenagos's Scorn 'purchaseUrls'
# Xenagos's Strike 'purchaseUrls'
# Xun Yu, Wei Advisor 'purchaseUrls'
# Yahenni's Expertise 'purchaseUrls'
# Yasova Dragonclaw 'purchaseUrls'
# Yavimaya Ants 'purchaseUrls'
# Yavimaya Hollow 'purchaseUrls'
# Yawgmoth's Bargain 'purchaseUrls'
# Yawgmoth's Will 'purchaseUrls'
# Yennett, Cryptic Sovereign 'purchaseUrls'
# Your Fate Is Thrice Sealed 'purchaseUrls'
# Your Inescapable Doom 'purchaseUrls'
# Your Puny Minds Cannot Fathom 'purchaseUrls'
# Your Will Is Not Your Own 'purchaseUrls'
# Yule Ooze 'purchaseUrls'
# Yuriko, the Tiger's Shadow 'purchaseUrls'
# Zameck Guildmage 'purchaseUrls'
# Zedruu the Greathearted 'purchaseUrls'
# Zephyr Falcon 'purchaseUrls'
# Zephyr Gull 'purchaseUrls'
# Zhalfirin Crusader 'purchaseUrls'
# Zhalfirin Knight 'purchaseUrls'
# Zndrsplt, Eye of Wisdom 'purchaseUrls'
# Zodiac Dog 'purchaseUrls'
# Zodiac Goat 'purchaseUrls'
# Zodiac Horse 'purchaseUrls'
# Zodiac Ox 'purchaseUrls'
# Zodiac Pig 'purchaseUrls'
# Zodiac Rabbit 'purchaseUrls'
# Zodiac Rat 'purchaseUrls'
# Zodiac Rooster 'purchaseUrls'
# Zodiac Snake 'purchaseUrls'
# Zodiac Tiger 'purchaseUrls'
# Zombie Apocalypse 'purchaseUrls'
# Zuo Ci, the Mocking Sage 'purchaseUrls'
# Zur the Enchanter 'purchaseUrls'
# Zuran Orb 'purchaseUrls'
# Zuran Spellcaster 'purchaseUrls'
# Zurgo Bellstriker 'purchaseUrls'

# %% [markdown]
# ### Test

# %%
np.count_nonzero(tcg_player_card_urls), np.count_nonzero(tcg_player_card_urls)
# Out:
# (18122, 18122)

# %%
tcg_names[0], tcg_player_card_urls[0]
# Out:
# ('"Ach! Hans, Run!"', 'https://mtgjson.com/links/85b366724beadefd')

# %% [markdown]
# ### Define
# - combine names with urls to make tcg_cards

# %% [markdown]
# ### Code

# %%
# code to make a dataframe of the two tcg columns to make tcg_names dataframe
tcg_names = pd.DataFrame(data={'name': tcg_names})
tcg_names['url'] = tcg_player_card_urls

# %% [markdown]
# ### Test

# %%
tcg_names.head()
# Out:
#                          name                                         url
# 0           "Ach! Hans, Run!"  https://mtgjson.com/links/85b366724beadefd
# 1  "Rumors of My Death . . ."  https://mtgjson.com/links/f4da472f5769fc77
# 2                        AWOL  https://mtgjson.com/links/e2cbf59017afe314
# 3                Abandon Hope  https://mtgjson.com/links/43a70ba6b21894cd
# 4              Abandon Reason  https://mtgjson.com/links/2550e0426610acfd

# %% [markdown]
# ### Define
# - get all the names and rarities

# %% [markdown]
# ### Code

# %%
mtg_rarities = pd.DataFrame(name = [], 
                            rarity = [])

for i in mtg_archive_clean.keys():
    names = mtg_archive_clean[i]['name']
    rarities = mtg_archive_clean[i]['rarity']

# %% [markdown]
# # standard_sets

# %% [markdown]
# ## Gather

# %%
# pull standard cards from mtgjson
standard_sets = requests.get('https://www.mtgjson.com/json/Standard.json')
standard_sets_clean = standard_sets.json()

# %%
# code to save standard_sets as a json file 
with open('standard_sets_clean.txt', 'w') as outfile:
    json.dump(standard_sets_clean, outfile)

# %%
# code to load standard_sets_clean
with open('standard_sets_clean.txt', encoding='utf-8') as file:
    standard_sets_clean = json.load(file)

# %% [markdown]
# ## Assess

# %%
list(standard_cards_clean.items())[3]
# Out:
# ('RNA',
#  {'baseSetSize': 259,
#   'block': 'Guilds of Ravnica',
#   'boosterV3': [['rare', 'mythic rare'],
#    'uncommon',
#    'uncommon',
#    'uncommon',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'common',
#    'land',
#    'marketing'],
#   'cards': [{'artist': 'Izzy',
#     'borderColor': 'black',
#     'colorIdentity': ['U', 'W'],
#     'colors': ['U', 'W'],
#     'convertedManaCost': 3.0,
#     'edhrecRank': 3718,
#     'flavorText': '"In your misguided attempt to subvert the law, you have eloquently explained why the law must exist."',
#     'foreignData': [{'flavorText': '„Dein fehlgeleiteter Versuch, die Gesetze zu unterlaufen, beweist, dass diese Gesetze dringend notwendig sind."',
#       'language': 'German',
#       'multiverseId': 457554,
#       'name': 'Absorbieren',
#       'text': 'Neutralisiere einen Zauberspruch deiner Wahl. Du erhältst 3 Lebenspunkte dazu.',
#       'type': 'Spontanzauber'},
#      {'flavorText': '"En tu intento equivocado de subvertir la ley, explicaste con elocuencia por qué debe existir".',
#       'language': 'Spanish',
#       'multiverseId': 457813,
#       'name': 'Absorber',
#       'text': 'Contrarresta el hechizo objetivo. Ganas 3 vidas.',
#       'type': 'Instantáneo'},
#      {'flavorText': '« Dans votre tentative malavisée de renverser la loi, vous avez expliqué avec éloquence pourquoi elle doit exister. »',
#       'language': 'French',
#       'multiverseId': 458072,
#       'name': 'Absorption',
#       'text': 'Contrecarrez le sort ciblé. Vous gagnez 3 points de vie.',
#       'type': 'Éphémère'},
#      {'flavorText': '"Con il tuo malaccorto tentativo di sovvertire la legge, ne hai dimostrato esaustivamente la necessità."',
#       'language': 'Italian',
#       'multiverseId': 458331,
#       'name': 'Assorbire',
#       'text': 'Neutralizza una magia bersaglio. Guadagni 3 punti vita.',
#       'type': 'Istantaneo'},
#      {'flavorText': '「法を脅かすという君の誤った試みの中に、法がなくてはならない理由が雄弁に語られている。」',
#       'language': 'Japanese',
#       'multiverseId': 458590,
#       'name': '吸収',
#       'text': '呪文１つを対象とし、それを打ち消す。あなたは３点のライフを得る。',
#       'type': 'インスタント'},
#      {'flavorText': '"잘못된 판단에 근거해 법을 전복시키려 한 네 시도가 왜 법이 존재해야만 하는지를 역설해 주었다."',
#       'language': 'Korean',
#       'multiverseId': 458849,
#       'name': '흡수',
#       'text': '주문을 목표로 정한다. 그 주문을 무효화한다. 당신은 생명 3점을 얻는다.',
#       'type': '순간마법'},
#      {'flavorText': '"Em sua equivocada tentativa de subverter a lei, você explicou eloquentemente a necessidade da lei."',
#       'language': 'Portuguese (Brazil)',
#       'multiverseId': 459108,
#       'name': 'Absorver',
#       'text': 'Anule a mágica alvo. Você ganha 3 pontos de vida.',
#       'type': 'Mágica Instantânea'},
#      {'flavorText': '«Своей нелепой попыткой помешать исполнению закона ты лишь красноречиво показал, почему он должен существовать».',
#       'language': 'Russian',
#       'multiverseId': 459367,
#       'name': 'Поглощение',
#       'text': 'Отмените целевое заклинание. Вы получаете 3 жизни.',
#       'type': 'Мгновенное заклинание'},
#      {'flavorText': '「在你试图颠覆律法的错误过程中，你已经完美地阐述了律法为何必须存在。」',
#       'language': 'Chinese Simplified',
#       'multiverseId': 459626,
#       'name': '吸收',
#       'text': '反击目标咒语。你获得3点生命。',
#       'type': '瞬间'},
#      {'flavorText': '「在你試圖顛覆律法的錯誤過程中，你已經完美地闡述了律法為何必須存在。」',
#       'language': 'Chinese Traditional',
#       'multiverseId': 459885,
#       'name': '吸收',
#       'text': '反擊目標咒語。你獲得3點生命。',
#       'type': '瞬間'}],
#     'frameVersion': '2015',
#     'hasFoil': True,
#     'hasNonFoil': True,
#     'isArena': True,
#     'isMtgo': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'brawl': 'Legal',
#      'commander': 'Legal',
#      'duel': 'Legal',
#      'future': 'Legal',
#      'historic': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'standard': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{W}{U}{U}',
#     'mcmId': 367888,
#     'mcmMetaId': 16,
#     'mtgArenaId': 69279,
#     'mtgoId': 71302,
#     'mtgstocksId': 47468,
#     'multiverseId': 457295,
#     'name': 'Absorb',
#     'number': '151',
#     'originalText': 'Counter target spell. You gain 3 life.',
#     'originalType': 'Instant',
#     'prices': {'mtgo': {'2019-07-13': 0.22,
#       '2019-07-15': 0.21,
#       '2019-07-16': 0.2,
#       '2019-07-17': 0.18,
#       '2019-07-18': 0.17,
#       '2019-07-19': 0.19,
#       '2019-07-20': 0.21,
#       '2019-07-21': 0.19,
#       '2019-07-22': 0.17,
#       '2019-07-24': 0.19,
#       '2019-07-25': 0.17,
#       '2019-07-27': 0.17,
#       '2019-07-28': 0.15,
#       '2019-07-29': 0.11,
#       '2019-07-30': 0.13,
#       '2019-08-01': 0.12,
#       '2019-08-02': 0.12,
#       '2019-08-03': 0.12,
#       '2019-08-07': 0.11,
#       '2019-08-08': 0.13,
#       '2019-08-09': 0.12,
#       '2019-08-10': 0.11,
#       '2019-08-11': 0.1,
#       '2019-08-15': 0.12,
#       '2019-08-17': 0.13,
#       '2019-08-26': 0.09,
#       '2019-09-01': 0.08,
#       '2019-09-02': 0.1,
#       '2019-09-03': 0.07,
#       '2019-09-04': 0.07,
#       '2019-09-05': 0.07,
#       '2019-09-06': 0.08,
#       '2019-09-07': 0.08,
#       '2019-09-08': 0.08,
#       '2019-09-09': 0.1,
#       '2019-09-11': 0.11,
#       '2019-09-12': 0.14,
#       '2019-09-13': 0.14,
#       '2019-09-14': 0.16,
#       '2019-09-15': 0.17,
#       '2019-09-17': 0.16,
#       '2019-09-18': 0.17,
#       '2019-09-21': 0.16,
#       '2019-09-22': 0.15,
#       '2019-09-24': 0.12,
#       '2019-09-26': 0.13,
#       '2019-09-27': 0.11,
#       '2019-09-30': 0.12,
#       '2019-10-01': 0.11,
#       '2019-10-02': 0.11,
#       '2019-10-03': 0.11,
#       '2019-10-04': 0.09,
#       '2019-10-06': 0.1,
#       '2019-10-09': 0.1,
#       '2019-10-11': 0.1,
#       '2019-10-12': 0.09,
#       '2019-10-13': 0.1},
#      'mtgoFoil': {'2019-10-09': 0.24,
#       '2019-10-11': 0.24,
#       '2019-10-12': 0.24,
#       '2019-10-13': 0.24},
#      'paper': {'2019-07-14': 1.28,
#       '2019-07-21': 1.25,
#       '2019-07-28': 1.25,
#       '2019-08-04': 1.2,
#       '2019-08-11': 1.15,
#       '2019-08-18': 1.08,
#       '2019-08-25': 1.03,
#       '2019-09-01': 1.0,
#       '2019-09-08': 1.0,
#       '2019-09-15': 1.0,
#       '2019-09-22': 1.0,
#       '2019-09-29': 1.0,
#       '2019-10-06': 1.0},
#      'paperFoil': {'2019-07-14': 4.08,
#       '2019-07-21': 4.05,
#       '2019-07-28': 4.0,
#       '2019-08-04': 3.97,
#       '2019-08-11': 3.96,
#       '2019-08-18': 3.86,
#       '2019-08-25': 3.83,
#       '2019-09-01': 3.75,
#       '2019-09-08': 3.64,
#       '2019-09-15': 3.63,
#       '2019-09-22': 3.57,
#       '2019-09-29': 3.59,
#       '2019-10-06': 3.55}},
#     'printings': ['INV', 'PRNA', 'RNA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/b43fc7358053b15c',
#      'mtgstocks': 'https://mtgjson.com/links/32506cf6531ceed4',
#      'tcgplayer': 'https://mtgjson.com/links/ff5cbfb7ab0a0afb'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2019-01-25',
#       'text': 'A spell that can’t be countered is a legal target for Absorb. The spell won’t be countered when Absorb resolves, but you’ll still gain 3 life.'}],
#     'scryfallId': '1e8a43c1-42d1-45ef-8a63-4b87775a6e88',
#     'scryfallIllustrationId': 'd64f2ad2-53b3-4d76-9f2f-4ef8b097af60',
#     'scryfallOracleId': '132ca99a-a3c7-4ed6-b4d0-0edcd7140ca2',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 182492,
#     'text': 'Counter target spell. You gain 3 life.',
#     'type': 'Instant',
#     'types': ['Instant'],
#     'uuid': 'f5f0ce1a-7ed3-5c87-b3b5-a428499b0042',
#     'watermark': 'azorius'},
#    {'artist': 'Scott Murphy',
#     'borderColor': 'black',
#     'colorIdentity': ['R'],
#     'colors': ['R'],
#     'convertedManaCost': 3.0,
#     'edhrecRank': 2737,
#     'flavorText': 'Seen through Rakdos eyes, a cruel betrayal is a hilarious stunt.',
#     'foreignData': [{'flavorText': 'Für die Rakdos ist grausamer Verrat eine urkomische Nummer.',
#       'language': 'German',
#       'multiverseId': 457494,
#       'name': 'Verräterische Tat',
#       'text': 'Übernimm bis zum Ende des Zuges die Kontrolle über eine Kreatur deiner Wahl. Enttappe die Kreatur. Sie erhält Eile bis zum Ende des Zuges.',
#       'type': 'Hexerei'},
#      {'flavorText': 'Vista a través de ojos rakdos, una traición cruel es una artimaña de lo más cómica.',
#       'language': 'Spanish',
#       'multiverseId': 457753,
#       'name': 'Acto de traición',
#       'text': 'Gana el control de la criatura objetivo hasta el final del turno. Endereza esa criatura. Gana la habilidad de prisa hasta el final del turno.',
#       'type': 'Conjuro'},
#      {'flavorText': 'Aux yeux des Rakdos, une trahison cruelle est un acte hilarant.',
#       'language': 'French',
#       'multiverseId': 458012,
#       'name': 'Acte de trahison',
#       'text': "Acquérez le contrôle de la créature ciblée jusqu'à la fin du tour. Dégagez cette créature. Elle acquiert la célérité jusqu'à la fin du tour.",
#       'type': 'Rituel'},
#      {'flavorText': 'Agli occhi dei Rakdos, un crudele tradimento è un espediente spassoso.',
#       'language': 'Italian',
#       'multiverseId': 458271,
#       'name': 'Atto di Tradimento',
#       'text': 'Prendi il controllo di una creatura bersaglio fino alla fine del turno. STAPpa quella creatura. Ha rapidità fino alla fine del turno.',
#       'type': 'Stregoneria'},
#      {'flavorText': 'ラクドスの目を通してみると、残酷な裏切りも愉快な一芸だ。',
#       'language': 'Japanese',
#       'multiverseId': 458530,
#       'name': '反逆の行動',
#       'text': 'クリーチャー１体を対象とする。ターン終了時まで、それのコントロールを得る。そのクリーチャーをアンタップする。ターン終了時まで、それは速攻を得る。',
#       'type': 'ソーサリー'},
#      {'flavorText': '락도스의 관점으로 보면, 잔혹한 배신은 아주 재미있는 곡예이다.',
#       'language': 'Korean',
#       'multiverseId': 458789,
#       'name': '반역 행위',
#       'text': '생물을 목표로 정한다. 턴종료까지 그 생물의 조종권을 얻는다. 그 생물은 언탭되고 턴종료까지 신속을 얻는다.',
#       'type': '집중마법'},
#      {'flavorText': 'Aos olhos dos Rakdos, uma traição cruel é uma esquete hilária.',
#       'language': 'Portuguese (Brazil)',
#       'multiverseId': 459048,
#       'name': 'Ato de Traição',
#       'text': 'Ganhe o controle da criatura alvo até o final do turno. Desvire aquela criatura. Ela ganha ímpeto até o final do turno.',
#       'type': 'Feitiço'},
#      {'flavorText': 'Если смотреть на жестокое предательство глазами Ракдосов, оно превращается в страшно смешной розыгрыш.',
#       'language': 'Russian',
#       'multiverseId': 459307,
#       'name': 'Акт Измены',
#       'text': 'Получите контроль над целевым существом до конца хода. Разверните то существо. Оно получает Ускорение до конца хода.',
#       'type': 'Волшебство'},
#      {'flavorText': '在拉铎司人眼中看来，残酷背叛不过是一场特技表演。',
#       'language': 'Chinese Simplified',
#       'multiverseId': 459566,
#       'name': '叛行',
#       'text': '获得目标生物的操控权直到回合结束。重置该生物。它获得敏捷异能直到回合结束。',
#       'type': '法术'},
#      {'flavorText': '在拉鐸司人眼中看來，殘酷背叛不過是一場特技表演。',
#       'language': 'Chinese Traditional',
#       'multiverseId': 459825,
#       'name': '叛行',
#       'text': '獲得目標生物的操控權直到回合結束。重置該生物。它獲得敏捷異能直到回合結束。',
#       'type': '巫術'}],
#     'frameVersion': '2015',
#     'hasFoil': True,
#     'hasNonFoil': True,
#     'isArena': True,
#     'isMtgo': True,
#     'isPaper': True,
#     'isReprint': True,
#     'layout': 'normal',
#     'legalities': {'brawl': 'Legal',
#      'commander': 'Legal',
#      'duel': 'Legal',
#      'future': 'Legal',
#      'historic': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'pauper': 'Legal',
#      'penny': 'Legal',
#      'standard': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{2}{R}',
#     'mcmId': 368581,
#     'mcmMetaId': 10625,
#     'mtgArenaId': 69219,
#     'mtgoId': 71182,
#     'mtgstocksId': 47733,
#     'multiverseId': 457235,
#     'name': 'Act of Treason',
#     'number': '91',
#     'originalText': 'Gain control of target creature until end of turn. Untap that creature. It gains haste until end of turn.',
#     'originalType': 'Sorcery',
#     'prices': {'mtgo': {'2019-10-09': 0.01,
#       '2019-10-11': 0.01,
#       '2019-10-12': 0.01,
#       '2019-10-13': 0.01},
#      'mtgoFoil': {'2019-10-09': 0.01,
#       '2019-10-11': 0.01,
#       '2019-10-12': 0.01,
#       '2019-10-13': 0.01},
#      'paper': {'2019-07-14': 0.14,
#       '2019-07-21': 0.14,
#       '2019-07-28': 0.15,
#       '2019-08-04': 0.15,
#       '2019-08-11': 0.15,
#       '2019-08-18': 0.15,
#       '2019-08-25': 0.15,
#       '2019-09-01': 0.15,
#       '2019-09-08': 0.15,
#       '2019-09-15': 0.15,
#       '2019-09-22': 0.15,
#       '2019-09-29': 0.15,
#       '2019-10-06': 0.15},
#      'paperFoil': {'2019-07-14': 0.3,
#       '2019-07-21': 0.3,
#       '2019-07-28': 0.3,
#       '2019-08-04': 0.3,
#       '2019-08-11': 0.3,
#       '2019-08-18': 0.3,
#       '2019-08-25': 0.29,
#       '2019-09-01': 0.3,
#       '2019-09-08': 0.29,
#       '2019-09-15': 0.29,
#       '2019-09-22': 0.3,
#       '2019-09-29': 0.3,
#       '2019-10-06': 0.29}},
#     'printings': ['A25',
#      'DDN',
#      'DPA',
#      'GTC',
#      'KTK',
#      'M10',
#      'M11',
#      'M12',
#      'M14',
#      'M19',
#      'M20',
#      'ORI',
#      'PS11',
#      'RNA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/13e1797fa9caa287',
#      'mtgstocks': 'https://mtgjson.com/links/8c066f00330eefc8',
#      'tcgplayer': 'https://mtgjson.com/links/543d7f6de7019195'},
#     'rarity': 'common',
#     'rulings': [{'date': '2019-07-12',
#       'text': 'Act of Treason can target any creature, even one that’s untapped or one you already control.'},
#      {'date': '2019-07-12',
#       'text': 'Gaining control of a creature doesn’t cause you to gain control of any Auras or Equipment attached to it.'}],
#     'scryfallId': '1f2328c4-7344-48bf-b515-977499bcfd1c',
#     'scryfallIllustrationId': '884b0712-07a7-4d81-a2c4-246bbcbf12d5',
#     'scryfallOracleId': '9d08af23-9f4a-4097-9abc-3b17475ab744',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 183383,
#     'text': 'Gain control of target creature until end of turn. Untap that creature. It gains haste until end of turn. (It can attack and {T} this turn.)',
#     'type': 'Sorcery',
#     'types': ['Sorcery'],
#     'uuid': '7e9b5fa0-4d69-55f3-88a4-7bbdee0f8803'},
#    {'artist': 'Simon Dominic',
#     'borderColor': 'black',
#     'colorIdentity': ['G', 'U'],
#     'colors': ['G', 'U'],
#     'convertedManaCost': 3.0,
#     'edhrecRank': 12236,
#     'flavorText': '"The absence of binocular vision imposes certain challenges for a flying creature, which are overcome via echolocation."\n—Simic research notes',
#     'foreignData': [{'flavorText': '„Die Einäugigkeit stellt diese fliegende Kreatur vor gewisse Herausforderungen, die sie mithilfe der Echolokation meistert."\n—Notizen von Simic-Forschern',
#       'language': 'German',
#       'multiverseId': 457555,
#       'name': 'Aeromunkulus',
#       'text': 'Fliegend\n{2}{G}{U}: Adaptieren 1. (Falls keine +1/+1-Marken auf dieser Kreatur liegen, lege eine +1/+1-Marke auf sie.)',
#       'type': 'Kreatur — Homunkulus, Mutant'},
#      {'flavorText': '"Para una criatura voladora, la ausencia de visión binocular supone ciertos desafíos, mas estos se resuelven gracias a la ecolocalización".\n—Notas de investigación simic',
#       'language': 'Spanish',
#       'multiverseId': 457814,
#       'name': 'Aeromúnculo',
#       'text': 'Vuela.\n{2}{G}{U}: Adaptar 1. (Si esta criatura no tiene contadores +1/+1 sobre ella, pon un contador +1/+1 sobre ella.)',
#       'type': 'Criatura — Mutante homúnculo'},
#      {'flavorText': "« L'absence de vision binoculaire posent certaines difficultés à une créature volante, mais que l'on peut surmonter grâce à l'écholocalisation. »\n—Notes de recherche des Simic",
#       'language': 'French',
#       'multiverseId': 458073,
#       'name': 'Aéromoncule',
#       'text': "Vol\n{2}{G}{U} : Adaptez 1. (Si cette créature n'a pas de marqueurs +1/+1 sur elle, mettez un marqueur +1/+1 sur elle.)",
#       'type': 'Créature : homoncule et mutant'},
#      {'flavorText': '"L\'assenza di visione binoculare pone alcune sfide nella creazione di una creatura volante; a queste si è ovviato attraverso un sistema di ecolocazione."\n—Note di ricerca dei Simic',
#       'language': 'Italian',
#       'multiverseId': 458332,
#       'name': 'Aeromuncolo',
#       'text': 'Volare\n{2}{G}{U}: Adattamento 1. (Se questa creatura non ha segnalini +1/+1, metti un segnalino +1/+1 su di essa.)',
#       'type': 'Creatura — Mutante Omuncolo'},
#      {'flavorText': '「二眼視の欠如は飛行生物にとって少なからぬ負担になるが、その点は反響定位により補われている。」\n――シミックの研究メモ',
#       'language': 'Japanese',
#       'multiverseId': 458591,
#       'name': 'エアロムンクルス',
#       'text': '飛行\n{2}{G}{U}：順応１を行う。（このクリーチャーの上に＋１/＋１カウンターが置かれていないなら、これの上に＋１/＋１カウンターを１個置く。）',
#       'type': 'クリーチャー — ホムンクルス・ミュータント'},
#      {'flavorText': '"두 눈으로 볼 수 없다는 사실은 날아다니는 생물에게 특정한 어려움을 제시하며, 이는 반향정위를 통해 극복된다."\n—시믹 연구 기록',
#       'language': 'Korean',
#       'multiverseId': 458850,
#       'name': '에어로문쿨루스',
#       'text': '비행\n{2}{G}{U}: 적응 1을 한다. (이 생물이 +1/+1 카운터를 가지고 있지 않다면, 이 생물에 +1/+1 카운터 한 개를 올려놓는다.)',
#       'type': '생물 — 호문쿨루스 돌연변이'},
#      {'flavorText': '"A ausência de visão binocular impõe certos desafios a uma criatura voadora. Esses são superados via ecolocalização."\n— Notas de pesquisa Simic',
#       'language': 'Portuguese (Brazil)',
#       'multiverseId': 459109,
#       'name': 'Aeromúnculo',
#       'text': 'Voar\n{2}{G}: Adaptar 1. (Se esta criatura não tiver marcadores +1/+1, coloque um marcador +1/+1 nela.)',
#       'type': 'Criatura — Homúnculo Mutante'},
#      {'flavorText': '«Отсутствие бинокулярного зрения накладывает определенные трудности на летающее существо, но их легко преодолеть при помощи эхолокации».\n— Исследовательские записки Симиков',
#       'language': 'Russian',
#       'multiverseId': 459368,
#       'name': 'Аэромункул',
#       'text': 'Полет\n{2}{G}{U}: адаптируйте 1. (Если на этом существе нет жетонов +1/+1, положите на него один жетон +1/+1.)',
#       'type': 'Существо — Гомункул Мутант'},
#      {'flavorText': '「对于飞行生物而言，没有双眼视觉多少会有点不便，但这个缺点能靠回声定位来弥补。」\n～析米克研究纪录',
#       'language': 'Chinese Simplified',
#       'multiverseId': 459627,
#       'name': '空行造妖',
#       'text': '飞行\n{2}{G}{U}：演化1。（如果此生物上没有+1/+1指示物，则在其上放置一个+1/+1指示物。）',
#       'type': '生物 ～造妖／突变体'},
#      {'flavorText': '「對於飛行生物而言，沒有雙眼視覺多少會有點不便，但這個缺點能靠回聲定位來彌補。」\n～析米克研究紀錄',
#       'language': 'Chinese Traditional',
#       'multiverseId': 459886,
#       'name': '空行造妖',
#       'text': '飛行\n{2}{G}{U}：演化1。（如果此生物上沒有+1/+1指示物，則在其上放置一個+1/+1指示物。）',
#       'type': '生物 ～造妖／突變體'}],
#     'frameVersion': '2015',
#     'hasFoil': True,
#     'hasNonFoil': True,
#     'isArena': True,
#     'isMtgo': True,
#     'isPaper': True,
#     'layout': 'normal',
#     'legalities': {'brawl': 'Legal',
#      'commander': 'Legal',
#      'duel': 'Legal',
#      'future': 'Legal',
#      'historic': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'pauper': 'Legal',
#      'penny': 'Legal',
#      'standard': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{1}{G}{U}',
#     'mcmId': 367838,
#     'mcmMetaId': 267346,
#     'mtgArenaId': 69280,
#     'mtgoId': 71304,
#     'mtgstocksId': 47451,
#     'multiverseId': 457296,
#     'name': 'Aeromunculus',
#     'number': '152',
#     'originalText': 'Flying\n{2}{G}{U}: Adapt 1. (If this creature has no +1/+1 counters on it, put a +1/+1 counter on it.)',
#     'originalType': 'Creature — Homunculus Mutant',
#     'power': '2',
#     'prices': {'mtgo': {'2019-10-09': 0.01,
#       '2019-10-11': 0.01,
#       '2019-10-12': 0.01,
#       '2019-10-13': 0.01},
#      'mtgoFoil': {'2019-10-09': 0.01,
#       '2019-10-11': 0.01,
#       '2019-10-12': 0.01,
#       '2019-10-13': 0.01},
#      'paper': {'2019-07-14': 0.15,
#       '2019-07-21': 0.14,
#       '2019-07-28': 0.15,
#       '2019-08-04': 0.15,
#       '2019-08-11': 0.15,
#       '2019-08-18': 0.15,
#       '2019-08-25': 0.15,
#       '2019-09-01': 0.15,
#       '2019-09-08': 0.14,
#       '2019-09-15': 0.14,
#       '2019-09-22': 0.14,
#       '2019-09-29': 0.15,
#       '2019-10-06': 0.15},
#      'paperFoil': {'2019-07-14': 0.3,
#       '2019-07-21': 0.31,
#       '2019-07-28': 0.3,
#       '2019-08-04': 0.29,
#       '2019-08-11': 0.3,
#       '2019-08-18': 0.3,
#       '2019-08-25': 0.3,
#       '2019-09-01': 0.3,
#       '2019-09-08': 0.33,
#       '2019-09-15': 0.33,
#       '2019-09-22': 0.33,
#       '2019-09-29': 0.3,
#       '2019-10-06': 0.29}},
#     'printings': ['RNA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/bb0fca2a2cf16175',
#      'mtgstocks': 'https://mtgjson.com/links/1dfa13a51ce91337',
#      'tcgplayer': 'https://mtgjson.com/links/ead433cc980a798b'},
#     'rarity': 'common',
#     'rulings': [{'date': '2019-01-25',
#       'text': 'You can always activate an ability that will cause a creature to adapt. As that ability resolves, if the creature has a +1/+1 counter on it for any reason, you simply won’t put any +1/+1 counters on it.'},
#      {'date': '2019-01-25',
#       'text': 'If a creature somehow loses all of its +1/+1 counters, it can adapt again and get more +1/+1 counters.'}],
#     'scryfallId': '671c94c1-df52-4985-ad78-3e1c9c78df18',
#     'scryfallIllustrationId': '1ab11619-378d-43c0-a43f-706acebb5ffe',
#     'scryfallOracleId': 'a0cd19c1-9125-4627-83ba-d42c489b4e7d',
#     'subtypes': ['Homunculus', 'Mutant'],
#     'supertypes': [],
#     'tcgplayerProductId': 182213,
#     'text': 'Flying\n{2}{G}{U}: Adapt 1. (If this creature has no +1/+1 counters on it, put a +1/+1 counter on it.)',
#     'toughness': '3',
#     'type': 'Creature — Homunculus Mutant',
#     'types': ['Creature'],
#     'uuid': 'a18dde06-a5bc-5c49-a8d4-ef2d06f12741',
#     'watermark': 'simic'},
#    {'artist': 'Dan Scott',
#     'borderColor': 'black',
#     'colorIdentity': ['R'],
#     'colors': ['R'],
#     'convertedManaCost': 4.0,
#     'edhrecRank': 10938,
#     'foreignData': [{'language': 'German',
#       'multiverseId': 457495,
#       'name': 'Amplifeuer',
#       'text': 'Decke zu Beginn deines Versorgungssegments Karten oben von deiner Bibliothek auf, bis du eine Kreaturenkarte aufdeckst. Bis zu deinem nächsten Zug wird die Basis-Stärke des Amplifeuers zum Doppelten der Stärke jener Karte und seine Basis-Widerstandskraft wird zum Doppelten der Widerstandskraft jener Karte. Lege die aufgedeckten Karten in zufälliger Reihenfolge unter deine Bibliothek.',
#       'type': 'Kreatur — Elementarwesen'},
#      {'language': 'Spanish',
#       'multiverseId': 457754,
#       'name': 'Amplifuego',
#       'text': 'Al comienzo de tu mantenimiento, muestra las primeras cartas de tu biblioteca hasta que muestres una carta de criatura. Hasta tu próximo turno, la fuerza base del Amplifuego se convierte en el doble de la fuerza de esa carta y su resistencia base se convierte en el doble de la resistencia de esa carta. Pon las cartas mostradas en el fondo de tu biblioteca en un orden aleatorio.',
#       'type': 'Criatura — Elemental'},
#      {'language': 'French',
#       'multiverseId': 458013,
#       'name': 'Flamplificateur',
#       'text': "Au début de votre entretien, révélez les cartes du dessus de votre bibliothèque jusqu'à ce que vous révéliez une carte de créature. Jusqu'à votre prochain tour, la force de base du Flamplificateur devient égale au double de la force de cette carte et son endurance de base devient égale au double de l'endurance de cette carte. Mettez les cartes révélées au-dessous de votre bibliothèque dans un ordre aléatoire.",
#       'type': 'Créature : élémental'},
#      {'language': 'Italian',
#       'multiverseId': 458272,
#       'name': 'Amplifuoco',
#       'text': "All'inizio del tuo mantenimento, rivela carte dalla cima del tuo grimorio finché non riveli una carta creatura. Fino al tuo prossimo turno, la forza base dell'Amplifuoco diventa il doppio della forza di quella carta e la sua costituzione base diventa il doppio della costituzione di quella carta. Metti le carte rivelate in fondo al tuo grimorio in ordine casuale.",
#       'type': 'Creatura — Elementale'},
#      {'language': 'Japanese',
#       'multiverseId': 458531,
#       'name': '倍火',
#       'text': 'あなたのアップキープの開始時に、クリーチャー・カードが公開されるまで、あなたのライブラリーの一番上からカードを１枚ずつ公開する。あなたの次のターンまで、倍火の基本のパワーはそのカードのパワーの２倍になり、これの基本のタフネスはそのカードのタフネスの２倍になる。それらの公開されたカードをあなたのライブラリーの一番下に無作為の順番で置く。',
#       'type': 'クリーチャー — エレメンタル'},
#      {'language': 'Korean',
#       'multiverseId': 458790,
#       'name': '증폭불길',
#       'text': '당신의 유지단 시작에, 생물 카드가 공개될 때까지 당신의 서고 맨 위 카드를 공개한다. 당신의 다음 턴까지, 증폭불길의 기본 공격력은 그 카드의 공격력의 두 배가 되고 기본 방어력은 그 카드의 방어력의 두 배가 된다. 공개된 카드들은 무작위 순서로 당신의 서고 맨 밑에 놓는다.',
#       'type': '생물 — 정령'},
#      {'language': 'Portuguese (Brazil)',
#       'multiverseId': 459049,
#       'name': 'Amplifogo',
#       'text': 'No início de sua manutenção, revele cards do topo de seu grimório até revelar um card de criatura. Até seu próximo turno, o poder básico de Amplifogo torna-se o dobro do poder daquele card e a resistência básica de Amplifogo torna-se o dobro da resistência daquele card. Coloque os cards revelados no fundo de seu grimório em ordem aleatória.',
#       'type': 'Criatura — Elemental'},
#      {'language': 'Russian',
#       'multiverseId': 459308,
#       'name': 'Сверхогонь',
#       'text': 'В начале вашего шага поддержки показывайте карты с верха вашей библиотеки до тех пор, пока вы не покажете карту существа. До вашего следующего хода базовая сила Сверхогня становится равной удвоенному значению силы той карты, а его базовая выносливость — удвоенному значению выносливости той карты. Положите показанные карты в низ вашей библиотеки в случайном порядке.',
#       'type': 'Существо — Элементаль'},
#      {'language': 'Chinese Simplified',
#       'multiverseId': 459567,
#       'name': '倍火妖',
#       'text': '在你的维持开始时，从你的牌库顶开始展示牌，直到你展示出一张生物牌为止。直到你的下一个回合，倍火妖的基础力量成为该牌力量的两倍，且其基础防御力成为该牌防御力的两倍。将所展示的牌以随机顺序置于你的牌库底。',
#       'type': '生物 ～元素'},
#      {'language': 'Chinese Traditional',
#       'multiverseId': 459826,
#       'name': '倍火妖',
#       'text': '在你的維持開始時，從你的牌庫頂開始展示牌，直到你展示出一張生物牌為止。直到你的下一個回合，倍火妖的基礎力量成為該牌力量的兩倍，且其基礎防禦力成為該牌防禦力的兩倍。將所展示的牌以隨機順序置於你的牌庫底。',
#       'type': '生物 ～元素'}],
#     'frameVersion': '2015',
#     'hasFoil': True,
#     'hasNonFoil': True,
#     'isArena': True,
#     'isMtgo': True,
#     'isPaper': True,
#     'layout': 'normal',
#     'legalities': {'brawl': 'Legal',
#      'commander': 'Legal',
#      'duel': 'Legal',
#      'future': 'Legal',
#      'historic': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'penny': 'Legal',
#      'standard': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{2}{R}{R}',
#     'mcmId': 368102,
#     'mcmMetaId': 267536,
#     'mtgArenaId': 69220,
#     'mtgoId': 71184,
#     'mtgstocksId': 47559,
#     'multiverseId': 457236,
#     'name': 'Amplifire',
#     'number': '92',
#     'originalText': "At the beginning of your upkeep, reveal cards from the top of your library until you reveal a creature card. Until your next turn, Amplifire's base power becomes twice that card's power and its base toughness becomes twice that card's toughness. Put the revealed cards on the bottom of your library in a random order.",
#     'originalType': 'Creature — Elemental',
#     'power': '1',
#     'prices': {'mtgo': {'2019-07-19': 0.02,
#       '2019-09-02': 0.02,
#       '2019-09-03': 0.02,
#       '2019-09-15': 0.01,
#       '2019-10-02': 0.02,
#       '2019-10-09': 0.01,
#       '2019-10-11': 0.01,
#       '2019-10-12': 0.01,
#       '2019-10-13': 0.01},
#      'mtgoFoil': {'2019-10-09': 0.34,
#       '2019-10-11': 0.34,
#       '2019-10-12': 0.34,
#       '2019-10-13': 0.34},
#      'paper': {'2019-07-14': 0.33,
#       '2019-07-21': 0.35,
#       '2019-07-28': 0.35,
#       '2019-08-04': 0.35,
#       '2019-08-11': 0.35,
#       '2019-08-18': 0.33,
#       '2019-08-25': 0.32,
#       '2019-09-01': 0.34,
#       '2019-09-08': 0.33,
#       '2019-09-15': 0.34,
#       '2019-09-22': 0.34,
#       '2019-09-29': 0.34,
#       '2019-10-06': 0.35},
#      'paperFoil': {'2019-07-14': 0.92,
#       '2019-07-21': 0.9,
#       '2019-07-28': 0.9,
#       '2019-08-04': 0.92,
#       '2019-08-11': 0.9,
#       '2019-08-18': 0.9,
#       '2019-08-25': 0.9,
#       '2019-09-01': 0.89,
#       '2019-09-08': 0.89,
#       '2019-09-15': 0.89,
#       '2019-09-22': 0.87,
#       '2019-09-29': 0.89,
#       '2019-10-06': 0.89}},
#     'printings': ['PRNA', 'RNA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/a4a0e74ae4a56fbc',
#      'mtgstocks': 'https://mtgjson.com/links/2bf1ab9b950818d0',
#      'tcgplayer': 'https://mtgjson.com/links/9476bf6b9cb4700e'},
#     'rarity': 'rare',
#     'rulings': [{'date': '2019-01-25',
#       'text': 'Amplifire will be a 1/1 creature from the time your untap step begins until the time its triggered ability resolves during your upkeep.'},
#      {'date': '2019-01-25',
#       'text': 'Any effects that modify Amplifire’s power and/or toughness without setting them to a specific number or value will apply after its base power and toughness are set, regardless of the order in which those effects were created. The same is true of counters that modify its power and toughness.'},
#      {'date': '2019-01-25',
#       'text': 'If you reveal your entire library and don’t reveal a creature card, Amplifire becomes a 0/0 creature and you put your library back in a random order.'}],
#     'scryfallId': '7a58c77f-7c15-44f4-8011-6046482a2d08',
#     'scryfallIllustrationId': '86fce992-2e43-4491-9a5a-646683c2a926',
#     'scryfallOracleId': 'c6861c50-d336-4352-a76d-ec22a86ec09e',
#     'subtypes': ['Elemental'],
#     'supertypes': [],
#     'tcgplayerProductId': 182953,
#     'text': "At the beginning of your upkeep, reveal cards from the top of your library until you reveal a creature card. Until your next turn, Amplifire's base power becomes twice that card's power and its base toughness becomes twice that card's toughness. Put the revealed cards on the bottom of your library in a random order.",
#     'toughness': '1',
#     'type': 'Creature — Elemental',
#     'types': ['Creature'],
#     'uuid': '21cc3904-5ef0-5f93-814b-4f8cc97c9458'},
#    {'artist': 'Ryan Yee',
#     'borderColor': 'black',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 5.0,
#     'edhrecRank': 7853,
#     'foreignData': [{'language': 'German',
#       'multiverseId': 457404,
#       'name': 'Engel der Barmherzigkeit',
#       'text': 'Aufblitzen\nFliegend\nWenn der Engel der Barmherzigkeit ins Spiel kommt, wird dein Lebenspunktestand bis zum Ende des Zuges durch Schaden, der ihn unter 1 reduzieren würde, stattdessen auf 1 reduziert.\n{4}{W}{W}, schicke den Engel der Barmherzigkeit aus deinem Friedhof ins Exil: Dein Lebenspunktestand wird zu 10.',
#       'type': 'Kreatur — Engel'},
#      {'language': 'Spanish',
#       'multiverseId': 457663,
#       'name': 'Ángel de la gracia',
#       'text': 'Destello.\nVuela.\nCuando el Ángel de la gracia entre al campo de batalla, hasta el final del turno, el daño que fuera a reducir tu total de vidas a menos de 1, en vez de eso, lo reduce a 1.\n{4}{W}{W}, exiliar al Ángel de la gracia de tu cementerio: Tu total de vidas se convierte en 10.',
#       'type': 'Criatura — Ángel'},
#      {'language': 'French',
#       'multiverseId': 457922,
#       'name': 'Ange de la grâce',
#       'text': "Flash\nVol\nQuand l'Ange de la grâce arrive sur le champ de bataille, jusqu'à la fin du tour, les blessures qui devraient réduire votre total de points de vie à moins de 1 le réduisent à 1 à la place.\n{4}{W}{W}, exilez l'Ange de la grâce de votre cimetière : Votre total de points de vie devient 10.",
#       'type': 'Créature : ange'},
#      {'language': 'Italian',
#       'multiverseId': 458181,
#       'name': 'Angelo della Grazia',
#       'text': "Lampo\nVolare\nQuando l'Angelo della Grazia entra nel campo di battaglia, fino alla fine del turno, qualsiasi danno che ridurrebbe i tuoi punti vita a meno di 1 li riduce invece a 1.\n{4}{W}{W}, Esilia l'Angelo della Grazia dal tuo cimitero: I tuoi punti vita diventano 10.",
#       'type': 'Creatura — Angelo'},
#      {'language': 'Japanese',
#       'multiverseId': 458440,
#       'name': '恩寵の天使',
#       'text': '瞬速\n飛行\n恩寵の天使が戦場に出たとき、ターン終了時まで、あなたのライフ総量を１点未満に減少させるダメージは、代わりにあなたのライフの総量を１点になるまで減少させる。\n{4}{W}{W}, あなたの墓地から恩寵の天使を追放する：あなたのライフ総量は10点になる。',
#       'type': 'クリーチャー — 天使'},
#      {'language': 'Korean',
#       'multiverseId': 458699,
#       'name': '은총의 천사',
#       'text': '섬광\n비행\n은총의 천사가 전장에 들어올 때, 턴종료까지, 당신의 생명 총점을 1 미만으로 낮추려는 피해는 대신 당신의 생명 총점을 1로 낮춘다.\n{4}{W}{W}, 은총의 천사를 당신의 무덤에서 추방한다: 당신의 생명 총점은 10이 된다.',
#       'type': '생물 — 천사'},
#      {'language': 'Portuguese (Brazil)',
#       'multiverseId': 458958,
#       'name': 'Anjo da Graça',
#       'text': 'Lampejo\nVoar\nQuando Anjo da Graça entra no campo de batalha, até o final do turno, o dano que reduziria seu total de pontos de vida a menos de 1 o reduz, em vez disso, a 1.\n{4}{W}{W}, exile Anjo da Graça de seu cemitério: Seu total de pontos de vida torna-se 10.',
#       'type': 'Criatura — Anjo'},
#      {'language': 'Russian',
#       'multiverseId': 459217,
#       'name': 'Ангел Милости',
#       'text': 'Миг\nПолет\nКогда Ангел Милости выходит на поле битвы, до конца хода повреждения, которые должны снизить ваше количество жизней до значения менее 1, снижают его до 1 вместо этого.\n{4}{W}{W}, изгоните Ангела Милости из вашего кладбища: ваше количество жизней становится равным 10.',
#       'type': 'Существо — Ангел'},
#      {'language': 'Chinese Simplified',
#       'multiverseId': 459476,
#       'name': '恩典天使',
#       'text': '闪现\n飞行\n当恩典天使进战场时，直到回合结束，将使你的总生命减少至1以下的伤害，改为减少你的总生命至1。\n{4}{W}{W}，从你的坟墓场放逐恩典天使：你的总生命成为10。',
#       'type': '生物 ～天使'},
#      {'language': 'Chinese Traditional',
#       'multiverseId': 459735,
#       'name': '恩典天使',
#       'text': '閃現\n飛行\n當恩典天使進戰場時，直到回合結束，將使你的總生命減少至1以下的傷害，改為減少你的總生命至1。\n{4}{W}{W}，從你的墳墓場放逐恩典天使：你的總生命成為10。',
#       'type': '生物 ～天使'}],
#     'frameVersion': '2015',
#     'hasFoil': True,
#     'hasNonFoil': True,
#     'isArena': True,
#     'isMtgo': True,
#     'isPaper': True,
#     'layout': 'normal',
#     'legalities': {'brawl': 'Legal',
#      'commander': 'Legal',
#      'duel': 'Legal',
#      'future': 'Legal',
#      'historic': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'standard': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{3}{W}{W}',
#     'mcmId': 368352,
#     'mcmMetaId': 267660,
#     'mtgArenaId': 69129,
#     'mtgoId': 71002,
#     'mtgstocksId': 47625,
#     'multiverseId': 457145,
#     'name': 'Angel of Grace',
#     'number': '1',
#     'originalText': 'Flash\nFlying\nWhen Angel of Grace enters the battlefield, until end of turn, damage that would reduce your life total to less than 1 reduces it to 1 instead.\n{4}{W}{W}, Exile Angel of Grace from your graveyard: Your life total becomes 10.',
#     'originalType': 'Creature — Angel',
#     'power': '5',
#     'prices': {'mtgo': {'2019-07-13': 3.43,
#       '2019-07-15': 3.4,
#       '2019-07-16': 3.42,
#       '2019-07-18': 3.27,
#       '2019-07-21': 3.12,
#       '2019-07-23': 3.11,
#       '2019-07-24': 3.0,
#       '2019-07-26': 2.92,
#       '2019-07-27': 2.84,
#       '2019-07-31': 2.76,
#       '2019-08-02': 2.67,
#       '2019-08-03': 2.69,
#       '2019-08-10': 2.54,
#       '2019-08-11': 2.48,
#       '2019-08-14': 2.38,
#       '2019-08-22': 2.31,
#       '2019-08-24': 2.25,
#       '2019-08-25': 2.15,
#       '2019-08-28': 2.03,
#       '2019-08-31': 1.92,
#       '2019-09-02': 1.82,
#       '2019-09-03': 1.78,
#       '2019-09-04': 1.77,
#       '2019-09-06': 1.74,
#       '2019-09-07': 1.98,
#       '2019-09-10': 1.94,
#       '2019-09-13': 1.87,
#       '2019-09-16': 1.81,
#       '2019-09-17': 1.69,
#       '2019-09-18': 1.61,
#       '2019-09-20': 1.59,
#       '2019-09-21': 1.56,
#       '2019-09-22': 1.55,
#       '2019-09-23': 1.55,
#       '2019-09-24': 1.54,
#       '2019-09-26': 1.42,
#       '2019-09-27': 1.44,
#       '2019-09-28': 1.43,
#       '2019-09-30': 1.45,
#       '2019-10-02': 1.3,
#       '2019-10-03': 1.19,
#       '2019-10-04': 1.13,
#       '2019-10-06': 1.04,
#       '2019-10-07': 0.93,
#       '2019-10-09': 0.93,
#       '2019-10-11': 0.93,
#       '2019-10-12': 0.9,
#       '2019-10-13': 0.9},
#      'mtgoFoil': {'2019-10-09': 2.22,
#       '2019-10-11': 2.22,
#       '2019-10-12': 2.22,
#       '2019-10-13': 2.22},
#      'paper': {'2019-07-14': 1.99,
#       '2019-07-21': 1.99,
#       '2019-07-28': 1.89,
#       '2019-08-04': 1.79,
#       '2019-08-11': 1.79,
#       '2019-08-18': 1.67,
#       '2019-08-25': 1.59,
#       '2019-09-01': 1.65,
#       '2019-09-08': 1.63,
#       '2019-09-15': 1.64,
#       '2019-09-22': 1.57,
#       '2019-09-29': 1.53,
#       '2019-10-06': 1.51},
#      'paperFoil': {'2019-07-14': 9.95,
#       '2019-07-21': 9.03,
#       '2019-07-28': 8.88,
#       '2019-08-04': 8.68,
#       '2019-08-11': 8.2,
#       '2019-08-18': 7.99,
#       '2019-08-25': 7.99,
#       '2019-09-01': 7.39,
#       '2019-09-08': 7.01,
#       '2019-09-15': 6.91,
#       '2019-09-22': 6.42,
#       '2019-09-29': 5.95,
#       '2019-10-06': 5.49}},
#     'printings': ['RNA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/a3a88a81bfd81d82',
#      'mtgstocks': 'https://mtgjson.com/links/be628f4a2746ba08',
#      'tcgplayer': 'https://mtgjson.com/links/58399f09d526df32'},
#     'rarity': 'mythic',
#     'rulings': [{'date': '2019-01-25',
#       'text': 'Angel of Grace’s triggered ability doesn’t prevent damage. It only changes the result of damage dealt to you. For example, a creature with lifelink that deals damage to you will still cause its controller to gain life, even if that damage would reduce your life total to less than 1.'},
#      {'date': '2019-01-25',
#       'text': 'Angel of Grace’s triggered ability doesn’t stop loss of life from effects that say that you lose life.'},
#      {'date': '2019-01-25',
#       'text': 'If you have less than 1 life and somehow haven’t lost the game, damage dealt to you reduces your life total further below 0 (as normal).'},
#      {'date': '2019-01-25',
#       'text': 'For a player’s life total to become 10, that player gains or loses the appropriate amount of life. For example, if your life total is 2, Angel of Grace’s last ability will cause you to gain 8 life; alternatively, if your life total is 20, it will cause you to lose 10 life. Other cards that interact with life gain or life loss will interact with this effect accordingly.'},
#      {'date': '2019-01-25',
#       'text': 'In a Two-Headed Giant game, after resolving Angel of Grace’s triggered ability, damage dealt to you and/or your teammate that would reduce your team’s life total to less than 1 reduces it to 1 instead.'},
#      {'date': '2019-01-25',
#       'text': 'In a Two-Headed Giant game, the activated ability of Angel of Grace causes you to gain or lose life so that your team’s life total becomes 10.'},
#      {'date': '2019-01-25',
#       'text': 'In a Commander game, combat damage you’re dealt by a commander is still tracked, even if it doesn’t change your life total.'}],
#     'scryfallId': '80164e61-3e94-4e10-9bd1-518b8dc7fc4c',
#     'scryfallIllustrationId': 'ed38713a-f6f3-4ad9-9e60-3e384ebd33ec',
#     'scryfallOracleId': 'fcfcac6b-6d26-4ffe-ae9e-b0ee7fa49787',
#     'subtypes': ['Angel'],
#     'supertypes': [],
#     'tcgplayerProductId': 183201,
#     'text': 'Flash\nFlying\nWhen Angel of Grace enters the battlefield, until end of turn, damage that would reduce your life total to less than 1 reduces it to 1 instead.\n{4}{W}{W}, Exile Angel of Grace from your graveyard: Your life total becomes 10.',
#     'toughness': '4',
#     'type': 'Creature — Angel',
#     'types': ['Creature'],
#     'uuid': '7eb0f276-5e32-5a1e-acfd-9b0ddc19b845'},
#    {'artist': 'John Severin Brassell',
#     'borderColor': 'black',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'convertedManaCost': 4.0,
#     'edhrecRank': 6968,
#     'flavorText': '"If we cannot have peace, we will have justice."\n—Aurelia',
#     'foreignData': [{'flavorText': '„Wenn uns der Friede nicht vergönnt ist, werden wir zumindest Gerechtigkeit haben."\n—Aurelia',
#       'language': 'German',
#       'multiverseId': 457405,
#       'name': 'Engelsgleicher Edelmut',
#       'text': 'Immer wenn eine Kreatur, die du kontrollierst, alleine angreift, erhält sie +X/+X bis zum Ende des Zuges, wobei X gleich der Anzahl an Kreaturen ist, die du kontrollierst.',
#       'type': 'Verzauberung'},
#      {'flavorText': '"Si no podemos tener la paz, tendremos justicia".\n—Aurelia',
#       'language': 'Spanish',
#       'multiverseId': 457664,
#       'name': 'Exaltación angélica',
#       'text': 'Siempre que una criatura que controlas ataque sola, obtiene +X/+X hasta el final del turno, donde X es la cantidad de criaturas que controlas.',
#       'type': 'Encantamiento'},
#      {'flavorText': '« Si nous ne pouvons obtenir la paix, nous obtiendrons justice. »\n—Aurélia',
#       'language': 'French',
#       'multiverseId': 457923,
#       'name': 'Exaltation angélique',
#       'text': "À chaque fois qu'une créature que vous contrôlez attaque seule, elle gagne +X/+X jusqu'à la fin du tour, X étant le nombre de créatures que vous contrôlez.",
#       'type': 'Enchantement'},
#      {'flavorText': '"Se non possiamo portare la pace, porteremo la giustizia."\n—Aurelia',
#       'language': 'Italian',
#       'multiverseId': 458182,
#       'name': 'Esaltazione Angelica',
#       'text': 'Ogniqualvolta una creatura che controlli attacca da sola, prende +X/+X fino alla fine del turno, dove X è il numero di creature che controlli.',
#       'type': 'Incantesimo'},
#      {'flavorText': '「平和を手にできないとしても、我々の手には正義がある。」\n――オレリア',
#       'language': 'Japanese',
#       'multiverseId': 458441,
#       'name': '天使の称賛',
#       'text': 'あなたがコントロールしているクリーチャーが単独で攻撃するたび、ターン終了時まで、それは＋Ｘ/＋Ｘの修整を受ける。Ｘはあなたがコントロールしているクリーチャーの総数に等しい。',
#       'type': 'エンチャント'},
#      {'flavorText': '"평화를 얻을 수 없다면, 정의를 얻으리라."\n—아우렐리아',
#       'language': 'Korean',
#       'multiverseId': 458700,
#       'name': '천사의 행복',
#       'text': '당신이 조종하는 생물이 혼자 공격할 때마다, 그 생물은 턴종료까지 +X/+X를 받는다. X는 당신이 조종하는 생물의 수이다.',
#       'type': '부여마법'},
#      {'flavorText': '"Se não pudermos ter paz, teremos justiça."\n— Aurélia',
#       'language': 'Portuguese (Brazil)',
#       'multiverseId': 458959,
#       'name': 'Exaltação Angelical',
#       'text': 'Toda vez que uma criatura que você controla ataca sozinha, ela recebe +X/+X até o final do turno, sendo X o número de criaturas que você controla.',
#       'type': 'Encantamento'},
#      {'flavorText': '«Коль скоро нам не суждено обрести мир, мы обретем правосудие».\n— Аурелия',
#       'language': 'Russian',
#       'multiverseId': 459218,
#       'name': 'Ангельское Упоение',
#       'text': 'Каждый раз, когда существо под вашим контролем атакует в одиночку, оно получает +X/+X до конца хода, где Х — количество существ под вашим контролем.',
#       'type': 'Чары'},
#      {'flavorText': '「如果和平不保，我们必将昭彰正义。」\n～欧瑞梨',
#       'language': 'Chinese Simplified',
#       'multiverseId': 459477,
#       'name': '天使颂赞',
#       'text': '每当一个由你操控的生物单独攻击时，它得+X/+X直到回合结束，X为由你操控的生物数量。',
#       'type': '结界'},
#      {'flavorText': '「如果和平不保，我們必將昭彰正義。」\n～歐瑞梨',
#       'language': 'Chinese Traditional',
#       'multiverseId': 459736,
#       'name': '天使頌讚',
#       'text': '每當一個由你操控的生物單獨攻擊時，它得+X/+X直到回合結束，X為由你操控的生物數量。',
#       'type': '結界'}],
#     'frameVersion': '2015',
#     'hasFoil': True,
#     'hasNonFoil': True,
#     'isArena': True,
#     'isMtgo': True,
#     'isPaper': True,
#     'layout': 'normal',
#     'legalities': {'brawl': 'Legal',
#      'commander': 'Legal',
#      'duel': 'Legal',
#      'future': 'Legal',
#      'historic': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'penny': 'Legal',
#      'standard': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{3}{W}',
#     'mcmId': 368160,
#     'mcmMetaId': 267581,
#     'mtgArenaId': 69130,
#     'mtgoId': 71004,
#     'mtgstocksId': 47594,
#     'multiverseId': 457146,
#     'name': 'Angelic Exaltation',
#     'number': '2',
#     'originalText': 'Whenever a creature you control attacks alone, it gets +X/+X until end of turn, where X is the number of creatures you control.',
#     'originalType': 'Enchantment',
#     'prices': {'mtgo': {'2019-10-09': 0.01,
#       '2019-10-11': 0.01,
#       '2019-10-12': 0.01,
#       '2019-10-13': 0.01},
#      'mtgoFoil': {'2019-10-09': 0.17,
#       '2019-10-11': 0.17,
#       '2019-10-12': 0.17,
#       '2019-10-13': 0.17},
#      'paper': {'2019-07-14': 0.24,
#       '2019-07-21': 0.25,
#       '2019-07-28': 0.24,
#       '2019-08-04': 0.24,
#       '2019-08-11': 0.24,
#       '2019-08-18': 0.24,
#       '2019-08-25': 0.24,
#       '2019-09-01': 0.24,
#       '2019-09-08': 0.22,
#       '2019-09-15': 0.21,
#       '2019-09-22': 0.21,
#       '2019-09-29': 0.23,
#       '2019-10-06': 0.24},
#      'paperFoil': {'2019-07-14': 0.73,
#       '2019-07-21': 0.75,
#       '2019-07-28': 0.73,
#       '2019-08-04': 0.73,
#       '2019-08-11': 0.74,
#       '2019-08-18': 0.71,
#       '2019-08-25': 0.68,
#       '2019-09-01': 0.68,
#       '2019-09-08': 0.65,
#       '2019-09-15': 0.65,
#       '2019-09-22': 0.64,
#       '2019-09-29': 0.64,
#       '2019-10-06': 0.65}},
#     'printings': ['RNA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/6e9d6b79d3df1253',
#      'mtgstocks': 'https://mtgjson.com/links/6f363d0ba93a0ad9',
#      'tcgplayer': 'https://mtgjson.com/links/8e153f94a55f2a36'},
#     'rarity': 'uncommon',
#     'rulings': [{'date': '2019-01-25',
#       'text': 'A creature attacks alone if it’s the only creature declared as an attacker during the declare attackers step (including creatures controlled by your teammates, if applicable). For example, Angelic Exaltation’s ability won’t trigger if you attack with multiple creatures and all but one of them are removed from combat.'},
#      {'date': '2019-01-25',
#       'text': 'The value of X is determined only as Angelic Exaltation’s ability begins to resolve. It won’t change later in the turn if the number of creatures you control changes.'}],
#     'scryfallId': 'ee7b5ae5-0f6b-4f45-8597-4e6212d2ad0e',
#     'scryfallIllustrationId': '0afc90ee-852c-4ba8-8af3-8469ab6ec8f0',
#     'scryfallOracleId': '507d2f27-08a9-4938-b191-5734cda42ef2',
#     'subtypes': [],
#     'supertypes': [],
#     'tcgplayerProductId': 183088,
#     'text': 'Whenever a creature you control attacks alone, it gets +X/+X until end of turn, where X is the number of creatures you control.',
#     'type': 'Enchantment',
#     'types': ['Enchantment'],
#     'uuid': '344b3de7-f937-5238-b0c2-689b11921d12'},
#    {'artist': 'Sidharth Chaturvedi',
#     'borderColor': 'black',
#     'colorIdentity': ['G', 'U'],
#     'colors': ['G', 'U'],
#     'convertedManaCost': 2.0,
#     'edhrecRank': 10728,
#     'foreignData': [{'language': 'German',
#       'multiverseId': 457556,
#       'name': 'Angewandte Biomagie',
#       'text': 'Bestimme eines oder beides —\n• Eine Kreatur deiner Wahl erhält +1/+1 bis zum Ende des Zuges.\n• Bringe eine Kreatur deiner Wahl auf die Hand ihres Besitzers zurück.',
#       'type': 'Spontanzauber'},
#      {'language': 'Spanish',
#       'multiverseId': 457815,
#       'name': 'Biomancia aplicada',
#       'text': 'Elige uno o ambos:\n• La criatura objetivo obtiene +1/+1 hasta el final del turno.\n• Regresa la criatura objetivo a la mano de su propietario.',
#       'type': 'Instantáneo'},
#      {'language': 'French',
#       'multiverseId': 458074,
#       'name': 'Biomancie appliquée',
#       'text': "Choisissez l'un ou les deux —\n• La créature ciblée gagne +1/+1 jusqu'à la fin du tour.\n• Renvoyez une créature ciblée dans la main de son propriétaire.",
#       'type': 'Éphémère'},
#      {'language': 'Italian',
#       'multiverseId': 458333,
#       'name': 'Biomanzia Applicata',
#       'text': 'Scegli uno o entrambi —\n• Una creatura bersaglio prende +1/+1 fino alla fine del turno.\n• Fai tornare una creatura bersaglio in mano al suo proprietario.',
#       'type': 'Istantaneo'},
#      {'language': 'Japanese',
#       'multiverseId': 458592,
#       'name': '応用生術',
#       'text': '以下から１つまたは両方を選ぶ。\n• クリーチャー１体を対象とする。ターン終了時まで、それは＋１/＋１の修整を受ける。\n• クリーチャー１体を対象とし、それをオーナーの手札に戻す。',
#       'type': 'インスタント'},
#      {'language': 'Korean',
#       'multiverseId': 458851,
#       'name': '응용 생명술',
#       'text': '하나 혹은 둘 다를 선택한다 —\n• 생물을 목표로 정한다. 그 생물은 턴종료까지 +1/+1을 받는다.\n• 생물을 목표로 정한다. 그 생물을 소유자의 손으로 되돌린다.',
#       'type': '순간마법'},
#      {'language': 'Portuguese (Brazil)',
#       'multiverseId': 459110,
#       'name': 'Biomancia Aplicada',
#       'text': 'Escolha um ou ambos —\n• A criatura alvo recebe +1/+1 até o final do turno.\n• Devolva a criatura alvo para a mão de seu dono.',
#       'type': 'Mágica Instantânea'},
#      {'language': 'Russian',
#       'multiverseId': 459369,
#       'name': 'Прикладная Биомантика',
#       'text': 'Выберите одно или оба —\n• Целевое существо получает +1/+1 до конца хода.\n• Верните целевое существо в руку его владельца.',
#       'type': 'Мгновенное заклинание'},
#      {'language': 'Chinese Simplified',
#       'multiverseId': 459628,
#       'name': '实用生机术',
#       'text': '选择一项或都选～\n•目标生物得+1/+1直到回合结束。\n•将目标生物移回其拥有者手上。',
# ...
#     'convertedManaCost': 2.0,
#     'edhrecRank': 12322,
#     'flavorText': 'Among the Zhur-Taa Clan, goblins are the first to enter battlefury. When the battle is over, the survivors are still frothing at the mouth, looking for someone to hit.',
#     'foreignData': [{'flavorText': 'Innerhalb des Zhur-Taa-Clans sind die Goblins die ersten, die dem Kampfrausch verfallen. Nach der Schlacht suchen die Überlebenden mit schäumenden Mäulern weiter nach Gegnern zum Verprügeln.',
#       'language': 'German',
#       'multiverseId': 457618,
#       'name': 'Zhur-Taa-Goblin',
#       'text': 'Aufruhr (Du bestimmst, ob diese Kreatur mit einer +1/+1-Marke oder mit Eile ins Spiel kommt.)',
#       'type': 'Kreatur — Goblin, Berserker'},
#      {'flavorText': 'En el clan Zhur-Taa, los trasgos son los que más se dejan llevar por la furia de batalla. Cuando la lucha termina, los supervivientes aún echan espuma por la boca y buscan alguien a quien golpear.',
#       'language': 'Spanish',
#       'multiverseId': 457877,
#       'name': 'Trasgo Zhur-Taa',
#       'text': 'Insurgencia. (Esta criatura entra al campo de batalla con lo que elijas: un contador +1/+1 o la habilidad de prisa.)',
#       'type': 'Criatura — Berserker trasgo'},
#      {'flavorText': "Les gobelins du clan Zhur-Taa sont les premiers à être pris de la frénésie du combat. À la fin de la bataille, les survivants ont encore l'écume aux lèvres, et cherchent quelqu'un à frapper.",
#       'language': 'French',
#       'multiverseId': 458136,
#       'name': 'Gobelin de Zhur-Taa',
#       'text': 'Émeute (Cette créature arrive sur le champ de bataille avec, selon votre choix, un marqueur +1/+1 ou la célérité.)',
#       'type': 'Créature : gobelin et berserker'},
#      {'flavorText': 'Nel clan Zhur-Taa, i goblin sono i primi a essere colti dalla frenesia della battaglia. Al termine del combattimento, i superstiti schiumano ancora per la furia, in cerca di qualcuno da colpire.',
#       'language': 'Italian',
#       'multiverseId': 458395,
#       'name': 'Goblin del Clan Zhur-Taa',
#       'text': 'Tumulto (Questa creatura entra nel campo di battaglia con un segnalino +1/+1 o rapidità a tua scelta.)',
#       'type': 'Creatura — Berserker Goblin'},
#      {'flavorText': 'ザル＝ター族の中では、ゴブリンが誰より先に闘争心を燃やす。戦いが終わっても、生き残ったゴブリンたちはまだ怒りに燃えながら殴る相手を探している。',
#       'language': 'Japanese',
#       'multiverseId': 458654,
#       'name': 'ザル＝ターのゴブリン',
#       'text': '暴動（このクリーチャーは＋１/＋１カウンター１個か速攻のうちあなたが選んだ１つを持った状態で戦場に出る。）',
#       'type': 'クリーチャー — ゴブリン・狂戦士'},
#      {'flavorText': '주르-타아 부족에서는 고블린들이 처음으로 전투분노에 들어간다. 전투가 끝나고 나서도, 살아남은 고블린들은 여전히 입에 거품을 물고 공격할 자들을 찾아다닌다.',
#       'language': 'Korean',
#       'multiverseId': 458913,
#       'name': '주르-타아 부족 고블린',
#       'text': '폭동 (이 생물은 당신의 선택에 따라 +1/+1 카운터 한 개 또는 신속을 가지고 전장에 들어온다.)',
#       'type': '생물 — 고블린 광전사'},
#      {'flavorText': 'No Clã Zhur-Taa, os goblins são os primeiros a entrar em fúria de batalha. Quando a batalha termina, os sobreviventes ainda estão espumando pela boca, procurando alguém em quem bater.',
#       'language': 'Portuguese (Brazil)',
#       'multiverseId': 459172,
#       'name': 'Goblin Zhur-Taa',
#       'text': 'Tumulto (Esta criatura entra no campo de batalha com um marcador +1/+1 ou ímpeto, à sua escolha.)',
#       'type': 'Criatura — Goblin Amoque'},
#      {'flavorText': 'В клане Зур-Таа гоблины первыми впадают в боевое бешенство. Даже когда битва уже закончена, у выживших идет пена изо рта, и они ищут, кого бы еще треснуть.',
#       'language': 'Russian',
#       'multiverseId': 459431,
#       'name': 'Гоблин из Зур-Таа',
#       'text': 'Беспорядки (Это существо выходит на поле битвы с одним жетоном +1/+1 или Ускорением, по вашему выбору.)',
#       'type': 'Существо — Гоблин Берсерк'},
#      {'flavorText': '在筑塔族中，鬼怪总是先人一步进入战怒状态。战斗结束后，幸存者依然满腔怒火，想要敲人。',
#       'language': 'Chinese Simplified',
#       'multiverseId': 459690,
#       'name': '筑塔族鬼怪',
#       'text': '起事（于此生物进战场时，你选择「+1/+1指示物」或「敏捷」异能。它进战场时上面有所选加成。）',
#       'type': '生物 ～鬼怪／狂战士'},
#      {'flavorText': '在筑塔族中，鬼怪總是先人一步進入戰怒狀態。戰鬥結束後，倖存者依然滿腔怒火，想要敲人。',
#       'language': 'Chinese Traditional',
#       'multiverseId': 459949,
#       'name': '筑塔族鬼怪',
#       'text': '起事（於此生物進戰場時，你選擇「+1/+1指示物」或「敏捷」異能。它進戰場時上面有所選加成。）',
#       'type': '生物 ～鬼怪／狂戰士'}],
#     'frameVersion': '2015',
#     'hasFoil': True,
#     'hasNonFoil': True,
#     'isArena': True,
#     'isMtgo': True,
#     'isPaper': True,
#     'layout': 'normal',
#     'legalities': {'brawl': 'Legal',
#      'commander': 'Legal',
#      'duel': 'Legal',
#      'future': 'Legal',
#      'historic': 'Legal',
#      'legacy': 'Legal',
#      'modern': 'Legal',
#      'penny': 'Legal',
#      'standard': 'Legal',
#      'vintage': 'Legal'},
#     'manaCost': '{R}{G}',
#     'mcmId': 368139,
#     'mcmMetaId': 267563,
#     'mtgArenaId': 69343,
#     'mtgoId': 71430,
#     'mtgstocksId': 47575,
#     'multiverseId': 457359,
#     'name': 'Zhur-Taa Goblin',
#     'number': '215',
#     'originalText': 'Riot (This creature enters the battlefield with your choice of a +1/+1 counter or haste.)',
#     'originalType': 'Creature — Goblin Berserker',
#     'power': '2',
#     'prices': {'mtgo': {'2019-10-09': 0.01,
#       '2019-10-11': 0.01,
#       '2019-10-12': 0.01,
#       '2019-10-13': 0.01},
#      'mtgoFoil': {'2019-10-09': 0.02,
#       '2019-10-11': 0.02,
#       '2019-10-12': 0.02,
#       '2019-10-13': 0.02},
#      'paper': {'2019-07-14': 0.24,
#       '2019-07-21': 0.25,
#       '2019-07-28': 0.25,
#       '2019-08-04': 0.25,
#       '2019-08-11': 0.25,
#       '2019-08-18': 0.25,
#       '2019-08-25': 0.24,
#       '2019-09-01': 0.24,
#       '2019-09-08': 0.22,
#       '2019-09-15': 0.21,
#       '2019-09-22': 0.22,
#       '2019-09-29': 0.21,
#       '2019-10-06': 0.22},
#      'paperFoil': {'2019-07-14': 0.97,
#       '2019-07-21': 0.98,
#       '2019-07-28': 0.9,
#       '2019-08-04': 0.87,
#       '2019-08-11': 0.88,
#       '2019-08-18': 0.87,
#       '2019-08-25': 0.88,
#       '2019-09-01': 0.87,
#       '2019-09-08': 0.8,
#       '2019-09-15': 0.84,
#       '2019-09-22': 0.82,
#       '2019-09-29': 0.85,
#       '2019-10-06': 0.84}},
#     'printings': ['RNA'],
#     'purchaseUrls': {'cardmarket': 'https://mtgjson.com/links/7d1b47952808fe62',
#      'mtgstocks': 'https://mtgjson.com/links/93b64ad6c7be5e90',
#      'tcgplayer': 'https://mtgjson.com/links/6829d6359482cd03'},
#     'rarity': 'uncommon',
#     'rulings': [{'date': '2019-01-25',
#       'text': 'Riot is a replacement effect. Players can’t respond to your choice of +1/+1 counter or haste, and they can’t take actions while the creature is on the battlefield without one or the other.'},
#      {'date': '2019-01-25',
#       'text': 'If a creature entering the battlefield has riot but can’t have a +1/+1 counter put onto it, it gains haste.'},
#      {'date': '2019-01-25',
#       'text': 'If you choose for the creature to gain haste, it gains haste indefinitely. It won’t lose it as the turn ends or as another player gains control of it.'}],
#     'scryfallId': '13070db2-cf89-4552-8b6c-76426274321a',
#     'scryfallIllustrationId': 'f6e5dc28-3820-481c-b7dd-00d7b9f82d1a',
#     'scryfallOracleId': '1003304f-af01-4235-af82-6ef901bd00bf',
#     'subtypes': ['Goblin', 'Berserker'],
#     'supertypes': [],
#     'tcgplayerProductId': 183030,
#     'text': 'Riot (This creature enters the battlefield with your choice of a +1/+1 counter or haste.)',
#     'toughness': '2',
#     'type': 'Creature — Goblin Berserker',
#     'types': ['Creature'],
#     'uuid': '27bc634e-c145-51ec-a8d7-61e332934179',
#     'watermark': 'gruul'}],
#   'code': 'RNA',
#   'isFoilOnly': False,
#   'isOnlineOnly': False,
#   'keyruneCode': 'RNA',
#   'mcmId': 2411,
#   'mcmName': 'Ravnica Allegiance',
#   'meta': {'date': '2019-10-13',
#    'pricesDate': '2019-10-13',
#    'version': '4.5.1-rebuild.4'},
#   'mtgoCode': 'RNA',
#   'name': 'Ravnica Allegiance',
#   'releaseDate': '2019-01-25',
#   'tcgplayerGroupId': 2366,
#   'tokens': [{'artist': 'Winona Nelson',
#     'borderColor': 'black',
#     'colorIdentity': ['G', 'R'],
#     'colors': ['G', 'R'],
#     'layout': 'normal',
#     'name': 'Beast',
#     'number': '8',
#     'power': '4',
#     'reverseRelated': ['Domri, Chaos Bringer', 'Thrash // Threat'],
#     'scryfallId': '87ec9ade-1e06-43c9-97df-55465cabdf32',
#     'scryfallIllustrationId': 'e71675cc-6d16-4d9f-93a5-9881dfdf8346',
#     'scryfallOracleId': '799e1995-cd7e-4147-b26c-7f3d031ed174',
#     'subtypes': ['Beast'],
#     'supertypes': [],
#     'text': 'Trample',
#     'toughness': '4',
#     'type': 'Token Creature — Beast',
#     'types': ['Token', 'Creature'],
#     'watermark': 'gruul'},
#    {'artist': 'Sidharth Chaturvedi',
#     'borderColor': 'black',
#     'colorIdentity': ['G'],
#     'colors': ['G'],
#     'layout': 'normal',
#     'name': 'Centaur',
#     'number': '5',
#     'power': '3',
#     'reverseRelated': ['Rampage of the Clans'],
#     'scryfallId': '5fc993a7-a1ce-4403-a0a0-2afc9f9eca42',
#     'scryfallIllustrationId': 'fad23b90-a84c-4fc4-a6c6-1ee0c99287c5',
#     'scryfallOracleId': 'c41ea1cd-d87a-4e4c-b814-4c24c5bef511',
#     'subtypes': ['Centaur'],
#     'supertypes': [],
#     'toughness': '3',
#     'type': 'Token Creature — Centaur',
#     'types': ['Token', 'Creature']},
#    {'artist': 'Zack Stella',
#     'borderColor': 'black',
#     'colorIdentity': [],
#     'colors': [],
#     'layout': 'emblem',
#     'name': 'Domri, Chaos Bringer Emblem',
#     'number': '13',
#     'reverseRelated': [],
#     'scryfallId': '44717d19-d8c2-45ba-9904-00c0c79ee0c3',
#     'scryfallIllustrationId': '9b8abfc4-72a8-4602-b6c7-b3de385c53c3',
#     'scryfallOracleId': 'a6696704-ac0f-4319-a3c4-f6739f84d7d1',
#     'subtypes': ['Domri'],
#     'supertypes': [],
#     'text': 'At the beginning of each end step, create a 4/4 red and green Beast creature token with trample.',
#     'type': 'Emblem — Domri',
#     'types': ['Emblem']},
#    {'artist': 'Jack Wang',
#     'borderColor': 'black',
#     'colorIdentity': ['G'],
#     'colors': ['G'],
#     'layout': 'normal',
#     'name': 'Frog Lizard',
#     'number': '6',
#     'power': '3',
#     'reverseRelated': ['Incubation // Incongruity'],
#     'scryfallId': '495d3391-6311-418e-b55a-10c0af751026',
#     'scryfallIllustrationId': '44cb22ed-7a4c-4e3f-bbd3-548940000a78',
#     'scryfallOracleId': '8653c69b-99a9-4881-a14c-68ba928c34d5',
#     'subtypes': ['Frog', 'Lizard'],
#     'supertypes': [],
#     'toughness': '3',
#     'type': 'Token Creature — Frog Lizard',
#     'types': ['Token', 'Creature']},
#    {'artist': 'Svetlin Velinov',
#     'borderColor': 'black',
#     'colorIdentity': ['R'],
#     'colors': ['R'],
#     'layout': 'normal',
#     'name': 'Goblin',
#     'number': '4',
#     'power': '1',
#     'reverseRelated': ['Goblin Gathering',
#      'Legion Warboss',
#      'Krenko, Tin Street Kingpin'],
#     'scryfallId': '993613a6-09a9-45a5-b35f-5a5fdb6d14ec',
#     'scryfallIllustrationId': '0f1b8921-4cce-4f76-bf88-42798b11d519',
#     'scryfallOracleId': '4465eff4-5851-4721-a248-866c686c2ab8',
#     'subtypes': ['Goblin'],
#     'supertypes': [],
#     'toughness': '1',
#     'type': 'Token Creature — Goblin',
#     'types': ['Token', 'Creature']},
#    {'artist': 'Bram Sels',
#     'borderColor': 'black',
#     'colorIdentity': ['W'],
#     'colors': ['W'],
#     'layout': 'normal',
#     'name': 'Human',
#     'number': '1',
#     'power': '1',
#     'reverseRelated': ['Hero of Precinct One', 'Watchful Giant'],
#     'scryfallId': '5f2a2483-d21f-4c31-9a36-ed7c5672894b',
#     'scryfallIllustrationId': '0d48a34e-af36-4147-a48b-2141ec7ce220',
#     'scryfallOracleId': '30272edf-097c-4918-84d2-9fa6c42dbe0a',
#     'subtypes': ['Human'],
#     'supertypes': [],
#     'toughness': '1',
#     'type': 'Token Creature — Human',
#     'types': ['Token', 'Creature']},
#    {'artist': 'Kev Walker',
#     'borderColor': 'black',
#     'colorIdentity': ['U'],
#     'colors': ['U'],
#     'layout': 'normal',
#     'name': 'Illusion',
#     'number': '2',
#     'power': '0',
#     'reverseRelated': ['Mesmerizing Benthid'],
#     'scryfallId': 'ccc3d8da-9005-44d9-bb10-18cdac7a32f5',
#     'scryfallIllustrationId': 'b8bc24da-d3bf-4385-a813-71722c69fdfe',
#     'scryfallOracleId': '349852d6-1697-48cf-86a4-c20a2aabf0fc',
#     'subtypes': ['Illusion'],
#     'supertypes': [],
#     'text': "Whenever this creature blocks a creature, that creature doesn't untap during its controller's next untap step.",
#     'toughness': '2',
#     'type': 'Token Creature — Illusion',
#     'types': ['Token', 'Creature']},
#    {'artist': 'Lake Hurwitz',
#     'borderColor': 'black',
#     'colorIdentity': ['G'],
#     'colors': ['G'],
#     'layout': 'normal',
#     'name': 'Ooze',
#     'number': '7',
#     'power': '2',
#     'reverseRelated': ['Biogenic Ooze'],
#     'scryfallId': '0260e0ae-bf09-430a-a449-c16219d84b63',
#     'scryfallIllustrationId': '3f428748-d3ee-4480-a52f-2829695c6f05',
#     'scryfallOracleId': '48bf9588-91fa-4f4c-a93a-3bef29ac9c27',
#     'subtypes': ['Ooze'],
#     'supertypes': [],
#     'toughness': '2',
#     'type': 'Token Creature — Ooze',
#     'types': ['Token', 'Creature']},
#    {'artist': 'Scott Murphy',
#     'borderColor': 'black',
#     'colorIdentity': ['U', 'W'],
#     'colors': ['U', 'W'],
#     'layout': 'normal',
#     'name': 'Sphinx',
#     'number': '9',
#     'power': '4',
#     'reverseRelated': ['Warrant // Warden'],
#     'scryfallId': 'f82ba894-7b10-45ae-9322-60ef85a2869d',
#     'scryfallIllustrationId': '654614a5-d022-4af8-814c-e510e731d9cc',
#     'scryfallOracleId': '814c8e0b-694e-4b65-a0b6-518ac005b218',
#     'subtypes': ['Sphinx'],
#     'supertypes': [],
#     'text': 'Flying, vigilance',
#     'toughness': '4',
#     'type': 'Token Creature — Sphinx',
#     'types': ['Token', 'Creature'],
#     'watermark': 'azorius'},
#    {'artist': 'Josh Hass',
#     'borderColor': 'black',
#     'colorIdentity': ['B', 'W'],
#     'colors': ['B', 'W'],
#     'layout': 'normal',
#     'name': 'Spirit',
#     'number': '10',
#     'power': '1',
#     'reverseRelated': ['Ethereal Absolution', 'Knight of the Last Breath'],
#     'scryfallId': '45b3bdd7-b093-4bfd-8a9a-965e72bfefb3',
#     'scryfallIllustrationId': 'cb429ac9-75e2-41c0-bcb1-18da51093d50',
#     'scryfallOracleId': '18ef473d-f958-4bff-8045-154f6adc6b04',
#     'subtypes': ['Spirit'],
#     'supertypes': [],
#     'text': 'Flying',
#     'toughness': '1',
#     'type': 'Token Creature — Spirit',
#     'types': ['Token', 'Creature'],
#     'watermark': 'orzhov'},
#    {'artist': 'Darren Tan',
#     'borderColor': 'black',
#     'colorIdentity': [],
#     'colors': [],
#     'layout': 'normal',
#     'name': 'Thopter',
#     'number': '11',
#     'power': '1',
#     'reverseRelated': ['Dovin, Grand Arbiter', 'Depose // Deploy'],
#     'scryfallId': '8dd768c3-f278-41f8-b329-8403391d6326',
#     'scryfallIllustrationId': 'da982e4b-9fcf-4674-a5f2-9bd8b0e2f440',
#     'scryfallOracleId': '7c0b6b53-4ddb-4bb5-8a26-0041b2006d3f',
#     'subtypes': ['Thopter'],
#     'supertypes': [],
#     'text': 'Flying',
#     'toughness': '1',
#     'type': 'Token Artifact Creature — Thopter',
#     'types': ['Token', 'Artifact', 'Creature'],
#     'watermark': 'azorius'},
#    {'artist': 'Mark Behm',
#     'borderColor': 'black',
#     'colorIdentity': [],
#     'colors': [],
#     'layout': 'normal',
#     'name': 'Treasure',
#     'number': '12',
#     'reverseRelated': ['Smothering Tithe'],
#     'scryfallId': '0559f9f3-eff0-465d-93c1-e875a8afe87f',
#     'scryfallIllustrationId': 'd9fbc3b2-23da-4626-8835-f15e8503c71d',
#     'scryfallOracleId': '3c549374-6c37-42e0-8d88-a8555d46732d',
#     'subtypes': ['Treasure'],
#     'supertypes': [],
#     'text': '{T}, Sacrifice this artifact: Add one mana of any color.',
#     'type': 'Token Artifact — Treasure',
#     'types': ['Token', 'Artifact']},
#    {'artist': 'Jason A. Engle',
#     'borderColor': 'black',
#     'colorIdentity': ['B'],
#     'colors': ['B'],
#     'layout': 'normal',
#     'name': 'Zombie',
#     'number': '3',
#     'power': '2',
#     'reverseRelated': ['Awaken the Erstwhile',
#      'Liliana, Dreadhorde General',
#      'Captive Audience'],
#     'scryfallId': '27b69e52-f394-4863-943b-239e96b5cc95',
#     'scryfallIllustrationId': '98966695-2af7-4434-8b41-b119bd1fabea',
#     'scryfallOracleId': 'ddc8c973-c31e-463f-be45-f3fa7d632362',
#     'subtypes': ['Zombie'],
#     'supertypes': [],
#     'toughness': '2',
#     'type': 'Token Creature — Zombie',
#     'types': ['Token', 'Creature']}],
#   'totalSetSize': 273,
#   'translations': {},
#   'type': 'expansion'})

# %%
standard_sets_clean['ELD']['cards'][1]['rarity']
# Out:
# 'rare'

# %% [markdown]
# ### Assessment
# - need names and rarity of the card in one dataset

# %% [markdown]
# ## Clean

# %% [markdown]
# ### Define
# - use pandas to tidy the data by making it a dataframe with only two variables: name and rarity

# %% [markdown]
# ### Code

# %%
# code to get rarity in a list by themselves
card_rarities = []
for i in standard_sets_clean.keys():
    current_set = standard_sets_clean[i]['cards']
    for a in np.arange(np.count_nonzero(current_set)):
        rarity = current_set[a]['rarity']
        card_rarities.append(rarity)

# %%
# code to get names in a list by themselves
card_names = []
for i in standard_sets_clean.keys():
    current_set = standard_sets_clean[i]['cards']
    for a in np.arange(np.count_nonzero(current_set)):
        name = current_set[a]['name']
        card_names.append(name)

# %%
# code to create dataframe of card_rarities and card_names
mtg_card_rarities = pd.DataFrame({'name': card_names, 'rarity': card_rarities})
mtg_card_rarities_clean = mtg_card_rarities.copy()
mtg_card_rarities_clean.to_csv('mtg_card_rarities_clean.csv', index=False)

# %% [markdown]
# ### Test

# %%
card_rarities
# Out:
# ['rare',
#  'rare',
#  'mythic',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'uncommon',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'mythic',
#  'rare',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'common',
#  'rare',
#  'rare',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'mythic',
#  'mythic',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'rare',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'mythic',
#  'mythic',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'uncommon',
#  'common',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'mythic',
#  'mythic',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'mythic',
#  'common',
#  'rare',
#  'mythic',
#  'common',
#  'rare',
#  'rare',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'uncommon',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'rare',
#  'mythic',
#  'mythic',
#  'mythic',
#  'rare',
#  'rare',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'mythic',
#  'mythic',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'mythic',
#  'mythic',
#  'common',
#  'uncommon',
#  'uncommon',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'mythic',
#  'mythic',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'mythic',
#  'common',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'common',
#  'rare',
#  'uncommon',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'mythic',
#  'uncommon',
#  'common',
#  'rare',
#  'common',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'rare',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'rare',
#  'rare',
#  'common',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'uncommon',
#  'uncommon',
#  'mythic',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'uncommon',
#  'mythic',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'common',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'mythic',
#  'rare',
#  'uncommon',
#  'common',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'mythic',
#  'mythic',
#  'common',
#  'mythic',
#  'rare',
#  'uncommon',
#  'rare',
#  'uncommon',
#  'rare',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'common',
#  'rare',
#  'uncommon',
#  'rare',
#  'uncommon',
#  'common',
#  'rare',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'mythic',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'common',
#  'common',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'mythic',
#  'uncommon',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'mythic',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'uncommon',
#  'rare',
#  'mythic',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'rare',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'common',
#  'mythic',
#  'uncommon',
#  'rare',
#  'common',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'common',
#  'rare',
#  'uncommon',
#  'mythic',
#  'mythic',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'uncommon',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'common',
#  'rare',
#  'common',
#  'rare',
#  'common',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'mythic',
#  'common',
#  'mythic',
#  'uncommon',
#  'uncommon',
#  'common',
#  'mythic',
#  'common',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'mythic',
#  'mythic',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'rare',
#  'uncommon',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'uncommon',
#  'mythic',
#  'mythic',
#  'uncommon',
#  'uncommon',
#  'common',
#  'rare',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'common',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'rare',
#  'common',
#  'uncommon',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'mythic',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'rare',
#  'common',
#  'rare',
#  'uncommon',
#  'rare',
#  'mythic',
#  'mythic',
#  'uncommon',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'uncommon',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'common',
#  'uncommon',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'rare',
#  'uncommon',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'rare',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'mythic',
#  'common',
#  'mythic',
#  'rare',
#  'mythic',
#  'common',
#  'common',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'rare',
#  'uncommon',
#  'uncommon',
#  'rare',
#  'uncommon',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'mythic',
#  'mythic',
#  'common',
#  'rare',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'mythic',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'common',
#  'common',
#  'rare',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'uncommon',
#  'rare',
#  'mythic',
#  'common',
#  'uncommon',
#  'rare',
#  'common',
#  'common',
#  'uncommon',
#  'common',
#  'uncommon',
#  'common',
#  'common',
#  'common',
#  'uncommon',
#  'rare',
#  'uncommon',
#  'common',
#  'common',
#  'uncommon',
#  'uncommon',
#  ...]

# %%
card_names
# Out:
# ['Acclaimed Contender',
#  'Acclaimed Contender',
#  'Alela, Artful Provocateur',
#  'All That Glitters',
#  'Bring to Life',
#  'Animating Faerie',
#  'Bring to Life',
#  'Animating Faerie',
#  'Arcane Signet',
#  "Arcanist's Owl",
#  'Archon of Absolution',
#  'Ardenvale Paladin',
#  'Dizzying Swoop',
#  'Ardenvale Tactician',
#  'Dizzying Swoop',
#  'Ardenvale Tactician',
#  'Ayara, First of Locthwain',
#  'Ayara, First of Locthwain',
#  'Bake into a Pie',
#  'Banish into Fable',
#  'Barge In',
#  'Barrow Witches',
#  'Bartered Cow',
#  'Fertile Footsteps',
#  'Beanstalk Giant',
#  'Fertile Footsteps',
#  'Beanstalk Giant',
#  'Belle of the Brawl',
#  'Beloved Princess',
#  'Blacklance Paragon',
#  'Blacklance Paragon',
#  'Bloodhaze Wolverine',
#  'Blow Your House Down',
#  'Bog Naughty',
#  'Stomp',
#  'Bonecrusher Giant',
#  'Stomp',
#  'Bonecrusher Giant',
#  'Bramblefort Fink',
#  'Petty Theft',
#  'Brazen Borrower',
#  'Petty Theft',
#  'Brazen Borrower',
#  'Brimstone Trebuchet',
#  'Burning-Yard Trainer',
#  'Castle Ardenvale',
#  'Castle Ardenvale',
#  'Castle Embereth',
#  'Castle Embereth',
#  'Castle Garenbrig',
#  'Castle Garenbrig',
#  'Castle Locthwain',
#  'Castle Locthwain',
#  'Castle Vantress',
#  'Castle Vantress',
#  'Cauldron Familiar',
#  "Cauldron's Gift",
#  'Charmed Sleep',
#  'Charming Prince',
#  'Charming Prince',
#  'Chittering Witch',
#  'Chulane, Teller of Tales',
#  'Clackbridge Troll',
#  'Clackbridge Troll',
#  'Claim the Firstborn',
#  'Clockwork Servant',
#  'Command Tower',
#  'Corridor Monitor',
#  'Covetous Urge',
#  'Crashing Drawbridge',
#  'Crystal Slipper',
#  'Treats to Share',
#  'Curious Pair',
#  'Treats to Share',
#  'Curious Pair',
#  'Dance of the Manse',
#  'Dance of the Manse',
#  'Deafening Silence',
#  'Deathless Knight',
#  "Didn't Say Please",
#  'Doom Foretold',
#  'Doom Foretold',
#  'Drown in the Loch',
#  'Dwarven Mine',
#  'Edgewall Innkeeper',
#  'Elite Headhunter',
#  'Embercleave',
#  'Embercleave',
#  'Embereth Paladin',
#  'Battle Display',
#  'Embereth Shieldbreaker',
#  'Battle Display',
#  'Embereth Shieldbreaker',
#  'Embereth Skyblazer',
#  'Emry, Lurker of the Loch',
#  'Emry, Lurker of the Loch',
#  'Enchanted Carriage',
#  'Epic Downfall',
#  'Escape to the Wilds',
#  'Escape to the Wilds',
#  'Eye Collector',
#  'Fabled Passage',
#  'Fabled Passage',
#  'Granted',
#  'Fae of Wishes',
#  'Granted',
#  'Fae of Wishes',
#  'Faeburrow Elder',
#  'Faeburrow Elder',
#  'Faerie Formation',
#  'Gift of the Fae',
#  'Faerie Guidemother',
#  'Gift of the Fae',
#  'Faerie Guidemother',
#  'Faerie Vandal',
#  'Feasting Troll King',
#  'Feasting Troll King',
#  'Fell the Pheasant',
#  'Ferocity of the Wilds',
#  'Fervent Champion',
#  'Fervent Champion',
#  'Festive Funeral',
#  'Fierce Witchstalker',
#  'Fireborn Knight',
#  'Fires of Invention',
#  'Fires of Invention',
#  'Welcome Home',
#  'Flaxen Intruder',
#  'Welcome Home',
#  'Flaxen Intruder',
#  'Fling',
#  'Flutterfox',
#  'Folio of Fancies',
#  'Folio of Fancies',
#  'Foreboding Fruit',
#  'Forest',
#  'Forest',
#  'Forest',
#  'Forest',
#  'Forever Young',
#  'Fortifying Provisions',
#  'Profane Insight',
#  'Foulmire Knight',
#  'Profane Insight',
#  'Foulmire Knight',
#  'Frogify',
#  'Gadwick, the Wizened',
#  'Gadwick, the Wizened',
#  "Shield's Might",
#  'Garenbrig Carver',
#  "Shield's Might",
#  'Garenbrig Carver',
#  'Garenbrig Paladin',
#  'Garenbrig Squire',
#  'Garrison Griffin',
#  'Garruk, Cursed Huntsman',
#  'Garruk, Cursed Huntsman',
#  'Chop Down',
#  'Giant Killer',
#  'Chop Down',
#  'Giant Killer',
#  'Giant Opportunity',
#  "Giant's Skewer",
#  'Gilded Goose',
#  'Gilded Goose',
#  'Gingerbread Cabin',
#  'Gingerbrute',
#  'Glass Casket',
#  'Glass Casket',
#  'Gluttonous Troll',
#  'Golden Egg',
#  'Grumgully, the Generous',
#  'Happily Ever After',
#  'Happily Ever After',
#  'Harmonious Archon',
#  'Harmonious Archon',
#  'Henge Walker',
#  'Heraldic Banner',
#  'Hushbringer',
#  'Hushbringer',
#  'Mesmeric Glare',
#  'Hypnotic Sprite',
#  'Mesmeric Glare',
#  'Hypnotic Sprite',
#  'Idyllic Grange',
#  'Improbable Alliance',
#  'Improbable Alliance',
#  'Inquisitive Puppet',
#  'Insatiable Appetite',
#  'Inspiring Veteran',
#  'Inspiring Veteran',
#  'Into the Story',
#  'Irencrag Feat',
#  'Irencrag Feat',
#  'Irencrag Pyromancer',
#  'Irencrag Pyromancer',
#  'Island',
#  'Island',
#  'Island',
#  'Island',
#  'Joust',
#  'Jousting Dummy',
#  'Keeper of Fables',
#  "Kenrith's Transformation",
#  "Kenrith's Transformation",
#  'Kenrith, the Returned King',
#  'Knight of the Keep',
#  "Knights' Charge",
#  'Korvold, Fae-Cursed King',
#  'Lash of Thorns',
#  'Linden, the Steadfast Queen',
#  'Linden, the Steadfast Queen',
#  'Loch Dragon',
#  'Lochmere Serpent',
#  'Lochmere Serpent',
#  'Locthwain Gargoyle',
#  'Locthwain Paladin',
#  'Rider in Need',
#  'Lonesome Unicorn',
#  'Rider in Need',
#  'Lonesome Unicorn',
#  'Lost Legion',
#  "Heart's Desire",
#  'Lovestruck Beast',
#  "Heart's Desire",
#  'Lovestruck Beast',
#  'Lucky Clover',
#  'Mace of the Valiant',
#  'Mad Ratter',
#  'Malevolent Noble',
#  'Mantle of Tides',
#  'Maraleaf Pixie',
#  'Maraleaf Rider',
#  'Memory Theft',
#  'Haggle',
#  'Merchant of the Vale',
#  'Haggle',
#  'Merchant of the Vale',
#  'Venture Deeper',
#  'Merfolk Secretkeeper',
#  'Venture Deeper',
#  'Merfolk Secretkeeper',
#  'Midnight Clock',
#  'Midnight Clock',
#  'Mirrormade',
#  'Mirrormade',
#  'Mistford River Turtle',
#  'Moonlit Scavengers',
#  'Mountain',
#  'Mountain',
#  'Mountain',
#  'Mountain',
#  'Swift End',
#  'Murderous Rider',
#  'Swift End',
#  'Murderous Rider',
#  'Mysterious Pathlighter',
#  'Mystic Sanctuary',
#  'Mystical Dispute',
#  'Oakhame Adversary',
#  'Bring Back',
#  'Oakhame Ranger',
#  'Bring Back',
#  'Oakhame Ranger',
#  'Oathsworn Knight',
#  'Oathsworn Knight',
#  'Ogre Errant',
#  "Oko's Accomplices",
#  "Oko's Hospitality",
#  'Oko, Thief of Crowns',
#  'Oko, Thief of Crowns',
#  'Oko, the Trickster',
#  'Once Upon a Time',
#  'Once Upon a Time',
#  'Once and Future',
#  'Opportunistic Dragon',
#  'Opportunistic Dragon',
#  'Opt',
#  'Alter Fate',
#  'Order of Midnight',
#  'Alter Fate',
#  'Order of Midnight',
#  'Outflank',
#  "Outlaws' Merriment",
#  "Outlaws' Merriment",
#  'Outmuscle',
#  'Overwhelmed Apprentice',
#  'Piper of the Swarm',
#  'Piper of the Swarm',
#  'Piper of the Swarm',
#  'Plains',
#  'Plains',
#  'Plains',
#  'Plains',
#  'Prized Griffin',
#  'Prophet of the Peak',
#  'Rage of Winter',
#  'Queen of Ice',
#  'Rage of Winter',
#  'Queen of Ice',
#  'Questing Beast',
#  'Questing Beast',
#  'Raging Redcap',
#  'Rally for the Throne',
#  'Rampart Smasher',
#  'Rankle, Master of Pranks',
#  'Rankle, Master of Pranks',
#  'Cast Off',
#  'Realm-Cloaked Giant',
#  'Cast Off',
#  'Realm-Cloaked Giant',
#  'Harvest Fear',
#  'Reaper of Night',
#  'Harvest Fear',
#  'Reaper of Night',
#  'Reave Soul',
#  'Redcap Melee',
#  'Redcap Raiders',
#  'Resolute Rider',
#  'Return of the Wildspeaker',
#  'Return of the Wildspeaker',
#  'Return to Nature',
#  'Revenge of Ravens',
#  'Righteousness',
#  'Boulder Rush',
#  'Rimrock Knight',
#  'Boulder Rush',
#  'Rimrock Knight',
#  'Robber of the Rich',
#  'Robber of the Rich',
#  'Seasonal Ritual',
#  'Rosethorn Acolyte',
#  'Seasonal Ritual',
#  'Rosethorn Acolyte',
#  'Rosethorn Halberd',
#  'Roving Keep',
#  "Rowan's Battleguard",
#  "Rowan's Stalwarts",
#  'Rowan, Fearless Sparkmage',
#  'Run Away Together',
#  'Sage of the Falls',
#  'Savvy Hunter',
#  'Scalding Cauldron',
#  'Scorching Dragonfire',
#  'Searing Barrage',
#  'Seven Dwarves',
#  'Shambling Suit',
#  'Usher to Safety',
#  'Shepherd of the Flock',
#  'Usher to Safety',
#  'Shepherd of the Flock',
#  'Shimmer Dragon',
#  'Shinechaser',
#  'Shining Armor',
#  'Signpost Scarecrow',
#  'Silverflame Ritual',
#  'On Alert',
#  'Silverflame Squire',
#  'On Alert',
#  'Silverflame Squire',
#  'Silverwing Squadron',
#  'Skullknocker Ogre',
#  'Slaying Fire',
#  'Slaying Fire',
#  'Curry Favor',
#  'Smitten Swordmaster',
#  'Curry Favor',
#  'Smitten Swordmaster',
#  'So Tiny',
#  "Sorcerer's Broom",
#  'Sorcerous Spyglass',
#  'Sorcerous Spyglass',
#  "Specter's Shriek",
#  'Spinning Wheel',
#  'Sporecap Spider',
#  'Steelbane Hydra',
#  'Steelclaw Lance',
#  'Steelgaze Griffin',
#  'Stolen by the Fae',
#  'Stolen by the Fae',
#  'Stonecoil Serpent',
#  'Stonecoil Serpent',
#  'Stormfist Crusader',
#  'Stormfist Crusader',
#  'Sundering Stroke',
#  'Sundering Stroke',
#  'Swamp',
#  'Swamp',
#  'Swamp',
#  'Swamp',
#  "Syr Alin, the Lion's Claw",
#  'Syr Carah, the Bold',
#  'Syr Elenora, the Discerning',
#  'Syr Faren, the Hengehammer',
#  'Syr Gwyn, Hero of Ashvale',
#  'Syr Konrad, the Grim',
#  'Tall as a Beanstalk',
#  'Taste of Death',
#  'Tempting Witch',
#  'The Cauldron of Eternity',
#  'The Cauldron of Eternity',
#  'The Circle of Loyalty',
#  'The Circle of Loyalty',
#  'The Great Henge',
#  'The Great Henge',
#  'The Magic Mirror',
#  'The Magic Mirror',
#  'The Royal Scions',
#  'The Royal Scions',
#  'Thorn Mammoth',
#  'Thornwood Falls',
#  'Thrill of Possibility',
#  'Thunderous Snapper',
#  'Tome Raider',
#  'Tome of Legends',
#  'Torbran, Thane of Red Fell',
#  'Torbran, Thane of Red Fell',
#  'Tournament Grounds',
#  'Trail of Crumbs',
#  'Trapped in the Tower',
#  "True Love's Kiss",
#  'Oaken Boon',
#  'Tuinvale Treefolk',
#  'Oaken Boon',
#  'Tuinvale Treefolk',
#  'Turn into a Pumpkin',
#  'Unexplained Vision',
#  'Vantress Gargoyle',
#  'Vantress Gargoyle',
#  'Vantress Paladin',
#  'Venerable Knight',
#  'Wandermare',
#  'Weapon Rack',
#  'Weaselback Redcap',
#  'Wicked Guardian',
#  'Wicked Wolf',
#  'Wicked Wolf',
#  'Wildborn Preserver',
#  'Wildborn Preserver',
#  'Wildwood Tracker',
#  'Wind-Scarred Crag',
#  'Wintermoor Commander',
#  'Wishclaw Talisman',
#  'Wishclaw Talisman',
#  'Wishful Merfolk',
#  "Witch's Cottage",
#  "Witch's Oven",
#  "Witch's Vengeance",
#  "Witch's Vengeance",
#  'Witching Well',
#  "Wolf's Quarry",
#  'Workshop Elders',
#  'Worthy Knight',
#  'Worthy Knight',
#  'Yorvo, Lord of Garenbrig',
#  'Yorvo, Lord of Garenbrig',
#  'Youthful Knight',
#  'Affectionate Indrik',
#  'Arboretum Elemental',
#  'Arclight Phoenix',
#  'Artful Takedown',
#  "Assassin's Trophy",
#  'Assemble',
#  'Assure',
#  'Attendant of Vraska',
#  'Aurelia, Exemplar of Justice',
#  'Barging Sergeant',
#  'Barrier of Bones',
#  'Bartizan Bats',
#  'Beacon Bolt',
#  'Beamsplitter Mage',
#  'Beast Whisperer',
#  'Blade Instructor',
#  'Blood Operative',
#  'Book Devourer',
#  'Boros Challenger',
#  'Boros Guildgate',
#  'Boros Guildgate',
#  'Boros Locket',
#  'Bounty Agent',
#  'Bounty of Might',
#  'Burglar Rat',
#  'Camaraderie',
#  'Candlelight Vigil',
#  'Capture Sphere',
#  'Centaur Peacemaker',
#  'Chamber Sentry',
#  'Chance for Glory',
#  'Charnel Troll',
#  "Chemister's Insight",
#  'Child of Night',
#  'Chromatic Lantern',
#  'Circuitous Route',
#  'Citywatch Sphinx',
#  'Citywide Bust',
#  'Collar the Culprit',
#  'Command the Storm',
#  'Conclave Cavalier',
#  'Conclave Guildmage',
#  'Conclave Tribunal',
#  'Concoct',
#  'Connive',
#  'Cosmotronic Wave',
#  'Crackling Drake',
#  'Creeping Chill',
#  'Crush Contraband',
#  'Crushing Canopy',
#  'Darkblade Agent',
#  'Dawn of Hope',
#  'Dazzling Lights',
#  'Dead Weight',
#  'Deadly Visit',
#  'Deafening Clarion',
#  'Demotion',
#  'Devious Cover-Up',
#  'Devkarin Dissident',
#  'Dimir Guildgate',
#  'Dimir Guildgate',
#  'Dimir Informant',
#  'Dimir Locket',
#  'Dimir Spybug',
#  'Direct Current',
#  'Dispersal',
#  'Discovery',
#  'Disdainful Stroke',
#  'Disinformation Campaign',
#  'District Guide',
#  'Divine Visitation',
#  'Doom Whisperer',
#  'Douser of Lights',
#  'Dream Eater',
#  'Drowned Secrets',
#  'Electrostatic Field',
#  'Emmara, Soul of the Accord',
#  'Enhanced Surveillance',
#  'Erratic Cyclops',
#  'Erstwhile Trooper',
#  'Etrata, the Silencer',
#  'Explosion',
#  'Expansion',
#  'Experimental Frenzy',
#  'Fearless Halberdier',
#  'Finality',
#  'Find',
#  'Fire Urchin',
#  "Firemind's Research",
#  'Flight of Equenauts',
#  'Flourish',
#  'Flower',
#  'Forest',
#  'Fresh-Faced Recruit',
#  'Garrison Sergeant',
#  'Gatekeeper Gargoyle',
#  'Gateway Plaza',
#  'Generous Stray',
#  'Gird for Battle',
#  'Glaive of the Guildpact',
#  'Glowspore Shaman',
#  'Goblin Banneret',
#  'Goblin Cratermaker',
#  'Goblin Electromancer',
#  'Goblin Locksmith',
#  'Golgari Findbroker',
#  'Golgari Guildgate',
#  'Golgari Guildgate',
#  'Golgari Locket',
#  'Golgari Raiders',
#  'Grappling Sundew',
#  'Gravitic Punch',
#  'Gruesome Menagerie',
#  'Guild Summit',
#  "Guildmages' Forum",
#  'Haazda Marshal',
#  'Hammer Dropper',
#  'Hatchery Spider',
#  "Healer's Hawk",
#  'Hellkite Whelp',
#  'Hired Poisoner',
#  'Hitchclaw Recluse',
#  'House Guildmage',
#  'Hunted Witness',
#  'Hypothesizzle',
#  'Impervious Greatwurm',
#  'Inescapable Blaze',
#  'Inspiring Unicorn',
#  'Intervention',
#  'Integrity',
#  'Intrusive Packbeast',
#  'Invent',
#  'Invert',
#  'Ionize',
#  'Ironshell Beetle',
#  'Island',
#  'Izoni, Thousand-Eyed',
#  'Izzet Guildgate',
#  'Izzet Guildgate',
#  'Izzet Locket',
#  'Join Shields',
#  'Justice Strike',
#  'Knight of Autumn',
#  'Kraul Foragers',
#  'Kraul Harpooner',
#  'Kraul Raider',
#  'Kraul Swarm',
#  'Lava Coil',
#  'Lazav, the Multifarious',
#  'League Guildmage',
#  'Leapfrog',
#  'Ledev Champion',
#  'Ledev Guardian',
#  'Legion Guildmage',
#  'Legion Warboss',
#  'Light of the Legion',
#  'Lotleth Giant',
#  'Loxodon Restorer',
#  'Luminous Bonds',
#  'Maniacal Rage',
#  'March of the Multitudes',
#  'Mausoleum Secrets',
#  'Maximize Altitude',
#  'Maximize Velocity',
#  'Mephitic Vapors',
#  'Midnight Reaper',
#  'Might of the Masses',
#  'Mission Briefing',
#  'Mnemonic Betrayal',
#  'Molderhulk',
#  'Moodmark Painter',
#  'Mountain',
#  'Murmuring Mystic',
#  'Muse Drake',
#  'Narcomoeba',
#  'Necrotic Wound',
#  'Never Happened',
#  'Nightveil Predator',
#  'Nightveil Sprite',
#  'Niv-Mizzet, Parun',
#  'Notion Rain',
#  'Nullhide Ferox',
#  'Ochran Assassin',
#  'Omnispell Adept',
#  'Ornery Goblin',
#  'Overgrown Tomb',
#  "Pack's Favor",
#  'Parhelion Patrol',
#  'Passwall Adept',
#  'Pause for Reflection',
#  'Pelt Collector',
#  'Pilfering Imp',
#  'Piston-Fist Cyclops',
#  'Pitiless Gorgon',
#  'Plaguecrafter',
#  'Plains',
#  'Portcullis Vine',
#  'Precision Bolt',
#  'Prey Upon',
#  'Price of Fame',
#  'Quasiduplicate',
#  'Radical Idea',
#  "Ral's Dispersal",
#  "Ral's Staticaster",
#  'Ral, Caller of Storms',
#  'Ral, Izzet Viceroy',
#  'Rampaging Monument',
#  'Resurgence',
#  'Response',
#  'Rhizome Lurcher',
#  'Righteous Blow',
#  'Risk Factor',
#  'Ritual of Soot',
#  'Roc Charger',
#  'Rosemane Centaur',
#  'Rubblebelt Boar',
#  'Runaway Steam-Kin',
#  'Sacred Foundry',
#  'Selective Snare',
#  'Selesnya Guildgate',
#  'Selesnya Guildgate',
#  'Selesnya Locket',
#  'Severed Strands',
#  'Siege Wurm',
#  'Silent Dart',
#  'Sinister Sabotage',
#  'Skyknight Legionnaire',
#  'Skyline Scout',
#  'Smelt-Ward Minotaur',
#  'Sonic Assault',
#  'Spinal Centipede',
#  'Sprouting Renewal',
#  'Statue',
#  'Status',
#  'Steam Vents',
#  'Street Riot',
#  'Sumala Woodshaper',
#  'Sunhome Stalwart',
#  'Sure Strike',
#  'Swamp',
#  'Swarm Guildmage',
#  'Swathcutter Giant',
#  'Swiftblade Vindicator',
#  'Sworn Companions',
#  "Tajic, Legion's Edge",
#  'Take Heart',
#  'Temple Garden',
#  'Tenth District Guard',
#  'Thief of Sanity',
#  'Thought Erasure',
#  'Thoughtbound Phantasm',
#  'Thousand-Year Storm',
#  'Torch Courier',
#  'Trostani Discordant',
#  'Truefire Captain',
#  'Undercity Necrolisk',
#  'Undercity Uprising',
#  'Underrealm Lich',
#  'Unexplained Disappearance',
#  'Unmoored Ego',
#  'Urban Utopia',
#  'Vedalken Mesmerist',
#  'Veiled Shade',
#  'Venerated Loxodon',
#  'Vernadi Shieldmate',
#  'Vicious Rumors',
#  'Vigorspore Wurm',
#  'Vivid Revival',
#  "Vraska's Stoneglare",
#  'Vraska, Golgari Queen',
#  'Vraska, Regal Gorgon',
#  'Wall of Mist',
#  'Wand of Vertebrae',
#  'Wary Okapi',
#  'Watcher in the Mist',
#  'Watery Grave',
#  'Wee Dragonauts',
#  'Whisper Agent',
#  'Whispering Snitch',
#  'Wild Ceratok',
#  'Wishcoin Crab',
#  'Wojek Bodyguard',
#  'Worldsoul Colossus',
#  'Act of Treason',
#  'Aerial Assault',
#  'Aether Gust',
#  'Agent of Treachery',
#  'Aggressive Mammoth',
#  'Agonizing Syphon',
#  'Air Elemental',
#  'Ajani, Inspiring Leader',
#  'Ajani, Strength of the Pride',
#  'Ancestral Blade',
#  'Angel of Vitality',
#  'Angelic Gift',
#  'Angelic Guardian',
#  'Anticipate',
#  'Anvilwrought Raptor',
#  'Apostle of Purifying Light',
#  'Atemsis, All-Seeing',
#  'Audacious Thief',
#  'Bag of Holding',
#  'Barkhide Troll',
#  'Barony Vampire',
#  'Bartizan Bats',
#  'Bastion Enforcer',
#  'Battalion Foot Soldier',
#  'Befuddle',
#  'Bishop of Wings',
#  'Bladebrand',
#  'Blightbeetle',
#  'Blood Burglar',
#  'Blood for Bones',
#  'Bloodfell Caves',
#  'Bloodsoaked Altar',
#  'Bloodthirsty Aerialist',
#  'Blossoming Sands',
#  'Bogstomper',
#  'Bone Splinters',
#  'Bone to Ash',
#  'Boneclad Necromancer',
#  'Boreal Elemental',
#  'Brightwood Tracker',
#  'Brineborn Cutthroat',
#  'Bristling Boar',
#  'Brought Back',
#  'Canopy Spider',
#  'Captivating Gyre',
#  'Cavalier of Dawn',
#  'Cavalier of Flame',
#  'Cavalier of Gales',
#  'Cavalier of Night',
#  'Cavalier of Thorns',
#  'Celestial Messenger',
#  'Centaur Courser',
#  'Cerulean Drake',
#  "Chandra's Embercat",
#  "Chandra's Flame Wave",
#  "Chandra's Outrage",
#  "Chandra's Regulator",
#  "Chandra's Spitfire",
#  'Chandra, Acolyte of Flame',
#  'Chandra, Awakened Inferno',
#  "Chandra, Flame's Fury",
#  'Chandra, Novice Pyromancer',
#  'Cloudkin Seer',
#  'Colossus Hammer',
#  'Concordia Pegasus',
#  'Convolute',
#  'Coral Merfolk',
#  'Corpse Knight',
#  'Corpse Knight',
#  'Creeping Trailblazer',
#  'Cryptic Caves',
#  'Daggersail Aeronaut',
#  'Dark Remedy',
#  'Dawning Angel',
#  'Daybreak Chaplain',
#  'Destructive Digger',
#  'Devout Decree',
#  'Diamond Knight',
#  'Disenchant',
#  'Disentomb',
#  'Disfigure',
#  'Dismal Backwater',
#  "Diviner's Lockbox",
#  'Dragon Mage',
#  'Drakuseth, Maw of Flames',
#  'Drawn from Dreams',
#  'Dread Presence',
#  'Dungeon Geists',
#  'Duress',
#  'Elvish Reclaimer',
#  'Ember Hauler',
#  'Embodiment of Agonies',
#  'Empyrean Eagle',
#  'Engulfing Eruption',
#  'Epicure of Blood',
#  'Eternal Isolation',
#  'Ethereal Elk',
#  'Evolving Wilds',
#  'Faerie Miscreant',
#  'Fathom Fleet Cutthroat',
#  'Fearless Halberdier',
#  'Fencing Ace',
#  'Feral Abomination',
#  'Feral Invocation',
#  'Ferocious Pup',
#  'Field of the Dead',
#  'Fire Elemental',
#  'Flame Sweep',
#  'Flood of Tears',
#  'Forest',
#  'Forest',
#  'Forest',
#  'Forest',
#  'Fortress Crab',
#  'Frilled Sandwalla',
#  'Frilled Sea Serpent',
#  'Frost Lynx',
#  'Fry',
#  'Gargos, Vicious Watcher',
#  'Gauntlets of Light',
#  'Gift of Paradise',
#  'Glaring Aegis',
#  'Glint-Horn Buccaneer',
#  'Gnarlback Rhino',
#  'Goblin Assailant',
#  'Goblin Bird-Grabber',
#  'Goblin Ringleader',
#  'Goblin Smuggler',
#  'Gods Willing',
#  'Goldmane Griffin',
#  'Golos, Tireless Pilgrim',
#  'Gorging Vulture',
#  "Grafdigger's Cage",
#  'Gravedigger',
#  'Gravewaker',
#  'Greenwood Sentinel',
#  'Griffin Protector',
#  'Griffin Sentinel',
#  'Growth Cycle',
#  'Gruesome Scourger',
#  'Haazda Officer',
#  'Hanged Executioner',
#  'Hard Cover',
#  'Healer of the Glade',
#  'Heart-Piercer Bow',
#  'Herald of the Sun',
#  'Hostile Minotaur',
#  'Howling Giant',
#  'Icon of Ancestry',
#  'Immortal Phoenix',
#  'Impassioned Orator',
#  'Imperial Outrider',
#  'Infuriate',
#  'Inspired Charge',
#  'Inspiring Captain',
#  'Ironclad Krovod',
#  'Ironroot Warlord',
#  'Island',
#  'Island',
#  'Island',
#  'Island',
#  'Jungle Hollow',
#  'Kaalia, Zenith Seeker',
#  'Keldon Raider',
#  'Kethis, the Hidden Hand',
#  'Knight of the Ebon Legion',
#  "Kykar, Wind's Fury",
#  'Lavakin Brawler',
#  'Leafkin Druid',
#  "Legion's End",
#  'Leyline of Abundance',
#  'Leyline of Anticipation',
#  'Leyline of Combustion',
#  'Leyline of Sanctity',
#  'Leyline of the Void',
#  'Lightning Stormkin',
#  'Loaming Shaman',
#  'Lotus Field',
#  'Loxodon Lifechanter',
#  'Loyal Pegasus',
#  'Mammoth Spider',
#  'Maniacal Rage',
#  'Manifold Key',
#  "Marauder's Axe",
#  'Marauding Raptor',
#  'Mask of Immolation',
#  'Master Splicer',
#  'Masterful Replication',
#  'Meteor Golem',
#  'Metropolis Sprite',
#  'Might of the Masses',
#  'Mind Rot',
#  'Moat Piranhas',
#  'Moldervine Reclamation',
#  'Moment of Heroism',
#  'Moorland Inquisitor',
#  'Mountain',
#  'Mountain',
#  'Mountain',
#  'Mountain',
#  'Mu Yanling, Celestial Wind',
#  'Mu Yanling, Sky Dancer',
#  'Murder',
#  'Mystic Forge',
#  'Natural End',
#  'Negate',
#  'Netcaster Spider',
#  'Nightpack Ambusher',
#  'Nimble Birdsticker',
#  'Noxious Grasp',
#  'Oakenform',
#  'Octoprophet',
#  'Ogre Siegebreaker',
#  'Omnath, Locus of the Roil',
#  'Overcome',
#  'Overgrowth Elemental',
#  'Pacifism',
#  'Pack Mastiff',
#  'Pattern Matcher',
#  'Phantom Warrior',
#  'Plains',
#  'Plains',
#  'Plains',
#  'Plains',
#  'Planar Cleansing',
#  'Plummet',
#  'Portal of Sanctuary',
#  'Prismite',
#  'Prized Unicorn',
#  'Prowling Caracal',
#  'Pulse of Murasa',
#  'Pyroclastic Elemental',
#  'Rabid Bite',
#  'Raise the Alarm',
#  'Rapacious Dragon',
#  'Reckless Air Strike',
#  'Reduce to Ashes',
#  'Renowned Weaponsmith',
#  'Repeated Reverberation',
#  'Retributive Wand',
#  'Riddlemaster Sphinx',
#  'Rienne, Angel of Rebirth',
#  'Ripscale Predator',
#  'Risen Reef',
#  'Rotting Regisaur',
#  'Rubblebelt Recluse',
#  'Rugged Highlands',
#  'Rule of Law',
#  "Sage's Row Denizen",
#  'Salvager of Ruin',
#  'Sanitarium Skeleton',
#  'Savage Gorger',
#  'Savannah Sage',
#  'Scampering Scorcher',
#  'Scheming Symmetry',
#  'Scholar of the Ages',
#  'Scorch Spitter',
#  'Scoured Barrens',
#  'Scuttlemutt',
#  'Season of Growth',
#  ...]

# %%
np.count_nonzero(card_rarities), np.count_nonzero(card_names)
# Out:
# (1679, 1679)

# %%
mtg_card_rarities_clean
# Out:
#                                name    rarity
# 0               Acclaimed Contender      rare
# 1               Acclaimed Contender      rare
# 2         Alela, Artful Provocateur    mythic
# 3                 All That Glitters  uncommon
# 4                     Bring to Life  uncommon
# 5                  Animating Faerie  uncommon
# 6                     Bring to Life  uncommon
# 7                  Animating Faerie  uncommon
# 8                     Arcane Signet    common
# 9                    Arcanist's Owl  uncommon
# 10             Archon of Absolution  uncommon
# 11                Ardenvale Paladin    common
# 12                   Dizzying Swoop    common
# 13              Ardenvale Tactician    common
# 14                   Dizzying Swoop    common
# 15              Ardenvale Tactician    common
# 16        Ayara, First of Locthwain      rare
# 17        Ayara, First of Locthwain      rare
# 18                  Bake into a Pie    common
# 19                Banish into Fable      rare
# 20                         Barge In    common
# 21                   Barrow Witches    common
# 22                     Bartered Cow    common
# 23                Fertile Footsteps  uncommon
# 24                  Beanstalk Giant  uncommon
# 25                Fertile Footsteps  uncommon
# 26                  Beanstalk Giant  uncommon
# 27               Belle of the Brawl  uncommon
# 28                 Beloved Princess    common
# 29               Blacklance Paragon      rare
# ...                             ...       ...
# 1649      Tibalt, Rakish Instigator  uncommon
# 1650      Tibalt, Rakish Instigator  uncommon
# 1651                      Time Wipe      rare
# 1652              Tithebearer Giant    common
# 1653           Toll of the Invasion    common
# 1654     Tolsimir, Friend to Wolves      rare
# 1655  Tomik, Distinguished Advokist      rare
# 1656              Topple the Statue    common
# 1657                   Totally Lost    common
# 1658                Trusted Pegasus    common
# 1659                    Turret Ogre    common
# 1660                 Tyrant's Scorn  uncommon
# 1661               Ugin's Conjurant  uncommon
# 1662            Ugin, the Ineffable      rare
# 1663            Ugin, the Ineffable      rare
# 1664                   Unlikely Aid    common
# 1665            Vampire Opportunist    common
# 1666                Vivien's Arkbow      rare
# 1667               Vivien's Grizzly    common
# 1668  Vivien, Champion of the Wilds      rare
# 1669  Vivien, Champion of the Wilds      rare
# 1670         Vizier of the Scorpion  uncommon
# 1671              Vraska's Finisher    common
# 1672       Vraska, Swarm's Eminence  uncommon
# 1673       Vraska, Swarm's Eminence  uncommon
# 1674                  Wall of Runes    common
# 1675              Wanderer's Strike    common
# 1676                  War Screecher    common
# 1677            Wardscale Crocodile    common
# 1678           Widespread Brutality      rare
#
# [1679 rows x 2 columns]

# %%
mtg_card_rarities_clean = pd.read_csv('mtg_card_rarities_clean.csv')

# %% [markdown]
# ### Define
# - drop duplicates

# %% [markdown]
# ### Code

# %%
# drop duplicates in mtg_card_rarities_clean
mtg_card_rarities_clean.drop_duplicates(inplace=True)

# %%
mtg_card_rarities_clean.to_csv('mtg_card_rarities_clean.csv', index=False)

# %% [markdown]
# ### Test

# %%
mtg_card_rarities_clean.duplicated().sum()
# Out:
# 0

# %%
mtg_card_rarities_clean = pd.read_csv('mtg_card_rarities_clean.csv')
print(mtg_card_rarities_clean)
# Out:
#                                 name    rarity
# 0                Acclaimed Contender      rare
# 1          Alela, Artful Provocateur    mythic
# 2                  All That Glitters  uncommon
# 3                      Bring to Life  uncommon
# 4                   Animating Faerie  uncommon
# 5                      Arcane Signet    common
# 6                     Arcanist's Owl  uncommon
# 7               Archon of Absolution  uncommon
# 8                  Ardenvale Paladin    common
# 9                     Dizzying Swoop    common
# 10               Ardenvale Tactician    common
# 11         Ayara, First of Locthwain      rare
# 12                   Bake into a Pie    common
# 13                 Banish into Fable      rare
# 14                          Barge In    common
# 15                    Barrow Witches    common
# 16                      Bartered Cow    common
# 17                 Fertile Footsteps  uncommon
# 18                   Beanstalk Giant  uncommon
# 19                Belle of the Brawl  uncommon
# 20                  Beloved Princess    common
# 21                Blacklance Paragon      rare
# 22               Bloodhaze Wolverine    common
# 23              Blow Your House Down    common
# 24                       Bog Naughty  uncommon
# 25                             Stomp      rare
# 26                 Bonecrusher Giant      rare
# 27                  Bramblefort Fink  uncommon
# 28                       Petty Theft    mythic
# 29                   Brazen Borrower    mythic
# ...                              ...       ...
# 1390  Tezzeret, Master of the Bridge    mythic
# 1391                  The Elderspell      rare
# 1392                    The Wanderer  uncommon
# 1393                   Thunder Drake    common
# 1394              Thundering Ceratok    common
# 1395                  Tibalt's Rager  uncommon
# 1396       Tibalt, Rakish Instigator  uncommon
# 1397                       Time Wipe      rare
# 1398               Tithebearer Giant    common
# 1399            Toll of the Invasion    common
# 1400      Tolsimir, Friend to Wolves      rare
# 1401   Tomik, Distinguished Advokist      rare
# 1402               Topple the Statue    common
# 1403                    Totally Lost    common
# 1404                     Turret Ogre    common
# 1405                  Tyrant's Scorn  uncommon
# 1406                Ugin's Conjurant  uncommon
# 1407             Ugin, the Ineffable      rare
# 1408                    Unlikely Aid    common
# 1409                 Vivien's Arkbow      rare
# 1410                Vivien's Grizzly    common
# 1411   Vivien, Champion of the Wilds      rare
# 1412          Vizier of the Scorpion  uncommon
# 1413               Vraska's Finisher    common
# 1414        Vraska, Swarm's Eminence  uncommon
# 1415                   Wall of Runes    common
# 1416               Wanderer's Strike    common
# 1417                   War Screecher    common
# 1418             Wardscale Crocodile    common
# 1419            Widespread Brutality      rare
#
# [1420 rows x 2 columns]

# %% [markdown]
# # deck_type_urls

# %% [markdown]
# ## Gather

# %%
# make a webcrawler to gather the data from mtgtop8.com on competitive decks
url = 'https://www.mtgtop8.com/format?f=ST'
url_standard_page_response = requests.get(url)

# %%
# save the response
with open('url_standard_page_response.html', mode='wb') as file:
    file.write(url_standard_page_response.content)

# %%
# open response as a BeautifulSoup object
with open('url_standard_page_response.html') as file:
    soup = BeautifulSoup(file, 'lxml')

# %%
url = {'url': soup.find_all(href=re.compile(r"archetype\?a"))}
deck_type_urls = pd.DataFrame(data=url)

# %%
# create column for deck type and clean the column
deck_type_urls.url = deck_type_urls.url.astype('str')
deck_type_urls['type'] = deck_type_urls.url.str.extract('(>.+<)')
deck_type_urls['type'] = deck_type_urls.type.str.replace('>', '')
deck_type_urls['type'] = deck_type_urls.type.str.replace('<', '')
deck_type_urls['type'] = deck_type_urls.type.str.strip()

# %%
# extract url from the url column
deck_type_urls['url'] = deck_type_urls.url.str.extract('(archetype.+f\=ST)')

# %%
# add root url to the data
urls = []
types = []

for i in np.arange(deck_type_urls.shape[0]):
    urls.append(str('https://www.mtgtop8.com/') + deck_type_urls.url[i])
    types.append(deck_type_urls.type[i] + str('.html'))

# %%
deck_type_urls['url'] = urls
deck_type_urls['type'] = types
deck_type_urls['type'] = deck_type_urls.type.str.replace(' ', '_')
deck_type_urls['type'] = deck_type_urls.type.str.replace('/', '-')

# %%
# create web crawler to request html pages from deck_type_urls

# create new path and name it newpath
newpath = str(os.path.abspath(os.curdir)) + '\\type_html_files'

# check to make sure that there is no path that matches newpath and create a folder called html_files if there isn't
if not os.path.exists(newpath):
    os.makedirs(newpath)

# change current directory to newpath
os.chdir(newpath)

# scrape all html files from urls in deck_type_urls and put them in html_files folder
for i in np.arange(deck_type_urls.shape[0]):
    type_html = requests.get(deck_type_urls.url[i])
    with open(deck_type_urls.type[i], 'wb') as file:
        file.write(type_html.content)

# %% [markdown]
# # deck_urls

# %% [markdown]
# ## Gather

# %%
# get a list of file names in html_files folder and name it dir_names
dir_names = []
cur_dir = os.path.abspath(os.curdir)

with os.scandir(cur_dir) as folder:
    for file in folder: 
        if file.is_file():
            dir_names.append(file.name)

# %%
# get a list of all urls in all files
deck_urls = []
for i in np.arange(np.count_nonzero(dir_names)):
    with open(dir_names[i]) as file:
        soup = BeautifulSoup(file, 'lxml')
    urls = soup.find_all(href=re.compile(r'event\?e\=.+\&d\=.+\&f\=ST'))
    for a in urls:
        deck_urls.append(a)

# %%
# turn deck urls into a dataframe
deck_urls = {'url': deck_urls}
deck_urls = pd.DataFrame(data=deck_urls)

# %%
# get deck names and clean them up
deck_urls.url = deck_urls.url.astype('str')
deck_urls['name'] = deck_urls.url.str.extract('(>.+<)')
deck_urls.name = deck_urls.name.str.replace('>', '')
deck_urls.name = deck_urls.name.str.replace('<', '')
deck_urls.name = deck_urls.name.str.strip()

# %%
# extract url from the url column
deck_urls['url'] = deck_urls.url.str.extract('(event.+f\=ST)')

# %%
# add root url to the data
urls = []
names = []

for i in np.arange(deck_urls.shape[0]):
    urls.append(str('https://www.mtgtop8.com/') + deck_urls.url[i])
    names.append(deck_urls.name[i] + str('.html'))

# %%
# clean urls and name
deck_urls['url'] = urls
deck_urls['name'] = names
deck_urls['name'] = deck_urls.name.str.replace(' ', '_')
deck_urls['name'] = deck_urls.name.str.replace('/', '-')

# %% [markdown]
# ## decks

# %%
# create a web crawler to request html pages from deck_type_urls

# create a new path and name it newpath
oldpath = str(os.path.abspath(os.curdir))
newpath = oldpath.replace('\\type_html_files', '\\deck_html_files')

# check to make sure that there is no path that matches newpath and create a folder called html_files if there isn't
if not os.path.exists(newpath):
    os.makedirs(newpath)

# change the current directory to newpath
os.chdir(newpath)

# scrape all html files from urls in deck_urls and put them in html_files folder
deck_errors = []

for i in np.arange(deck_urls.shape[0]):
    try:
        deck_html = requests.get(deck_urls.url[i])
        with open(deck_urls.name[i], 'wb') as file:
            file.write(deck_html.content)
    except Exception as e:
        print(str(i) + ' ' + str(e))
        deck_errors.append(i)
# Out:
# 134 [Errno 22] Invalid argument: 'Bant_Golos.html'
# 281 [Errno 22] Invalid argument: 'Grixis_"spacebar"_Midrange.html'
